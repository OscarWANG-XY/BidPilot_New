# %% [markdown]
# #### 前期准备

# %%
# 获取当前notebook的绝对路径
import sys, os
from pathlib import Path
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[4]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/clients/tiptap/tools/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
#project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2

# %%
from app.services.structuring.cache import Cache
cache = Cache(project_id)
raw_document = await cache.get_document('raw_document')
h1_document = await cache.get_document('h1_document')
h2h3_document = await cache.get_document('h2h3_document')
intro_document = await cache.get_document('intro_document')
final_document = await cache.get_document('final_document')
# Out:
# Redis连接成功
# 获取文档数据失败 final_document: cannot access local variable 'e' where it is not associated with a value

# %%
print("raw_document:",type(raw_document), len(raw_document))
print("h1_document:",type(h1_document), len(h1_document))
print("h2h3_document:",type(h2h3_document), len(h2h3_document))
print("intro_document:",type(intro_document), len(intro_document))
# print("final_document:",type(final_document), len(final_document))
# Out:
# raw_document: <class 'dict'> 2
# h1_document: <class 'dict'> 2
# h2h3_document: <class 'dict'> 2
# intro_document: <class 'dict'> 2

# %% [markdown]
# #### 验证 get_paragraph_nodes_with_position

# %%
from app.clients.tiptap.tools import get_paragraph_nodes_with_position
paragraphs = get_paragraph_nodes_with_position(raw_document)
print(len(paragraphs))
from pprint import pprint
pprint(paragraphs)
# Out:
# 903
# [{'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 0,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 1,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 2,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 3,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 4,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '年端午节物资采购项目',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 5,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 6,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 7,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 8,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 9,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 10,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 11,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 12,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '招标文件',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 13,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 14,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 15,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 16,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 17,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 18,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 19,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 20,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '项目名称',
#                         'type': 'text'},
#                        {'text': '：', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '年端午节',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '物资采购项目（第一包：一级压榨花生油）',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 21,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '项目编号：DLXM-2024-148-01',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 22,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '招',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '标',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '人：北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '代理机构：北京中外建工程管理有限公司',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 23,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 24,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 25,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 26,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 27,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 28,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 29,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 30,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '年',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '3',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '月',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 31,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 32,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '目',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '录',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 33,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 34,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 35,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark2',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第一章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark2',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark2',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '招标公告 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark2',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '2',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 36,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark4',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第二章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark4',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark4',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '招标需求 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark4',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '5',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 37,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark6',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第三章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark6',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark6',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '投标人须知 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark6',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '8',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 38,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark8',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '前附表 8',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 39,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark10',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '一、总则 12',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 40,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark12',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '二、招标文件 13',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 41,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark14',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '三、投标文件的编制 14',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 42,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark16',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '四、开标 18',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 43,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark18',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '五、评标 19',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 44,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark20',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '六、定标 21',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 45,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark22',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '七、合同授予 21',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 46,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark24',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '八、履约保证金 21',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 47,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark26',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '九、招标代理服务费的收取 21',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 48,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark28',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第四章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark28',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark28',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '评标办法及评分标准 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark28',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '22',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 49,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark30',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件一：资格审查表 25',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 50,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark32',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件二：符合性审查表 26',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 51,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark33',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件三：评分标准 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark33',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '错误!未定义书签。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 52,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark35',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第五章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark35',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark35',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '合同条款及格式 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark35',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '31',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 53,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark37',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '第六章',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark37',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': ' ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark37',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'},
#                                   {'type': 'bold'}],
#                         'text': '投标文件格式 ',
#                         'type': 'text'},
#                        {'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark37',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '31',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 54,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark39',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 1 投标函 43',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 55,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark41',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 2 投标保证书 44',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 56,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark43',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 3 无违法记录声明 45',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 57,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark45',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 4 法定代表人授权书 46',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 58,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark47',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 5 投标人情况简介 47',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 59,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark49',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 48',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 60,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark51',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 7 投标一览表 49',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 61,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark53',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 8 分项报价表 50',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 62,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark55',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 9 投标方案 51',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 63,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark57',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 10 投标人资格声明 52',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 64,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark59',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 11 资格证明文件 53',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 65,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark61',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 12 与投标人存在“关系”的其他法人单位信息 54',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 66,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark63',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 13 投标人认为必要的其他证明文件 55',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 67,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark65',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 14 技术规格偏离表 56',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 68,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark67',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 15 商务条款偏离表 57',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 69,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark69',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 16 拟投入本项目的人员配备表 58',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 70,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark71',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 17 中标服务费承诺书 59',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 71,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark73',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 18 关于投标保证金的声明 60',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 72,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                              'href': '#bookmark75',
#                                              'rel': 'noopener noreferrer '
#                                                     'nofollow',
#                                              'target': '_blank'},
#                                    'type': 'link'}],
#                         'text': '附件 19 开标会声明书 61',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 73,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 74,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '第一章',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '招标公告',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 75,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#                                 '北京中外建工程管理有限公司受招标人委托，就',
#                         'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '北京京铁运恒采购',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '年端午节物资采购项目（第一包：一级压榨花生油）',
#                         'type': 'text'},
#                        {'text': '进行 国内公开招标采购，欢迎合格的投标人前来投标。', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 76,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '一、项目编号：DLXM-2024-148-01',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 77,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '二、', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '采购组织类型：',
#                         'type': 'text'},
#                        {'text': '委托代理', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 78,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '三、采购方式：',
#                         'type': 'text'},
#                        {'text': '公开招标', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 79,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '四、招标最高限价：1840',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '万元',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 80,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '五、采购内容、数量及简要技术要求',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 81,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 82,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '六',
#                         'type': 'text'},
#                        {'text': '、', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '合格投标人的资格要求(本项目采用资格后审)',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 84,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（1）在中华人民共和国境内注册的、具有独立承担民事责任的能力；',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 85,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（2）具有依法缴纳税收和社会保险的良好记录；', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 86,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（3）近三年内，在经营活动中没有重大违法记录；', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 87,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（4）单位负责人为同一人或者存在直接控股、管理关系的不同投标人，不得 '
#                                 '同时参加本项目的投标；',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 88,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（5）信用中国网站（www.creditchina.gov.cn）和中国政府采购网',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 89,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（www.ccgp.gov.cn）查询信用记录中（查询时间为招标公告发布后至投标截止时 '
#                                 '间期间），被列入失信被执行人、重大税收违法案件当事人名单或政府采购严重 '
#                                 '违法失信行为记录名单的投标人，不得参加本项目投标；',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 90,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（6）具有有效的《食品生产许可证》或《食品经营许可证》。若投标人为仅 '
#                                 '销售预包装食品的企业，须具有包含“食品经营（仅销售预包装食品）”的有效 '
#                                 '营业执照或仅销售预包装食品备案证明材料；',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 91,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（7）投标人财务状况正常，须提供会计师事务所出具的上一年度（2023年度） '
#                                 '财务审计报告，投标人尚未完成2023年度财务审计的须提供2022年度经审计的财',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 92,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 93,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '务报告；若投标人为2023年1月1日之后成立的公司，须提供财务状况说明；',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 94,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（8）法律、行政法规规定的其他条件；', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 95,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '（9）本项目不接受联合体投标。', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 96,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '七、招标公告的发布：',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 97,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '本项目招标公告同时在中国招标投标公共服务平台、国铁物资采购平台',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': 'https://',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': 'cg.95306.cn/上发布。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 98,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '八、招标文件的发售',
#                         'type': 'text'},
#                        {'text': '：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 99,
# ...
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '16',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '拟投入本项目的人员配备表',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 853,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 854,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 855,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '项目名称： 项目编号：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 856,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 857,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '注：本表后附拟投入主要管理人和主要技术人员的社保证明（近半年内任意一个月 '
#                                 '的证明材料）复印件加盖公章。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 859,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 860,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 861,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 862,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 863,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 864,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '投标人名称（公章）： 法定代表人或授权代表(签字或印章)：',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 865,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '日 期：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 866,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 867,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '附件',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '17',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '中标服务费承诺书',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 868,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 869,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 870,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 871,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 872,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 873,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 874,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '致：北京中外建工程管理有限公司：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 875,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 876,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 877,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 878,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '我们在贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节物资 '
#                                 '采购项目（第一包： 一级压榨花生油） 招标项目中若获中标（项目编号： '
#                                 'DLXM-2024-148-01），我们保证在签订经济合同的同时按招标文件的规定，以支 '
#                                 '票、汇票或现金， 向贵公司即北京中外建工程管理有限公司（地址：北京市丰台 区福宜街 5 '
#                                 '号院 1 号楼新时代国际中心 A 座 15 层，开户银行：中国民生银行股 '
#                                 '份有限公司北京丽泽商务区支行，账号：',
#                         'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '619201915',
#                         'type': 'text'},
#                        {'text': '），一次性支付应该缴纳的 中标服务费用。代理服务费支付按照招标文件中规定的标准执行。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 879,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 880,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 881,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 882,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '特此承诺！', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 883,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 884,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 885,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 886,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '承诺方法定名称（盖章）： 承诺方授权代表（签字）： 地址：',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 887,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '电话： 传真： 电传： 邮编： 承诺日期：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 888,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 889,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '附件',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '18',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '关于投标保证金的声明',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 890,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 891,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 892,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '致：北京中外建工程管理有限公司',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 893,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 894,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 895,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '我单位参与贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节 '
#                                 '物资采购项目（第一包：一级压榨花生油），项目编号 DLXM-2024-148-01。在 '
#                                 '招投标活动结束后，请将投标保证金退至我单位以下账户：',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 896,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '户 名： 开 户 行： 行 号： 账 号： 为此，我单位声明：',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 897,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '以上账户信息真实有效，如我单位相关信息在此期间内发生变更，我单位负 '
#                                 '责及时通知贵公司。如由于填写信息不实、内容不清晰、我单位信息变更而未及 '
#                                 '时告知贵公司等问题，引发的退还保证金延误等问题，后果由我单位自行承担。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 898,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 899,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 900,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '投标人名称（盖章）：', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 901,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 902,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 903,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '日期： 年 月 日', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 904,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 905,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 906,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 907,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '注：1.此笔款项为本次招标项目的投标保证金。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 908,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '2.本声明须加盖投标人公章或财务专用章，并请勿加盖在银行信息上。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 909,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '3.此声明需与投标文件一并递交（请勿装订在投标文件中，需单独密封）。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 910,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 911,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '附件',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '19',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '开标会声明书',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 912,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '关于北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '年端午节物资采购项目',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '（第一包：一级压榨花生油）开标会的声明书',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 913,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 914,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '致：北京中外建工程管理有限公司',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 915,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 916,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 917,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 918,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '本单位 （投标人名称） 关于北京京铁运恒采购供应站有限公司 2024 '
#                                 '年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： ',
#                         'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
#                        {'text': ' 年 ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '4',
#                         'type': 'text'},
#                        {'text': ' 月 ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '11',
#                         'type': 'text'},
#                        {'text': ' 日 ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '09',
#                         'type': 'text'},
#                        {'text': ' 时 ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '00',
#                         'type': 'text'},
#                        {'text': ' 分前通过 ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '快递',
#                         'type': 'text'},
#                        {'text': ' 方式（快递单号： ）递 '
#                                 '交至开标地点，如投标文件、样品及本声明书未在递交截止时间前送达指定地点 '
#                                 '的，我单位默认放弃本次投标，并承担由此产生的一切后果。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 919,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '本单位 （投标人名称） 不参加 北京京铁运恒采购供应站有限公司 2024 '
#                                 '年端午节物资采购项目（第一包：一级压榨花生油）现场开标活动，承诺 '
#                                 '认可开标过程以及由本项目招标人代为签署的一切过程文件。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 920,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '本单位以腾讯会议的方式参加北京京铁运恒采购供应站有限公司 2024 年端 '
#                                 '午节物资采购项目（第一包：一级压榨花生油）的开标活动，如因自身原因未能 '
#                                 '准时进入视频会场，我单位承诺认可本项目开标的全过程，并确认开标全部内容。',
#                         'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 921,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '特此声明！', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 922,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 923,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '投标人名称：（公章）', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 924,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 925,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'text': '法定代表人或被授权代表(签字或盖章)： 年 月 日', 'type': 'text'}],
#            'type': 'paragraph'},
#   'position': 926,
#   'type': 'paragraph'}]

# %% [markdown]
# #### 验证 extract_indexed_paragraphs

# %%
from app.clients.tiptap.tools import get_paragraph_text_with_position
paragraphs = get_paragraph_text_with_position(raw_document)
print(len(paragraphs))
from pprint import pprint
pprint(paragraphs)
# Out:
# 903
# [{'content': '', 'position': 0, 'type': 'paragraph'},
#  {'content': '', 'position': 1, 'type': 'paragraph'},
#  {'content': '', 'position': 2, 'type': 'paragraph'},
#  {'content': '', 'position': 3, 'type': 'paragraph'},
#  {'content': '', 'position': 4, 'type': 'paragraph'},
#  {'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#   'position': 5,
#   'type': 'paragraph'},
#  {'content': '', 'position': 6, 'type': 'paragraph'},
#  {'content': '', 'position': 7, 'type': 'paragraph'},
#  {'content': '', 'position': 8, 'type': 'paragraph'},
#  {'content': '', 'position': 9, 'type': 'paragraph'},
#  {'content': '', 'position': 10, 'type': 'paragraph'},
#  {'content': '', 'position': 11, 'type': 'paragraph'},
#  {'content': '', 'position': 12, 'type': 'paragraph'},
#  {'content': '招标文件', 'position': 13, 'type': 'paragraph'},
#  {'content': '', 'position': 14, 'type': 'paragraph'},
#  {'content': '', 'position': 15, 'type': 'paragraph'},
#  {'content': '', 'position': 16, 'type': 'paragraph'},
#  {'content': '', 'position': 17, 'type': 'paragraph'},
#  {'content': '', 'position': 18, 'type': 'paragraph'},
#  {'content': '', 'position': 19, 'type': 'paragraph'},
#  {'content': '', 'position': 20, 'type': 'paragraph'},
#  {'content': '项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油）',
#   'position': 21,
#   'type': 'paragraph'},
#  {'content': '项目编号：DLXM-2024-148-01', 'position': 22, 'type': 'paragraph'},
#  {'content': '招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司',
#   'position': 23,
#   'type': 'paragraph'},
#  {'content': '', 'position': 24, 'type': 'paragraph'},
#  {'content': '', 'position': 25, 'type': 'paragraph'},
#  {'content': '', 'position': 26, 'type': 'paragraph'},
#  {'content': '', 'position': 27, 'type': 'paragraph'},
#  {'content': '', 'position': 28, 'type': 'paragraph'},
#  {'content': '', 'position': 29, 'type': 'paragraph'},
#  {'content': '', 'position': 30, 'type': 'paragraph'},
#  {'content': '2024 年 3 月', 'position': 31, 'type': 'paragraph'},
#  {'content': '', 'position': 32, 'type': 'paragraph'},
#  {'content': '目 录', 'position': 33, 'type': 'paragraph'},
#  {'content': '', 'position': 34, 'type': 'paragraph'},
#  {'content': '', 'position': 35, 'type': 'paragraph'},
#  {'content': '第一章 招标公告 2', 'position': 36, 'type': 'paragraph'},
#  {'content': '第二章 招标需求 5', 'position': 37, 'type': 'paragraph'},
#  {'content': '第三章 投标人须知 8', 'position': 38, 'type': 'paragraph'},
#  {'content': '前附表 8', 'position': 39, 'type': 'paragraph'},
#  {'content': '一、总则 12', 'position': 40, 'type': 'paragraph'},
#  {'content': '二、招标文件 13', 'position': 41, 'type': 'paragraph'},
#  {'content': '三、投标文件的编制 14', 'position': 42, 'type': 'paragraph'},
#  {'content': '四、开标 18', 'position': 43, 'type': 'paragraph'},
#  {'content': '五、评标 19', 'position': 44, 'type': 'paragraph'},
#  {'content': '六、定标 21', 'position': 45, 'type': 'paragraph'},
#  {'content': '七、合同授予 21', 'position': 46, 'type': 'paragraph'},
#  {'content': '八、履约保证金 21', 'position': 47, 'type': 'paragraph'},
#  {'content': '九、招标代理服务费的收取 21', 'position': 48, 'type': 'paragraph'},
#  {'content': '第四章 评标办法及评分标准 22', 'position': 49, 'type': 'paragraph'},
#  {'content': '附件一：资格审查表 25', 'position': 50, 'type': 'paragraph'},
#  {'content': '附件二：符合性审查表 26', 'position': 51, 'type': 'paragraph'},
#  {'content': '附件三：评分标准 错误!未定义书签。', 'position': 52, 'type': 'paragraph'},
#  {'content': '第五章 合同条款及格式 31', 'position': 53, 'type': 'paragraph'},
#  {'content': '第六章 投标文件格式 31', 'position': 54, 'type': 'paragraph'},
#  {'content': '附件 1 投标函 43', 'position': 55, 'type': 'paragraph'},
#  {'content': '附件 2 投标保证书 44', 'position': 56, 'type': 'paragraph'},
#  {'content': '附件 3 无违法记录声明 45', 'position': 57, 'type': 'paragraph'},
#  {'content': '附件 4 法定代表人授权书 46', 'position': 58, 'type': 'paragraph'},
#  {'content': '附件 5 投标人情况简介 47', 'position': 59, 'type': 'paragraph'},
#  {'content': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 48',
#   'position': 60,
#   'type': 'paragraph'},
#  {'content': '附件 7 投标一览表 49', 'position': 61, 'type': 'paragraph'},
#  {'content': '附件 8 分项报价表 50', 'position': 62, 'type': 'paragraph'},
#  {'content': '附件 9 投标方案 51', 'position': 63, 'type': 'paragraph'},
#  {'content': '附件 10 投标人资格声明 52', 'position': 64, 'type': 'paragraph'},
#  {'content': '附件 11 资格证明文件 53', 'position': 65, 'type': 'paragraph'},
#  {'content': '附件 12 与投标人存在“关系”的其他法人单位信息 54',
#   'position': 66,
#   'type': 'paragraph'},
#  {'content': '附件 13 投标人认为必要的其他证明文件 55', 'position': 67, 'type': 'paragraph'},
#  {'content': '附件 14 技术规格偏离表 56', 'position': 68, 'type': 'paragraph'},
#  {'content': '附件 15 商务条款偏离表 57', 'position': 69, 'type': 'paragraph'},
#  {'content': '附件 16 拟投入本项目的人员配备表 58', 'position': 70, 'type': 'paragraph'},
#  {'content': '附件 17 中标服务费承诺书 59', 'position': 71, 'type': 'paragraph'},
#  {'content': '附件 18 关于投标保证金的声明 60', 'position': 72, 'type': 'paragraph'},
#  {'content': '附件 19 开标会声明书 61', 'position': 73, 'type': 'paragraph'},
#  {'content': '', 'position': 74, 'type': 'paragraph'},
#  {'content': '第一章 招标公告', 'position': 75, 'type': 'paragraph'},
#  {'content': '根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#              '北京中外建工程管理有限公司受招标人委托，就北京京铁运恒采购 供应站有限公司 2024 '
#              '年端午节物资采购项目（第一包：一级压榨花生油）进行 国内公开招标采购，欢迎合格的投标人前来投标。',
#   'position': 76,
#   'type': 'paragraph'},
#  {'content': '一、项目编号：DLXM-2024-148-01', 'position': 77, 'type': 'paragraph'},
#  {'content': '二、采购组织类型：委托代理', 'position': 78, 'type': 'paragraph'},
#  {'content': '三、采购方式：公开招标', 'position': 79, 'type': 'paragraph'},
#  {'content': '四、招标最高限价：1840 万元', 'position': 80, 'type': 'paragraph'},
#  {'content': '五、采购内容、数量及简要技术要求', 'position': 81, 'type': 'paragraph'},
#  {'content': '', 'position': 82, 'type': 'paragraph'},
#  {'content': '六、合格投标人的资格要求(本项目采用资格后审)', 'position': 84, 'type': 'paragraph'},
#  {'content': '（1）在中华人民共和国境内注册的、具有独立承担民事责任的能力；',
#   'position': 85,
#   'type': 'paragraph'},
#  {'content': '（2）具有依法缴纳税收和社会保险的良好记录；', 'position': 86, 'type': 'paragraph'},
#  {'content': '（3）近三年内，在经营活动中没有重大违法记录；', 'position': 87, 'type': 'paragraph'},
#  {'content': '（4）单位负责人为同一人或者存在直接控股、管理关系的不同投标人，不得 同时参加本项目的投标；',
#   'position': 88,
#   'type': 'paragraph'},
#  {'content': '（5）信用中国网站（www.creditchina.gov.cn）和中国政府采购网',
#   'position': 89,
#   'type': 'paragraph'},
#  {'content': '（www.ccgp.gov.cn）查询信用记录中（查询时间为招标公告发布后至投标截止时 '
#              '间期间），被列入失信被执行人、重大税收违法案件当事人名单或政府采购严重 违法失信行为记录名单的投标人，不得参加本项目投标；',
#   'position': 90,
#   'type': 'paragraph'},
#  {'content': '（6）具有有效的《食品生产许可证》或《食品经营许可证》。若投标人为仅 '
#              '销售预包装食品的企业，须具有包含“食品经营（仅销售预包装食品）”的有效 营业执照或仅销售预包装食品备案证明材料；',
#   'position': 91,
#   'type': 'paragraph'},
#  {'content': '（7）投标人财务状况正常，须提供会计师事务所出具的上一年度（2023年度） '
#              '财务审计报告，投标人尚未完成2023年度财务审计的须提供2022年度经审计的财',
#   'position': 92,
#   'type': 'paragraph'},
#  {'content': '', 'position': 93, 'type': 'paragraph'},
#  {'content': '务报告；若投标人为2023年1月1日之后成立的公司，须提供财务状况说明；',
#   'position': 94,
#   'type': 'paragraph'},
#  {'content': '（8）法律、行政法规规定的其他条件；', 'position': 95, 'type': 'paragraph'},
#  {'content': '（9）本项目不接受联合体投标。', 'position': 96, 'type': 'paragraph'},
#  {'content': '七、招标公告的发布：', 'position': 97, 'type': 'paragraph'},
#  {'content': '本项目招标公告同时在中国招标投标公共服务平台、国铁物资采购平台 https:// cg.95306.cn/上发布。',
#   'position': 98,
#   'type': 'paragraph'},
#  {'content': '八、招标文件的发售：', 'position': 99, 'type': 'paragraph'},
#  {'content': '1.发售时间：2024 年 3 月 22 日至 2024 年 3 月 26 日，上午 9:00-11:00；下 午 '
#              '1:30-4:30 （北京时间）。',
#   'position': 100,
#   'type': 'paragraph'},
#  {'content': '2.发售地点：北京中外建工程管理有限公司（地址： 北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 15 层）。',
#   'position': 101,
#   'type': 'paragraph'},
#  {'content': '3.招标文件售价：人民币 500 元/包，招标文件售后不退。请投标人以电汇或 '
#              '网上银行转账方式购买招标文件，无需到现场购买，汇款后请将以下资料的扫描 '
#              '件发至招标代理机构指定邮箱（782144725@qq.com）：①汇款底单，②经办人的 '
#              '法定代表人授权委托书原件（加盖公章和法人章或法人签字），③经办人身份证 '
#              '复印件加盖公章。投标人将上述资料发至指定邮箱后电话联系采购代理机构填写 '
#              '相关表格并获取电子版招标文件。汇款附言栏内请写明汇款用途及本项目项目编 号。购买招标文件汇款账号：',
#   'position': 102,
#   'type': 'paragraph'},
#  {'content': '账户名称：北京中外建工程管理有限公司', 'position': 103, 'type': 'paragraph'},
#  {'content': '开户行：中国民生银行股份有限公司北京丽泽商务区支行 账 号：619201915',
#   'position': 104,
#   'type': 'paragraph'},
#  {'content': '4.凡有意参加投标者，请投标人登录 https:// cg.95306.cn/网站，按要求 '
#              '和提示填写企业相关信息,完成注册并通过初审 (相关注册事宜可拨打 电话 010-51864501、010-51864508 '
#              '咨询，联系人：石先生、赵女士)。',
#   'position': 105,
#   'type': 'paragraph'},
#  {'content': '5.招标文件发售联系人和联系电话： 江女士、王女士、魏先生，电话： '
#              '010-83928607、010-83928608、13071152980。',
#   'position': 106,
#   'type': 'paragraph'},
#  {'content': '九、投标保证金：', 'position': 107, 'type': 'paragraph'},
#  {'content': '投标保证金金额：人民币贰拾万元整(¥200000）', 'position': 108, 'type': 'paragraph'},
#  {'content': '投标人应于 2024 年 4 月 11 日 09 时 00 分前将投标保证金以银行汇票（电汇）、 '
#              '支票等非现金形式交至北京中外建工程管理有限公司。',
#   'position': 109,
#   'type': 'paragraph'},
#  {'content': '', 'position': 110, 'type': 'paragraph'},
#  {'content': '十、投标截止时间和地点：', 'position': 111, 'type': 'paragraph'},
#  {'content': '本项目投标文件采用邮寄方式或现场递交，如采用邮寄方式具体要求如下： '
#              '1.邮寄时间要求：请投标人采用正规快递货运公司（建议使用顺丰快递）邮寄 '
#              '递交投标文件（不接受无邮寄单据的非正规闪送），并请于投标截止时间（2024 年 4 月 11 日 09 时 00 '
#              '分）之前将投标文件邮寄到以下地点（北京市丰台区福宜 街 5 号院 1 号楼新时代国际中心 A 座 15 '
#              '层（北京中外建工程管理有限公司)），',
#   'position': 112,
#   'type': 'paragraph'},
#  {'content': '逾期送达或未按规定邮寄的投标文件恕不接受。 2.投标文件邮寄包装及标记要求：',
#   'position': 113,
#   'type': 'paragraph'},
#  {'content': '（ 2 ） 投 标 文 件 寄 出 后 ， 请 立 即 将 邮 寄 内 容 及 邮 寄 单 号 发 送 至 '
#              '782144725@qq.com 。邮件标题格式须为“XXXX（投标人全称）DLXM-2024-148-01 '
#              '邮寄单号”，并电话通知项目负责人：江女士、王女士、魏先生，电话：010-83928607、 '
#              '010-83928608、13071152980。',
#   'position': 114,
#   'type': 'paragraph'},
#  {'content': '十一、开标时间及地点：', 'position': 115, 'type': 'paragraph'},
#  {'content': '开标时间：本次招标将于 2024 年 4 月 11 日 09 时 00 分（北京时间）',
#   'position': 116,
#   'type': 'paragraph'},
#  {'content': '开标地点：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 14 层 开标形式：本项目将采用线上方式组织开标。',
#   'position': 117,
#   'type': 'paragraph'},
#  {'content': '十二、评标办法：综合评分法。', 'position': 118, 'type': 'paragraph'},
#  {'content': '十三、业务咨询', 'position': 119, 'type': 'paragraph'},
#  {'content': '招标人：北京京铁运恒采购供应站有限公司', 'position': 120, 'type': 'paragraph'},
#  {'content': '地址：北京市丰台区北京西站东附楼瑞尔威写字楼 A1 座 A706 室',
#   'position': 121,
#   'type': 'paragraph'},
#  {'content': '联系方式：石先生 010-51864501', 'position': 122, 'type': 'paragraph'},
#  {'content': '招标代理机构：北京中外建工程管理有限公司', 'position': 123, 'type': 'paragraph'},
#  {'content': '地址：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 15 层',
#   'position': 124,
#   'type': 'paragraph'},
#  {'content': '联系人：江女士、王女士、魏先生', 'position': 125, 'type': 'paragraph'},
#  {'content': '联系电话：010-83928607、010-83928608、13071152980 '
#              'E-mail：782144725@qq.com',
#   'position': 126,
#   'type': 'paragraph'},
#  {'content': '', 'position': 127, 'type': 'paragraph'},
#  {'content': '', 'position': 128, 'type': 'paragraph'},
#  {'content': '第二章 招标需求', 'position': 129, 'type': 'paragraph'},
#  {'content': '一、概述', 'position': 130, 'type': 'paragraph'},
#  {'content': '1.本招标项目是针对北京京铁运恒采购供应站有限公司所需货物的采购、供应、 运输、验收及售后服务进行的招标。',
#   'position': 131,
#   'type': 'paragraph'},
#  {'content': '2.本项目的组织及解释权归招标人。', 'position': 132, 'type': 'paragraph'},
#  {'content': '3.招标文件中的技术要求是基本质量要求，投标人应根据自己的投标方案综合考 虑详细的技术指标，但不得低于招标基本质量要求。',
#   'position': 133,
#   'type': 'paragraph'},
#  {'content': '4.投标人供应的产品，需符合国家《中华人民共和国产品质量法》、《中华人民 '
#              '共和国食品安全法》等相关法律规定的要求，符合卫生防疫部门、检验检疫部门 '
#              '的各项合格指标，并有完整的销售合格标注或证书,所有的产品可追溯供货源头， '
#              '在行业标准、国家标准等各项标准不一致时应以要求高的标准为准。',
#   'position': 134,
#   'type': 'paragraph'},
#  {'content': '5.投标人提供的所有货物都应具有合格证及质量检测报告。',
#   'position': 135,
#   'type': 'paragraph'},
#  {'content': '', 'position': 136, 'type': 'paragraph'},
#  {'content': '二、采购内容', 'position': 137, 'type': 'paragraph'},
#  {'content': '', 'position': 138, 'type': 'paragraph'},
#  {'content': '三、技术和质量要求 1.质量要求', 'position': 140, 'type': 'paragraph'},
#  {'content': '花生油质量不低于《花生油》(GB/T1534-2017)压榨成品花生油一级要求，指 标达到 '
#              'GB2716-2018、GB2760-2014 国家有关规定标准，清晰无浑浊、无异味、无 '
#              '污染、无变质，剩余保质期不少于产品保质期的三分之二。外包装完好，密封性 良好，采用 PET 材质，5L/桶，有 SC '
#              '标志，标明品名、品牌、生产厂家、净含量、 生产日期、保质期、批号、执行标准、具有产品合格证。品牌商标必须带有 R 标 志。',
#   'position': 141,
#   'type': 'paragraph'},
#  {'content': '2.花生油主要技术参数', 'position': 142, 'type': 'paragraph'},
#  {'content': '', 'position': 143, 'type': 'paragraph'},
#  {'content': '', 'position': 145, 'type': 'paragraph'},
#  {'content': '', 'position': 146, 'type': 'paragraph'},
#  {'content': '', 'position': 147, 'type': 'paragraph'},
#  {'content': '合同有效期内，如遇国家有关标准调整，则按新标准执行。',
#   'position': 149,
#   'type': 'paragraph'},
#  {'content': '*3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 法》的规定。',
#   'position': 150,
#   'type': 'paragraph'},
#  {'content': '4.样品', 'position': 151, 'type': 'paragraph'},
#  {'content': '4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。',
#   'position': 152,
#   'type': 'paragraph'},
#  {'content': '4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 的样品规格不符合招标文件的，样品评分部分不得分。',
#   'position': 153,
#   'type': 'paragraph'},
#  {'content': '4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#              '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 应的质量要求或技术参数不一致，责令中标人在 24 '
#              '小时内重新提供与要求相符的 货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。',
#   'position': 154,
#   'type': 'paragraph'},
#  {'content': '4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 字体清晰，粘贴牢固。',
#   'position': 155,
#   'type': 'paragraph'},
#  {'content': '4.5 样品应与投标文件同时递交到指定地点（样品不退还）。',
#   'position': 156,
#   'type': 'paragraph'},
#  {'content': '*5. 送达地点', 'position': 157, 'type': 'paragraph'},
#  {'content': '按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#              '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。',
#   'position': 158,
#   'type': 'paragraph'},
#  {'content': '*6. 交货时间', 'position': 159, 'type': 'paragraph'},
#  {'content': '中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 标人送货计划通知为准。',
#   'position': 160,
#   'type': 'paragraph'},
#  {'content': '', 'position': 161, 'type': 'paragraph'},
#  {'content': '四、履约保证金', 'position': 162, 'type': 'paragraph'},
#  {'content': '1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 保证金。',
#   'position': 163,
#   'type': 'paragraph'},
#  {'content': '2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#              '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 性退回中标人。',
#   'position': 164,
#   'type': 'paragraph'},
#  {'content': '', 'position': 165, 'type': 'paragraph'},
#  {'content': '第三章 投标人须知', 'position': 166, 'type': 'paragraph'},
#  {'content': '前附表', 'position': 167, 'type': 'paragraph'},
#  {'content': '', 'position': 168, 'type': 'paragraph'},
#  {'content': '', 'position': 170, 'type': 'paragraph'},
#  {'content': '', 'position': 171, 'type': 'paragraph'},
#  {'content': '', 'position': 172, 'type': 'paragraph'},
#  {'content': '', 'position': 174, 'type': 'paragraph'},
#  {'content': '', 'position': 175, 'type': 'paragraph'},
#  {'content': '', 'position': 176, 'type': 'paragraph'},
#  {'content': '', 'position': 178, 'type': 'paragraph'},
#  {'content': '', 'position': 179, 'type': 'paragraph'},
#  {'content': '', 'position': 180, 'type': 'paragraph'},
#  {'content': '', 'position': 182, 'type': 'paragraph'},
#  {'content': '', 'position': 183, 'type': 'paragraph'},
#  {'content': '一、总则', 'position': 184, 'type': 'paragraph'},
#  {'content': '（一）适用范围', 'position': 185, 'type': 'paragraph'},
#  {'content': '本招标文件适用于北京京铁运恒采购供应站有限公司 2024 年端午节物资采 '
#              '购项目的招标、投标、评标、定标、验收、合同履约、付款等行为（法律、法规 另有规定的，从其规定）。',
#   'position': 186,
#   'type': 'paragraph'},
#  {'content': '（二） 定义', 'position': 187, 'type': 'paragraph'},
#  {'content': '1.“招标人”系指组织本次招标的代理机构和采购单位。 2.“投标人”系指向招标人提交投标文件的单位。',
#   'position': 188,
#   'type': 'paragraph'},
#  {'content': '3.“货物”系指供方按招标文件规定，须向招标人提供的一切货物、保险、 税金、手册及其它有关技术资料和材料。',
#   'position': 189,
#   'type': 'paragraph'},
#  {'content': '4.“服务”系指招标文件规定投标人须承担的培训、技术指导以及其他类似 的义务。',
#   'position': 190,
#   'type': 'paragraph'},
#  {'content': '5.“项目”系指投标人按招标文件规定向招标人提供的货物和服务。 6.“书面形式”包括信函、传真、电报等。',
#   'position': 191,
#   'type': 'paragraph'},
#  {'content': '7.“*”系指实质性要求条款。', 'position': 192, 'type': 'paragraph'},
#  {'content': '（三） 招标方式', 'position': 193, 'type': 'paragraph'},
#  {'content': '本次招标采用公开招标方式进行。', 'position': 194, 'type': 'paragraph'},
#  {'content': '（四）投标委托', 'position': 195, 'type': 'paragraph'},
#  {'content': '投标人代表须携带有效身份证件。如投标人代表不是法定代表人，须有法定 代表人出具的授权委托书（格式见第六章）。',
#   'position': 196,
#   'type': 'paragraph'},
#  {'content': '（五） 踏勘现场（本项目不适用）和投标费用', 'position': 197, 'type': 'paragraph'},
#  {'content': '1．投标人可以对现场及周围环境进行踏勘，以便获取有关编制投标文件和签 '
#              '署合同所涉及现场的资料。投标人应承担踏勘现场所发生的自身费用。',
#   'position': 198,
#   'type': 'paragraph'},
#  {'content': '2．招标人向投标人提供的有关现场的数据和资料，是招标人现有的能被投标 '
#              '人利用的资料，招标人对投标人做出的任何推论、理解和结论不负责任。',
#   'position': 199,
#   'type': 'paragraph'},
#  {'content': '3．经招标人允许，投标人可为踏勘目的进入招标人的项目现场，但投标人不 '
#              '得因此使招标人承担有关的责任和蒙受损失。投标人应承担踏勘现场的责任和风 险。',
#   'position': 200,
#   'type': 'paragraph'},
#  {'content': '4．无论投标结果如何，投标人自行承担其所有与参加投标有关的全部费用。 投标文件一律不退还。',
#   'position': 201,
#   'type': 'paragraph'},
#  {'content': '', 'position': 202, 'type': 'paragraph'},
#  {'content': '5. 如因不可抗力因素或招标人采购计划调整，导致本项目招标采购活动无法 开展，投标人须自行承担其所有与参加投标有关的全部费用。',
#   'position': 203,
#   'type': 'paragraph'},
#  {'content': '（六） 联合体投标', 'position': 204, 'type': 'paragraph'},
#  {'content': '本项目不接受联合体投标。', 'position': 205, 'type': 'paragraph'},
#  {'content': '（七）转包', 'position': 206, 'type': 'paragraph'},
#  {'content': '本项目不允许转包、分包。', 'position': 207, 'type': 'paragraph'},
#  {'content': '（八）、特别说明：', 'position': 208, 'type': 'paragraph'},
#  {'content': '*1.投标人应仔细阅读招标文件的所有内容，按照招标文件的要求提交投标文 件，并对所提供的全部资料的真实性承担法律责任。',
#   'position': 209,
#   'type': 'paragraph'},
#  {'content': '*2. 投标人以他人名义投标或者以其他方式弄虚作假，骗取中标的，中标无 '
#              '效；给招标人造成损失的，依法承担赔偿责任；构成犯罪的，依法追究刑事责任。',
#   'position': 210,
#   'type': 'paragraph'},
#  {'content': '（九） 质疑和投诉', 'position': 211, 'type': 'paragraph'},
#  {'content': '1. 投标人或者其他利害关系人认为招标投标活动不符合法律、行政法规规定 的，可以自知道或者应当知道之日起 10 '
#              '日内向有关行政监督部门投诉。投诉应当 有明确的请求和必要的证明材料。',
#   'position': 212,
#   'type': 'paragraph'},
#  {'content': '2.异议、投诉应当采用书面形式，异议、投诉书均应明确阐述招标投标活动 '
#              '中使自己合法权益受到损害的实质性内容，提供相关事实、依据和证据及其来源 或线索，便于有关单位调查、答复和处理。',
#   'position': 213,
#   'type': 'paragraph'},
#  {'content': '二、招标文件', 'position': 214, 'type': 'paragraph'},
#  {'content': '（一）招标文件的构成。本招标文件由以下部分组成：', 'position': 215, 'type': 'paragraph'},
#  {'content': '1.招标公告', 'position': 216, 'type': 'paragraph'},
#  {'content': '2.招标需求', 'position': 217, 'type': 'paragraph'},
#  {'content': '3.投标人须知', 'position': 218, 'type': 'paragraph'},
#  {'content': '4.评标办法及评分标准 5.合同条款', 'position': 219, 'type': 'paragraph'},
#  {'content': '6.投标文件格式', 'position': 220, 'type': 'paragraph'},
#  {'content': '7.本项目招标文件的澄清、答复、修改、补充的内容', 'position': 221, 'type': 'paragraph'},
#  {'content': '（二） 投标人的风险', 'position': 222, 'type': 'paragraph'},
#  {'content': '投标人未按照招标文件要求提供全部资料，或者投标人未对招标文件在各方 '
#              '面作出实质性响应是投标人的风险，并可能导致其投标被拒绝或无效。',
#   'position': 223,
#   'type': 'paragraph'},
#  {'content': '', 'position': 224, 'type': 'paragraph'},
#  {'content': '（三） 招标文件的澄清与修改', 'position': 225, 'type': 'paragraph'},
#  {'content': '1.投标人应认真阅读本招标文件，发现其中有误或有不合理要求的，投标人 '
#              '须在递交投标文件截止时间十日前以书面形式提出异议。招标代理机构对已发出 '
#              '的招标文件进行必要澄清、答复、修改或补充的，应当在招标文件要求提交投标 '
#              '文件截止时间十五日前，在指定的信息发布媒体上发布更正公告，并以书面形式 '
#              '通知所有招标文件收受人（若为潜在投标人原因而导致通知无法送达，由此造成 的后果由潜在投标人负责）。',
#   'position': 226,
#   'type': 'paragraph'},
#  {'content': '2.招标文件澄清、答复、修改、补充的内容为招标文件的组成部分。当招标 '
#              '文件与招标文件的答复、澄清、修改、补充通知就同一内容的表述不一致时，以 最后发出的书面文件为准。',
#   'position': 227,
#   'type': 'paragraph'},
#  {'content': '3.招标文件的澄清、答复、修改或补充都应该通过招标代理机构以法定形式 发布。',
#   'position': 228,
#   'type': 'paragraph'},
#  {'content': '（四）、对招标文件的异议', 'position': 229, 'type': 'paragraph'},
#  {'content': '购买招标文件的潜在投标人对招标文件有异议，应在投标截止时间十日前书 '
#              '面提出。逾期提出的将不予受理。对招标文件的异议应有法定代表人或其委托代 理人签字，并盖投标人公章和注明日期。',
#   'position': 230,
#   'type': 'paragraph'},
#  {'content': '三、投标文件的编制', 'position': 231, 'type': 'paragraph'},
#  {'content': '（一）、投标文件的组成', 'position': 232, 'type': 'paragraph'},
#  {'content': '1. 投标人应完整地按招标文件要求的投标文件格式编写投标文件，投标文 件应包含但不限于以下内容：',
#   'position': 233,
#   'type': 'paragraph'},
#  {'content': '（1）投标函；', 'position': 234, 'type': 'paragraph'},
#  {'content': '（2）投标保证书；', 'position': 235, 'type': 'paragraph'},
#  {'content': '（3）无违法记录声明；', 'position': 236, 'type': 'paragraph'},
#  {'content': '（4）法定代表人授权书；', 'position': 237, 'type': 'paragraph'},
#  {'content': '①投标人代表若为法定代表人的，投标文件中须提供法定代表人身份证 复印件加盖公章；',
#   'position': 238,
#   'type': 'paragraph'},
#  {'content': '②投标人代表若为非法定代表人的，投标文件中须提交法定代表人授权 书原件、法定代表人身份证复印件及被授权代表的身份证复印件加盖公 '
#              '章；',
#   'position': 239,
#   'type': 'paragraph'},
#  {'content': '（5）投标人情况简介；', 'position': 240, 'type': 'paragraph'},
#  {'content': '', 'position': 241, 'type': 'paragraph'},
#  {'content': '（6）投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表；',
#   'position': 242,
#   'type': 'paragraph'},
#  {'content': '（7）投标一览表；', 'position': 243, 'type': 'paragraph'},
#  {'content': '（8）分项报价表；', 'position': 244, 'type': 'paragraph'},
#  {'content': '（9）投标方案；', 'position': 245, 'type': 'paragraph'},
#  {'content': '（10）投标人资格声明；', 'position': 246, 'type': 'paragraph'},
#  {'content': '（11）资格证明文件：', 'position': 247, 'type': 'paragraph'},
#  {'content': '（11.1）投标人的营业执照副本复印件（加盖公章）；',
#   'position': 248,
#   'type': 'paragraph'},
#  {'content': '（11.2）投标人近半年内任意一个月的缴纳税收记录和缴纳社会保障记 录证明文件（复印件并加盖公章）；',
#   'position': 249,
#   'type': 'paragraph'},
#  {'content': '（11.3）参加本项目招标活动近三年内，在经营活动中没有重大违法记 录声明；',
#   'position': 250,
#   'type': 'paragraph'},
#  {'content': '（11.4）投标人须提供在信用中国网站（www.creditchina.gov.cn）和中 '
#              '国政府采购网（www.ccgp.gov.cn）的信用查询记录网页截图（查 询时间为招标公告发布后至投标截止时间期间）；',
#   'position': 251,
#   'type': 'paragraph'},
#  {'content': '（11.5）投标人有效的《食品生产许可证》或《食品经营许可证》复印 件加盖公章，若投标人为仅销售预包装食品的企业，须具有包 '
#              '含“食品经营（仅销售预包装食品）”的有效营业执照或仅销 售预包装食品备案证明材料并加盖公章；',
#   'position': 252,
#   'type': 'paragraph'},
#  {'content': '（11.6）会计师事务所出具的上一年度（2023 年度）财务审计报告复印 件加盖公章，投标人尚未完成 2023 '
#              '年度财务审计的须提供 2022 年度经审计的财务报告复印件并加盖公章；若投标人为 2023 年 1 月 1 '
#              '日之后成立的公司，须提供财务状况说明并加盖公章；',
#   'position': 253,
#   'type': 'paragraph'},
#  {'content': '（12）与投标人存在“单位负责人为同一人或者存在直接控股、管理关系” 的其他法人单位信息；',
#   'position': 254,
#   'type': 'paragraph'},
#  {'content': '（13） 投标人认为必要的其他证明文件（包括但不限于：质量管理体系认 证、荣誉证书等）；',
#   'position': 255,
#   'type': 'paragraph'},
#  {'content': '（14）技术规格偏离表；', 'position': 256, 'type': 'paragraph'},
#  {'content': '（15）商务条款偏离表；', 'position': 257, 'type': 'paragraph'},
#  {'content': '（16）拟投入本项目的人员配备表；', 'position': 258, 'type': 'paragraph'},
#  {'content': '（17）中标服务费承诺书；', 'position': 259, 'type': 'paragraph'},
#  {'content': '', 'position': 260, 'type': 'paragraph'},
#  {'content': '（18）关于投标保证金的声明；', 'position': 261, 'type': 'paragraph'},
#  {'content': '（19）开标会声明书。', 'position': 262, 'type': 'paragraph'},
#  {'content': '2.上述组成投标文件的各项资料中本招标文件有规定格式的，应统一按本招 '
#              '标文件的规定格式填写。未有规定格式的资料，投标人应自行编制，但至少要包 含以上要求的内容。',
#   'position': 263,
#   'type': 'paragraph'},
#  {'content': '3.投标文件在对投标产品技术规格偏离表的应答时，对招标文件有技术数值 '
#              '要求的参数，必须以投标货物的具体技术数值据实应答；对于招标文件无数值要 '
#              '求的参数的应答，必须作出明确、直接、无导致两种理解可能的应答。',
#   'position': 264,
#   'type': 'paragraph'},
#  {'content': '（二）、投标文件的语言及计量', 'position': 265, 'type': 'paragraph'},
#  {'content': '*1.除专用术语外，投标文件及来往函电均应使用中文书写。必要时专用术语 '
#              '应附有中文解释。投标人提交的支持资料和已印制的文献可以用外文，但相应内 '
#              '容应附有中文翻译本，在解释投标文件时以中文翻译本为准。未附中文翻译本或 '
#              '翻译本中文内容明显与外文内容不一致的，其不利后果由投标人自行承担。',
#   'position': 266,
#   'type': 'paragraph'},
#  {'content': '*2.除招标文件有特殊要求外，本项目投标所使用的计量单位，应采用中华人 民共和国法定计量单位。',
#   'position': 267,
#   'type': 'paragraph'},
#  {'content': '（三）、投标报价', 'position': 268, 'type': 'paragraph'},
#  {'content': '投标报价应按招标文件中相关附表格式填写。', 'position': 269, 'type': 'paragraph'},
#  {'content': '（四）、投标文件的有效期', 'position': 270, 'type': 'paragraph'},
#  {'content': '*1. 自投标截止日起 90 天投标文件应保持有效。投标有效期少于招标文件规 定期限的，其投标无效。',
#   'position': 271,
#   'type': 'paragraph'},
#  {'content': '2.在特殊情况下，招标人可与投标人协商延长投标文件的有效期。',
#   'position': 272,
#   'type': 'paragraph'},
#  {'content': '3.投标人可拒绝接受延期要求而不会导致投标保证金被没收。同意延长有效 '
#              '期的投标人需要相应延长投标保证金的有效期，但不能修改投标文件。',
#   'position': 273,
#   'type': 'paragraph'},
#  {'content': '4.中标人的投标文件自开标之日起至合同履行完毕止均应保持有效。',
#   'position': 274,
#   'type': 'paragraph'},
#  {'content': '（五）、投标保证金', 'position': 275, 'type': 'paragraph'},
#  {'content': '*1.投标人须按规定提交投标保证金。否则，其投标无效。',
#   'position': 276,
#   'type': 'paragraph'},
#  {'content': '2.保证金形式：网银、银行汇票（电汇）、支票等非现金形式。',
#   'position': 277,
#   'type': 'paragraph'},
#  {'content': '3.投标保证金退还：详见第三章投标须知。', 'position': 278, 'type': 'paragraph'},
#  {'content': '4.保证金利息按中国人民银行同期利率计算。', 'position': 279, 'type': 'paragraph'},
#  {'content': '5.投标人有下列情形之一的，投标保证金将不予退还：', 'position': 280, 'type': 'paragraph'},
#  {'content': '', 'position': 281, 'type': 'paragraph'},
#  {'content': '（1）投标截止后投标人撤销投标文件的；', 'position': 282, 'type': 'paragraph'},
#  {'content': '（2）中标人无正当理由不与招标人订立合同的；', 'position': 283, 'type': 'paragraph'},
#  {'content': '（3）在签订合同时向招标人提出附加条件的；', 'position': 284, 'type': 'paragraph'},
#  {'content': '（4）不按照招标文件要求提交履约保证金的；', 'position': 285, 'type': 'paragraph'},
#  {'content': '（5）法律、法规规定的其他情形。', 'position': 286, 'type': 'paragraph'},
#  {'content': '（六）、投标文件的签署和份数', 'position': 287, 'type': 'paragraph'},
#  {'content': '1.投标人应按本招标文件规定的格式和顺序编制、编制目录页及评分标准页 '
#              '码对照表、装订投标文件并标注页码，因投标文件内容不完整、编排混乱导致投 '
#              '标文件被误读、漏读或者查找不到相关内容所导致的后果由投标人自行承担。',
#   'position': 288,
#   'type': 'paragraph'},
#  {'content': '2.投标文件正本 1 份，副本 2，分别编制并单独装订成册，投标文件的封 '
#              '面应注明“正本”、“副本”字样；若正本和副本不符，以正本为准。电子版需 提供U盘 '
#              '2份，电子版内容为投标文件正本签字盖章后的扫描件，格式要求为 pdf。',
#   'position': 289,
#   'type': 'paragraph'},
#  {'content': '3.投标文件的正本需打印或用不褪色的墨水填写，投标文件正本除本《投标 '
#              '人须知》中规定的可提供复印件外均须提供原件。副本可为正本的复印件。',
#   'position': 290,
#   'type': 'paragraph'},
#  {'content': '4.投标文件不得涂改，若有修改错漏处，须加盖单位公章或者法定代表人或 '
#              '授权委托人签字或盖章。投标文件因字迹潦草或表达不清所引起的后果由投标人 负责。',
#   'position': 291,
#   'type': 'paragraph'},
#  {'content': '5. 投标文件需胶装装订成册。', 'position': 292, 'type': 'paragraph'},
#  {'content': '（七）、投标文件的包装、递交、修改和撤回', 'position': 293, 'type': 'paragraph'},
#  {'content': '1.投标文件的密封和标记', 'position': 294, 'type': 'paragraph'},
#  {'content': '1.1 投标时，投标人应将投标文件正本和所有的副本分开密封装在单独的信 封中，且在信封正面标明“正本”“副本”字样。',
#   'position': 295,
#   'type': 'paragraph'},
#  {'content': '1.2 为方便开标唱标，投标人应将 “投标一览表”单独密封，并在信封上标 明“投标一览表”字样，在投标时单独递交。',
#   'position': 296,
#   'type': 'paragraph'},
#  {'content': '1.3 为方便核查投标保证金，投标人应将“投标保证金”单独密封，并在信 封上标明 “投标保证金”字样，在投标时单独递交。',
#   'position': 297,
#   'type': 'paragraph'},
#  {'content': '1.4 所有信封上均应：', 'position': 298, 'type': 'paragraph'},
#  {'content': '1）清楚标明递交至招标公告或投标邀请书中指明的地址。',
#   'position': 299,
#   'type': 'paragraph'},
#  {'content': '2）注明招标公告或投标邀请书中指明的项目名称、项目编号和“在 （开 标日期、时间）之前不得启封”的字样。',
#   'position': 300,
#   'type': 'paragraph'},
#  {'content': '', 'position': 301, 'type': 'paragraph'},
#  {'content': '3）在信封的封装处加盖投标人公章。', 'position': 302, 'type': 'paragraph'},
#  {'content': '1.5 所有信封上还应写明投标人名称和地址，以便若其投标被宣布为“迟到” 投标时，能原封退回。',
#   'position': 303,
#   'type': 'paragraph'},
#  {'content': '1.6 如果投标人未按上述要求密封及加写标记，包括未单独提交投标保证金、 '
#              '开标一览表的，其投标将被拒绝，并且招标人对投标文件的误投或过早启封概不 负责。',
#   'position': 304,
#   'type': 'paragraph'},
#  {'content': '2.投标截止期', 'position': 305, 'type': 'paragraph'},
#  {'content': '2.1 投标人应在招标公告或招标邀请中规定的截止日期和时间内，将投标文件 '
#              '递交招标人，递交地点应是招标公告或投标邀请书中规定的地址。',
#   'position': 306,
#   'type': 'paragraph'},
#  {'content': '2.2 招标人有权按本须知的规定，通过修改招标文件延长投标截止期。在此情 '
#              '况下，招标人和投标人受投标截止期制约的所有权利和义务均应延长至新的截止 期。',
#   'position': 307,
#   'type': 'paragraph'},
#  {'content': '2.3 招标人将拒绝并原封退回在本须知规定的投标截止期后收到的任何投标 文件。',
#   'position': 308,
#   'type': 'paragraph'},
#  {'content': '3.投标文件的修改与撤回', 'position': 309, 'type': 'paragraph'},
#  {'content': '3.1 投标以后，如果投标人提出书面修改或撤标要求，在投标截止时间前送达 招标人者，招标人将予以接受。',
#   'position': 310,
#   'type': 'paragraph'},
#  {'content': '3.2 投标人对投标文件的修改或撤回通知应按本须知规定编制、密封、标记和 发送。',
#   'position': 311,
#   'type': 'paragraph'},
#  {'content': '3.3 在投标截止期之后，投标人不得对其投标文件做任何修改。',
#   'position': 312,
#   'type': 'paragraph'},
#  {'content': '3.4 从投标截止期至投标人在投标书格式中确定的投标有效期之间，投标人不 '
#              '得撤回其投标，否则其投标保证金将按照本须知的规定不予退回。',
#   'position': 313,
#   'type': 'paragraph'},
#  {'content': '（八）、投标无效的情形', 'position': 314, 'type': 'paragraph'},
#  {'content': '实质上没有响应招标文件要求的投标将被视为无效投标。投标人不得通过修 '
#              '正或撤销不合要求的偏离或保留从而使其投标成为实质上响应的投标。',
#   'position': 315,
#   'type': 'paragraph'},
#  {'content': '四、开标', 'position': 316, 'type': 'paragraph'},
#  {'content': '（一）、开标准备', 'position': 317, 'type': 'paragraph'},
#  {'content': '招标代理机构将在规定的时间和地点进行开标，投标人的法定代表人或其授 '
#              '权代表应参加线上开标会。投标人的法定代表人或其授权代表未按时参加线上开 标会的，视同放弃开标监督权利、认可开标结果。',
#   'position': 318,
#   'type': 'paragraph'},
#  {'content': '', 'position': 319, 'type': 'paragraph'},
#  {'content': '（二）、开标程序：', 'position': 320, 'type': 'paragraph'},
#  {'content': '1.开标会由招标代理机构主持，主持人宣布开标会议开始； 2.主持人介绍参加开标会的人员名单；',
#   'position': 321,
#   'type': 'paragraph'},
#  {'content': '3.主持人宣布评标期间的有关事项；', 'position': 322, 'type': 'paragraph'},
#  {'content': '4.投标文件密封情况经招标人代表和监标人共同核实无误后，由招标代理机 构工作人员现场拆封并唱标。',
#   'position': 323,
#   'type': 'paragraph'},
#  {'content': '5.招标代理机构在开标仪式上，将公布投标人名称、投标内容、投标价格、 交货期等以及招标人认为合适的其他内容，并做开标记录。',
#   'position': 324,
#   'type': 'paragraph'},
#  {'content': '6.投标人的法定代表人或其委托代理人应准时参加开标会议。',
#   'position': 325,
#   'type': 'paragraph'},
#  {'content': '7.投标人的法定代表人或其委托代理人应在开标会视频会议现场就开标记录 表上对自己的总投标价进行确认。',
#   'position': 326,
#   'type': 'paragraph'},
#  {'content': '8.开标会议结束。', 'position': 327, 'type': 'paragraph'},
#  {'content': '五、评标', 'position': 328, 'type': 'paragraph'},
#  {'content': '（一）、组建评标委员会', 'position': 329, 'type': 'paragraph'},
#  {'content': '评标委员会根据招标采购项目的特点进行组建，并负责评标工作。评标委员 会由招标人代表和有关技术、经济等方面的专家组成。成员为 5 '
#              '人以上单数，专 家不得少于 2/3。',
#   'position': 330,
#   'type': 'paragraph'},
#  {'content': '评标委员会履行下列职责：', 'position': 331, 'type': 'paragraph'},
#  {'content': '（1）审查投标文件是否符合招标文件要求，并做出评价；',
#   'position': 332,
#   'type': 'paragraph'},
#  {'content': '（2）要求投标人对投标文件有关事项作出解释或者澄清；',
#   'position': 333,
#   'type': 'paragraph'},
#  {'content': '（3）推荐中标候选人。', 'position': 334, 'type': 'paragraph'},
#  {'content': '（二）、评标的方式', 'position': 335, 'type': 'paragraph'},
#  {'content': '本项目采用不公开方式评标，评标的依据为招标文件和投标文件。',
#   'position': 336,
#   'type': 'paragraph'},
#  {'content': '（三）、评标程序', 'position': 337, 'type': 'paragraph'},
#  {'content': '1. 投标文件的初审', 'position': 338, 'type': 'paragraph'},
#  {'content': '1.1 投标文件的初审分为资格性审查和符合性审查。', 'position': 339, 'type': 'paragraph'},
#  {'content': '1.1.1 资格性审查：指依据法律、法规和招标文件的规定，对投标文件中的 资格证明等进行审查，以确定投标人是否具备投标资格。',
#   'position': 340,
#   'type': 'paragraph'},
#  {'content': '1.1.2 符合性审查：依据招标文件的规定，从投标文件的有效性、完整性和 '
#              '对招标文件的响应程度进行审查，以确定是否对招标文件的实质性要求做出响应。',
#   'position': 341,
#   'type': 'paragraph'},
#  {'content': '', 'position': 342, 'type': 'paragraph'},
#  {'content': '2.实质审查与比较', 'position': 343, 'type': 'paragraph'},
#  {'content': '（1）评标委员会审查投标文件的实质性内容是否符合招标文件的实质性要 求。',
#   'position': 344,
#   'type': 'paragraph'},
#  {'content': '（2）评标委员会将根据投标人的投标文件进行审查、核对,如有疑问,将对投 '
#              '标人发出澄清函，投标人要向评标委员会澄清有关问题,并最终以书面形式进行答 复。',
#   'position': 345,
#   'type': 'paragraph'},
#  {'content': '（3）评委对各部分得分汇总，计算出本项目最终得分。各投标人的最终得分 '
#              '为所有评委的有效评分的算术平均数。评标委员会按评标原则推荐中标候选人同 时起草评标报告。',
#   'position': 346,
#   'type': 'paragraph'},
#  {'content': '（四）、澄清问题的形式', 'position': 347, 'type': 'paragraph'},
#  {'content': '对投标文件中含义不明确、同类问题表述不一致或者有明显文字和计算错误 '
#              '的内容，评标委员会可要求投标人做出必要的澄清、说明或者纠正。投标人的澄 '
#              '清、说明或者补正应当采用书面形式，由其授权代表签字或盖章确认，并不得超 出投标文件的范围或者改变投标文件的实质性内容。',
#   'position': 348,
#   'type': 'paragraph'},
#  {'content': '（五）、错误修正', 'position': 349, 'type': 'paragraph'},
#  {'content': '投标文件如果出现计算或表达上的错误，修正错误的原则如下：开标时，投 '
#              '标文件中投标一览表内容与投标文件明细内容不一致的，以投标一览表为准。',
#   'position': 350,
#   'type': 'paragraph'},
#  {'content': '投标文件的大写金额和小写金额不一致的，以大写金额为准；总价金额与按 '
#              '单价汇总金额不一致的，以单价金额计算结果为准；单价金额小数点明显错位的， '
#              '应以总价为准，并修改单价；对不同文字文本投标文件的解释发生异议的，以中 文文本为准。',
#   'position': 351,
#   'type': 'paragraph'},
#  {'content': '按上述修正错误的原则及方法调整或修正投标文件的投标报价，投标人同意 '
#              '并签字确认后，调整后的投标报价对投标人具有约束作用。如果投标人不接受修 正后的报价，则其投标将作为无效投标处理。',
#   'position': 352,
#   'type': 'paragraph'},
#  {'content': '（六）、评标原则和评标办法', 'position': 353, 'type': 'paragraph'},
#  {'content': '1.评标原则。评标委员会必须公平、公正、客观， 不带任何倾向性和启发性； '
#              '不得向外界透露任何与评标有关的内容；任何单位和个人不得干扰、影响评标的 正常进行；评标委员会及有关工作人员不得私下与投标人接触。',
#   'position': 354,
#   'type': 'paragraph'},
#  {'content': '2.评标办法。本项目评标办法是 综合评分法 ，具体评标内容及评分标准等 详见《第四章 评标办法及评分标准》。',
#   'position': 355,
#   'type': 'paragraph'},
#  {'content': '', 'position': 356, 'type': 'paragraph'},
#  {'content': '六、定标', 'position': 357, 'type': 'paragraph'},
#  {'content': '本项目评标委员会按评审排序结果推荐 1-3 名中标候选人，并由招标人确定 中标人。',
#   'position': 358,
#   'type': 'paragraph'},
#  {'content': '1. 招标代理机构在评标结束后将评标报告交招标人确认，同时在发布招标公 告的网站上对评标结果进行公示。',
#   'position': 359,
#   'type': 'paragraph'},
#  {'content': '2. 若中标人放弃中标、或因不可抗力提出不能履行合同， 或不按招标文件规 '
#              '定提交履约保证金或其它原因被依法撤销中标资格，则招标人重新组织招标。',
#   'position': 360,
#   'type': 'paragraph'},
#  {'content': '七、合同授予', 'position': 361, 'type': 'paragraph'},
#  {'content': '1.招标人与中标人应当在《中标通知书》发出之日起 30 日内签订合同。 '
#              '2.中标人拖延、拒签合同的,将被扣罚投标保证金并取消中标资格。',
#   'position': 362,
#   'type': 'paragraph'},
#  {'content': '八、履约保证金', 'position': 363, 'type': 'paragraph'},
#  {'content': '中标人与招标人签订合同后 7 个工作日内，向招标人提交合同总价款 10%的 履约保证金。',
#   'position': 364,
#   'type': 'paragraph'},
#  {'content': '九、招标代理服务费的收取', 'position': 365, 'type': 'paragraph'},
#  {'content': '1. 招标代理服务费由中标人支付。', 'position': 366, 'type': 'paragraph'},
#  {'content': '2.招标代理服务费的收取标准：按照《招标代理服务收费标准》货物收费标 准下浮 12%计取。',
#   'position': 367,
#   'type': 'paragraph'},
#  {'content': '招标代理服务收费标准', 'position': 368, 'type': 'paragraph'},
#  {'content': '', 'position': 369, 'type': 'paragraph'},
#  {'content': '', 'position': 371, 'type': 'paragraph'},
#  {'content': '3.招标代理服务费支付方式：银行汇款、电汇、支票。', 'position': 372, 'type': 'paragraph'},
#  {'content': '', 'position': 373, 'type': 'paragraph'},
#  {'content': '第四章 评标办法及评分标准', 'position': 374, 'type': 'paragraph'},
#  {'content': '一、评标原则及顺序', 'position': 375, 'type': 'paragraph'},
#  {'content': '（一）招标人负责依法组建评标委员会，评标工作由评标委员会承担。评标委员 '
#              '会由技术、经济等方面的专家和招标人委派的评标代表共同组成。成员为',
#   'position': 376,
#   'type': 'paragraph'},
#  {'content': '5 人以上单数，专家不得少于 2/3。', 'position': 377, 'type': 'paragraph'},
#  {'content': '（二）评标工作依据《中华人民共和国招标投标法》、国家七部委联合颁发的《评 '
#              '标委员会和评标办法暂行规定》等相关法律法规中规定的公平、公正、科 '
#              '学、择优的原则进行。采用相同的程序、标准和方法，对投标人的投标文 件进行评审、比较。',
#   'position': 378,
#   'type': 'paragraph'},
#  {'content': '（三）评标委员会依据招标文件（及其有效的补充或修改文件）以及本评标办法 进行评标，任何其他的外部证据均不得作为评标的依据。',
#   'position': 379,
#   'type': 'paragraph'},
#  {'content': '（四）评标采用综合评分评标法。本办法中规定了所有必须评价的项目及相关评 '
#              '价标准。按照本办法设定的评标标准及方法对投标文件进行评审，任何人 在复制、使用过程中均不得对原件修改。',
#   'position': 380,
#   'type': 'paragraph'},
#  {'content': '（五）评标工作由评标委员会推举的评标委员会组长主持。每位专家独立评标， 任何人不得通过任何方式，干扰评标委员会的评标。',
#   'position': 381,
#   'type': 'paragraph'},
#  {'content': '（六）评标委员会对投标人按得分多少进行排序，按评审排序结果推荐 1-3 名中 标候选人，由招标人确定中标人。',
#   'position': 382,
#   'type': 'paragraph'},
#  {'content': '二、评标内容及评标程序', 'position': 383, 'type': 'paragraph'},
#  {'content': '评标的内容包括：对投标人商务部分、技术部分和投标报价进行评审和比较。',
#   'position': 384,
#   'type': 'paragraph'},
#  {'content': '1、依法组建评标委员会， 由评标委员会推选评标委员会组长。评标委员会组 长负责全面主持、协调所有评标工作。',
#   'position': 385,
#   'type': 'paragraph'},
#  {'content': '2、评标委员会依据招标文件中的相关规定， 对投标文件进行初步评审，依次 '
#              '进行资格性和符合性审查，并确定通过初步评审进入后续评审程序的投标人名单。',
#   'position': 386,
#   'type': 'paragraph'},
#  {'content': '2.1 评标委员会对投标文件进行资格性审查，下列条件有一项不符合的，其 投标无效：',
#   'position': 387,
#   'type': 'paragraph'},
#  {'content': '（1）投标人须提供有效的营业执照复印件并加盖公章；', 'position': 388, 'type': 'paragraph'},
#  {'content': '（2）投标人须提供距投标截止时间近半年内任意一个月的依法缴纳社会保险 记录和依法纳税记录复印件并加盖公章；',
#   'position': 389,
#   'type': 'paragraph'},
#  {'content': '（3）投标人须提供近三年内，在经营活动中没有重大违法记录的声明（格式',
#   'position': 390,
#   'type': 'paragraph'},
#  {'content': '', 'position': 391, 'type': 'paragraph'},
#  {'content': '见附件 3）；', 'position': 392, 'type': 'paragraph'},
#  {'content': '（4）投标人须提供“与投标人存在‘单位负责人为同一人或者存在直接控股、 管理关系’的其他法人信息”（按格式附件 12 '
#              '填写并签字盖章）；',
#   'position': 393,
#   'type': 'paragraph'},
#  {'content': '（5）投标人须提供在信用中国网站（www.creditchina.gov.cn）和中国政府 '
#              '采购网（www.ccgp.gov.cn）的信用查询记录网页截图并加盖公章（查询时间 为招标公告发布后至投标截止时间期间）；',
#   'position': 394,
#   'type': 'paragraph'},
#  {'content': '（6）投标人提供有效的《食品生产许可证》或《食品经营许可证》复印件加 '
#              '盖公章，若投标人为仅销售预包装食品的企业，须具有包含“食品经营（仅 '
#              '销售预包装食品）”的有效营业执照或仅销售预包装食品备案证明材料并加 盖公章；',
#   'position': 395,
#   'type': 'paragraph'},
#  {'content': '（7）投标人须提供会计师事务所出具的上一年度（2023 年度）财务审计报告 复印件加盖公章，投标人尚未完成 2023 '
#              '年度财务审计的须提供 2022 年度经 审计的财务报告复印件并加盖公章；若投标人为 2023 年 1 月 1 日之后成立的 '
#              '公司，须提供财务状况说明并加盖公章；',
#   'position': 396,
#   'type': 'paragraph'},
#  {'content': '2.2 评标委员会对投标文件进行符合性审查，下列条件有一项不符合的，其 投标无效：',
#   'position': 397,
#   'type': 'paragraph'},
#  {'content': '（1）未按招标文件规定的格式提供法定代表人授权书；', 'position': 398, 'type': 'paragraph'},
#  {'content': '（2）未交投标保证金或投标保证金不足；', 'position': 399, 'type': 'paragraph'},
#  {'content': '（3）投标有效期不足；', 'position': 400, 'type': 'paragraph'},
#  {'content': '（4）未按照招标文件要求密封、签署、盖章；', 'position': 401, 'type': 'paragraph'},
#  {'content': '（5）未提供招标文件要求的资格证书和资质证明文件；', 'position': 402, 'type': 'paragraph'},
#  {'content': '（6）任何对招标文件带“*”号的重要商务、技术条款的负偏离和未作实质 性响应，都将直接导致投标无效。',
#   'position': 403,
#   'type': 'paragraph'},
#  {'content': '（7）未对招标文件做出实质性响应的，或者投标文件的组成存在较大缺陷， 不符合招标文件规定的要求。由全体评委出具书面意见确认；',
#   'position': 404,
#   'type': 'paragraph'},
#  {'content': '（8）投标货物的技术规格和性能存在较大偏离，不能符合实际使用要求。由 全体评委出具书面意见确认；',
#   'position': 405,
#   'type': 'paragraph'},
#  {'content': '（9）交货期、质保及售后服务存在较大偏离， 不能符合采购使用要求。由全 体评委出具书面意见确认；',
#   'position': 406,
#   'type': 'paragraph'},
#  {'content': '', 'position': 407, 'type': 'paragraph'},
#  {'content': '（10）投标文件中对同一招标项目有两个或多个报价，且未声明哪个为有效 '
#              '的，或投标文件中出现重大漏项、漏量的。由全体评委出具书面意见确认；',
#   'position': 408,
#   'type': 'paragraph'},
#  {'content': '（11）投标文件附有招标人不能接受的条件。由全体评委出具书面意见确认；',
#   'position': 409,
#   'type': 'paragraph'},
#  {'content': '（12）评委会一致认为报价明显不合理的；', 'position': 410, 'type': 'paragraph'},
#  {'content': '（13）提供虚假证明材料被查实的。由全体评委出具书面意见确认；',
#   'position': 411,
#   'type': 'paragraph'},
#  {'content': '（14）法律、法规规定的其他情形。', 'position': 412, 'type': 'paragraph'},
#  {'content': '3、若本次所有投标人的报价经评标委员会认定明显高于市场价格， 则招标人 保留重新组织招标的权利。',
#   'position': 413,
#   'type': 'paragraph'},
#  {'content': '三、评标方法', 'position': 414, 'type': 'paragraph'},
#  {'content': '1、本项目采用综合评分法评标。', 'position': 415, 'type': 'paragraph'},
#  {'content': '2、按招标文件规定的价格、商务和技术评分标准， 由评标委员会各成员以记 名方式独立评定打分。',
#   'position': 416,
#   'type': 'paragraph'},
#  {'content': '3、汇总各评委的评分， 取算术平均值（小数点后保留两位小数）为该投标人 的总得分。',
#   'position': 417,
#   'type': 'paragraph'},
#  {'content': '4、根据各投标人的评标最终得分， 从高到低确定排名次序。若投标人的评标 '
#              '最终得分相等，则投标价低者列前。评标委员会按评审排序结果推荐1-3名中标候 选人，并由招标人确定中标人。',
#   'position': 418,
#   'type': 'paragraph'},
#  {'content': '5、评标办法的解释权归招标人所有。', 'position': 419, 'type': 'paragraph'},
#  {'content': '', 'position': 420, 'type': 'paragraph'},
#  {'content': '', 'position': 421, 'type': 'paragraph'},
#  {'content': '附件一：资格审查表', 'position': 422, 'type': 'paragraph'},
#  {'content': '', 'position': 423, 'type': 'paragraph'},
#  {'content': '以上证明资料，投标文件中须提供复印件并加盖投标人公章。 以上条件中有一项不合格，则投标人不能通过资格性审查。',
#   'position': 425,
#   'type': 'paragraph'},
#  {'content': '', 'position': 426, 'type': 'paragraph'},
#  {'content': '附件二：符合性审查表', 'position': 427, 'type': 'paragraph'},
#  {'content': '', 'position': 428, 'type': 'paragraph'},
#  {'content': '', 'position': 429, 'type': 'paragraph'},
#  {'content': '', 'position': 431, 'type': 'paragraph'},
#  {'content': '', 'position': 432, 'type': 'paragraph'},
#  {'content': '附件三：评分标准', 'position': 433, 'type': 'paragraph'},
#  {'content': '（一）、价格分（40 分）', 'position': 434, 'type': 'paragraph'},
#  {'content': '', 'position': 435, 'type': 'paragraph'},
#  {'content': '', 'position': 437, 'type': 'paragraph'},
#  {'content': '', 'position': 438, 'type': 'paragraph'},
#  {'content': '（二）、商务分（25 分）', 'position': 439, 'type': 'paragraph'},
#  {'content': '', 'position': 440, 'type': 'paragraph'},
#  {'content': '', 'position': 442, 'type': 'paragraph'},
#  {'content': '', 'position': 443, 'type': 'paragraph'},
#  {'content': '（三）、技术分（35 分）', 'position': 444, 'type': 'paragraph'},
#  {'content': '', 'position': 446, 'type': 'paragraph'},
#  {'content': '', 'position': 447, 'type': 'paragraph'},
#  {'content': '', 'position': 448, 'type': 'paragraph'},
#  {'content': '上述信息企业需如实提供，如发现有虚报、捏造，与税务、社保等部门数据不符，将追究企 '
#              '业的欺诈责任。请投标人根据实际情况提供证明材料。',
#   'position': 450,
#   'type': 'paragraph'},
#  {'content': '', 'position': 451, 'type': 'paragraph'},
#  {'content': '第五章 合同条款及格式', 'position': 452, 'type': 'paragraph'},
#  {'content': '', 'position': 453, 'type': 'paragraph'},
#  {'content': '', 'position': 454, 'type': 'paragraph'},
#  {'content': '', 'position': 455, 'type': 'paragraph'},
#  {'content': '', 'position': 456, 'type': 'paragraph'},
#  {'content': '', 'position': 457, 'type': 'paragraph'},
#  {'content': '', 'position': 458, 'type': 'paragraph'},
#  {'content': '', 'position': 459, 'type': 'paragraph'},
#  {'content': '', 'position': 460, 'type': 'paragraph'},
#  {'content': '买卖合同', 'position': 461, 'type': 'paragraph'},
#  {'content': '', 'position': 462, 'type': 'paragraph'},
#  {'content': '', 'position': 463, 'type': 'paragraph'},
#  {'content': '', 'position': 464, 'type': 'paragraph'},
#  {'content': '', 'position': 465, 'type': 'paragraph'},
#  {'content': '甲方合同编号: 乙方合同编号:', 'position': 466, 'type': 'paragraph'},
#  {'content': '', 'position': 467, 'type': 'paragraph'},
#  {'content': '', 'position': 468, 'type': 'paragraph'},
#  {'content': '', 'position': 469, 'type': 'paragraph'},
#  {'content': '', 'position': 470, 'type': 'paragraph'},
#  {'content': '', 'position': 471, 'type': 'paragraph'},
#  {'content': '', 'position': 472, 'type': 'paragraph'},
#  {'content': '', 'position': 473, 'type': 'paragraph'},
#  {'content': '甲 方（买 方 ）： 北京京铁运恒采购供应站有限公司',
#   'position': 474,
#   'type': 'paragraph'},
#  {'content': '法定代表人（负责人 ）： 王荣生', 'position': 475, 'type': 'paragraph'},
#  {'content': '住 所： 北京市丰台区北京西站东附楼瑞尔威', 'position': 476, 'type': 'paragraph'},
#  {'content': '写字楼 A1 座 A706 室', 'position': 477, 'type': 'paragraph'},
#  {'content': '', 'position': 478, 'type': 'paragraph'},
#  {'content': '乙 方（卖 方 ）：', 'position': 479, 'type': 'paragraph'},
#  {'content': '法定代表人（负责人 ）：', 'position': 480, 'type': 'paragraph'},
#  {'content': '住 所 ：', 'position': 481, 'type': 'paragraph'},
#  {'content': '', 'position': 482, 'type': 'paragraph'},
#  {'content': '', 'position': 483, 'type': 'paragraph'},
#  {'content': '', 'position': 484, 'type': 'paragraph'},
#  {'content': '', 'position': 485, 'type': 'paragraph'},
#  {'content': '', 'position': 486, 'type': 'paragraph'},
#  {'content': '', 'position': 487, 'type': 'paragraph'},
#  {'content': '', 'position': 488, 'type': 'paragraph'},
#  {'content': '', 'position': 489, 'type': 'paragraph'},
#  {'content': '', 'position': 490, 'type': 'paragraph'},
#  {'content': '', 'position': 491, 'type': 'paragraph'},
#  {'content': '', 'position': 492, 'type': 'paragraph'},
#  {'content': '签订地点：', 'position': 493, 'type': 'paragraph'},
#  {'content': '', 'position': 494, 'type': 'paragraph'},
#  {'content': '根据《中华人民共和国民法典》及其他有关法律、法规之规定， 甲乙双方遵 循公平、自愿、诚实信用的原则， '
#              '在协商一致的基础上，就乙方向甲方出售下列 商品达成协议如下:',
#   'position': 495,
#   'type': 'paragraph'},
#  {'content': '第一条 合同标的', 'position': 496, 'type': 'paragraph'},
#  {'content': '', 'position': 497, 'type': 'paragraph'},
#  {'content': '', 'position': 499, 'type': 'paragraph'},
#  {'content': '第二条 质量要求', 'position': 500, 'type': 'paragraph'},
#  {'content': '（一）商品的质量标准（包括技术要求），按下列第〔 〕项和第〔 〕项 执行：',
#   'position': 501,
#   'type': 'paragraph'},
#  {'content': '1.按国家标准执行 ；', 'position': 502, 'type': 'paragraph'},
#  {'content': '2.按行业标准或中国国家铁路集团有限公司颁布标准执行：（标准代号、编 号和标准名称）；',
#   'position': 503,
#   'type': 'paragraph'},
#  {'content': '3.按企业标准执行： 标准代号、编号和标准名称）；', 'position': 504, 'type': 'paragraph'},
#  {'content': '4.按 。', 'position': 505, 'type': 'paragraph'},
#  {'content': '（二）乙方需对商品进行全面的质量检查，承诺销售给甲方的商品全部符合 约定的质量要求，并提供相应的检验证明和商品合格证。',
#   'position': 506,
#   'type': 'paragraph'},
#  {'content': '第三条 商品的包装标准和包装物的供应与回收', 'position': 507, 'type': 'paragraph'},
#  {'content': '包装物由乙方负责。所有商品应包装坚固， 能耐受长途运输以及多次装卸搬 '
#              '运，并应根据设备的特点和需要提供防潮、防尘、防雨、防冻、防震、防腐蚀等 '
#              '保护措施，以保证商品安全无损地运抵安装场地并妥善保管。包装、装运及保管 应符合相关标准。',
#   'position': 508,
#   'type': 'paragraph'},
#  {'content': '包装物回收及费用由乙方负责。', 'position': 509, 'type': 'paragraph'},
#  {'content': '第四条 商品交货数量的正负尾差、合理磅差和在途自然减（增）量规定等',
#   'position': 510,
#   'type': 'paragraph'},
#  {'content': '', 'position': 511, 'type': 'paragraph'},
#  {'content': '合理损耗标准及计算方法： / 。 第五条 商品的交货方式、交货地点和交货时间',
#   'position': 512,
#   'type': 'paragraph'},
#  {'content': '（一）交货方式：乙方负责将商品通过 汽运方式送至甲方指定的地点：按照 '
#              '甲方要求送达到指定物流公司库房(物流公司库房地址主要为京津冀地区)，具体 '
#              '配送地点以甲方要求为准。运输费、装卸费等费用由乙方承担， 乙方应保证通过 该等运输时，商品的质量、性能、技术指标等不受影响。',
#   'position': 513,
#   'type': 'paragraph'},
#  {'content': '（二）交货时间： 乙方接到中标通知书开始备货，签订合同后开始送货， 实际送货进度以甲方送货计划通知为准。',
#   'position': 514,
#   'type': 'paragraph'},
#  {'content': '（三）甲方如要求变更到货地点或接货人，应在合同规定的交货期限前 3 天通知乙方。乙方交付前应至少提前 3 '
#              '日通知甲方。乙方如未经甲方同意提前 交货，应承担仓储费等所有费用，且甲方保留拒绝受领及延迟付款的权利。',
#   'position': 515,
#   'type': 'paragraph'},
#  {'content': '（四）乙方应在交货时提供下列文件：', 'position': 516, 'type': 'paragraph'},
#  {'content': '1.相关出厂检验、试验报告、合格证、第三方检定报告（如有）等质量文件； 2.使用说明、仓储手册等使用和保管方面的书面资料；',
#   'position': 517,
#   'type': 'paragraph'},
#  {'content': '3.其他 / 。', 'position': 518, 'type': 'paragraph'},
#  {'content': '（五）如商品有通关必要时，乙方应负责或协助甲方完成清关、报关手续， 因乙方过错造成通关受阻而引起甲方损失的由乙方负责赔偿。',
#   'position': 519,
#   'type': 'paragraph'},
#  {'content': '第六条 验收及质保', 'position': 520, 'type': 'paragraph'},
#  {'content': '（一）乙方将商品运送到第五条第（一）款约定的地点后，应及时与甲方办 理验收手续。甲方指定 为验收人，乙方指定 '
#              '为验收人，如乙方未指 定验收人或指定的验收人未及时与甲方办理验收手续，视为乙方同意甲方验收结 果。',
#   'position': 521,
#   'type': 'paragraph'},
#  {'content': '（二）甲方应在收到商品后 10 日内进行验收（若约定的验收时间过短，不 '
#              '足以发现产品隐藏的质量瑕疵，则验收仅视为对商品数量、型号、外观等瑕疵的 认可）。对存在质量问题或者其他问题的，甲方在 3 '
#              '日内提出异议，乙方须在 甲方提出异议后的 2 日内进行处理。若乙方未在甲方提出异议后的 2 日内进行 '
#              '处理，则视为乙方同意甲方的异议，甲乙双方对经处理的标的物按合同约定重新 组织验收。',
#   'position': 522,
#   'type': 'paragraph'},
#  {'content': '（三）商品验收合格的，甲方应向乙方出具验收凭证，一式两份，经双方指 定验收人签字确认后，作为乙方办理结算的凭证。',
#   'position': 523,
#   'type': 'paragraph'},
#  {'content': '', 'position': 524, 'type': 'paragraph'},
#  {'content': '（四）本合同约定商品的质保期为 甲方验收后以商品标识中的质保期为准， '
#              '且剩余保质期不少于三分之二，自验收合格之日起计算。甲方出具的验收凭证不 作为最终判定标的物质量的依据。',
#   'position': 525,
#   'type': 'paragraph'},
#  {'content': '（五）质保期内，标的物发生质量问题时，乙方应当在 2 日内无条件完成 '
#              '免费更换，并承担所产生的全部费用及损失，否则甲方有权另行委托第三方修理， '
#              '并由乙方承担相应费用；更换全新产品的，其质保期重新计算。',
#   'position': 526,
#   'type': 'paragraph'},
#  {'content': '第七条 所有权及风险转移', 'position': 527, 'type': 'paragraph'},
#  {'content': '商品所有权自交付时转移给甲方，商品毁损灭失等风险于甲方出具验收凭证 后转移给甲方。',
#   'position': 528,
#   'type': 'paragraph'},
#  {'content': '第八条 付款方式及质保金', 'position': 529, 'type': 'paragraph'},
#  {'content': '（一）乙方把合同标的货物全部送达甲方指定地址后,经甲方验收合格且收 到增值税专用发票并验票合格后第 15个日历日至第 '
#              '20个日历日以汇款方式向乙 方支付合同总价（含增值税） 的 60 %即人民币 元整（小写： 元），第一次付款后 30 '
#              '日内以汇款方式向乙方支付剩余货款，预估约合同总价 （含增值税）的 40 %即人民币 元整（小写： 元），结算 '
#              '金额以实际配送数量为准。每次付款前乙方应按甲方规定提供合法有效的增值税 发票。',
#   'position': 530,
#   'type': 'paragraph'},
#  {'content': '合同签订后 7 个工作日内，乙方按合同总价款的 10%即人民币 元 整（小写 ： 元）向甲方支付合同履约保证金。双方结账完毕， '
#              '履约保证 金自动转为商品质量保证金。三个月后， 在商品没有出现任何问题的情况下，甲 方将质量保证金不计息一次性退回乙方。',
#   'position': 531,
#   'type': 'paragraph'},
#  {'content': '（二）账户信息', 'position': 532, 'type': 'paragraph'},
#  {'content': '乙方银行账户信息如下：', 'position': 533, 'type': 'paragraph'},
#  {'content': '单位名称： 开户银行: 银行账号: 甲方增值税专用发票开票信息如下：',
#   'position': 534,
#   'type': 'paragraph'},
#  {'content': '单位名称：北京京铁运恒采购供应站有限公司 统一社会信用代码：91110111101392541J',
#   'position': 535,
#   'type': 'paragraph'},
#  {'content': '开户银行：中国建设银行北京铁道专业支行', 'position': 536, 'type': 'paragraph'},
#  {'content': '', 'position': 537, 'type': 'paragraph'},
#  {'content': '银行账号：11050137360000003174', 'position': 538, 'type': 'paragraph'},
#  {'content': '单位地址：北京市丰台区北京西站东附楼瑞尔威写字楼 A1 座 A706 室 电 话：51829559',
#   'position': 539,
#   'type': 'paragraph'},
#  {'content': '任何一方如需改变上述账户信息，应提前 3 日以书面形式通知另一方。如 '
#              '一方未按本合同规定通知而遭受损失的自行承担，若使另外一方遭受损失的，应 赔偿相应损失。',
#   'position': 540,
#   'type': 'paragraph'},
#  {'content': '（三）发票约定', 'position': 541, 'type': 'paragraph'},
#  {'content': '1.乙方应按规定向甲方开具符合国家规定的增值税发票，并承诺开具发票的 '
#              '形式与内容均合法、有效、完整、准确。开具的发票不合法、不合规， 甲方有权 '
#              '延迟支付乙方应付款项直至开具合法、合规发票之日且不承担违约责任， 且乙方 '
#              '仍应按合同约定履行各项义务。如果乙方无法在合理时间内提供合法合规的增值 '
#              '税发票，给甲方造成损失的，乙方应赔偿甲方由此造成的损失。甲方有权在应支 付的价款中扣除相应的抵扣税款。',
#   'position': 542,
#   'type': 'paragraph'},
#  {'content': '2.发票开具后，乙方应在 3 日内及时送达甲方。如逾期送达导致延迟支付 '
#              '或给甲方造成损失的，甲方不承担违约责任，且有权要求乙方赔偿甲方的损失。',
#   'position': 543,
#   'type': 'paragraph'},
#  {'content': '3.在发票交付甲方之后，发生发票丢失、破损或逾期等情形， 乙方应按规定 协助办理增值税抵扣事项。',
#   'position': 544,
#   'type': 'paragraph'},
# ...
#  {'content': '', 'position': 704, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表(签字或盖章)：', 'position': 705, 'type': 'paragraph'},
#  {'content': '', 'position': 706, 'type': 'paragraph'},
#  {'content': '', 'position': 707, 'type': 'paragraph'},
#  {'content': '投标人名称（公章）：', 'position': 708, 'type': 'paragraph'},
#  {'content': '', 'position': 709, 'type': 'paragraph'},
#  {'content': '', 'position': 710, 'type': 'paragraph'},
#  {'content': '', 'position': 711, 'type': 'paragraph'},
#  {'content': '', 'position': 712, 'type': 'paragraph'},
#  {'content': '日期： 年 月 日', 'position': 713, 'type': 'paragraph'},
#  {'content': '', 'position': 714, 'type': 'paragraph'},
#  {'content': '附件 4 法定代表人授权书', 'position': 715, 'type': 'paragraph'},
#  {'content': '致：招标人', 'position': 716, 'type': 'paragraph'},
#  {'content': '本授权书声明：注册于（国家或地区的名称）的（公司名称）的在下面签字 '
#              '的（法人代表（单位负责人）姓名、职务）代表本公司授权（单位名称）的在下 '
#              '面签字的（被授权人的姓名、职务）（身份证件号码）为本公司的合法代理人， '
#              '就（项目名称）的投标，以本公司名义处理一切与之有关的事务。',
#   'position': 717,
#   'type': 'paragraph'},
#  {'content': '本授权书于 年 月 日签字生效,特此声明。', 'position': 718, 'type': 'paragraph'},
#  {'content': '', 'position': 719, 'type': 'paragraph'},
#  {'content': '', 'position': 720, 'type': 'paragraph'},
#  {'content': '法定代表人（单位负责人）签字或盖章：', 'position': 721, 'type': 'paragraph'},
#  {'content': '', 'position': 722, 'type': 'paragraph'},
#  {'content': '', 'position': 723, 'type': 'paragraph'},
#  {'content': '被授权人签字：', 'position': 724, 'type': 'paragraph'},
#  {'content': '', 'position': 725, 'type': 'paragraph'},
#  {'content': '', 'position': 726, 'type': 'paragraph'},
#  {'content': '单位公章：', 'position': 727, 'type': 'paragraph'},
#  {'content': '', 'position': 728, 'type': 'paragraph'},
#  {'content': '', 'position': 729, 'type': 'paragraph'},
#  {'content': '', 'position': 730, 'type': 'paragraph'},
#  {'content': '被授权人姓名： 职 务： 详细通讯地址： 邮 政 编 码： 传 真： 电 话：',
#   'position': 731,
#   'type': 'paragraph'},
#  {'content': '', 'position': 732, 'type': 'paragraph'},
#  {'content': '附件 5 投标人情况简介', 'position': 733, 'type': 'paragraph'},
#  {'content': '投标人：（公章） 填表日期： 年 月 日', 'position': 734, 'type': 'paragraph'},
#  {'content': '', 'position': 736, 'type': 'paragraph'},
#  {'content': '', 'position': 737, 'type': 'paragraph'},
#  {'content': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表',
#   'position': 738,
#   'type': 'paragraph'},
#  {'content': '', 'position': 739, 'type': 'paragraph'},
#  {'content': '注：要求提供用户合同复印件、发票复印件、发票明细汇总清单、案例用户联系人及联系方 式。',
#   'position': 741,
#   'type': 'paragraph'},
#  {'content': '', 'position': 742, 'type': 'paragraph'},
#  {'content': '', 'position': 743, 'type': 'paragraph'},
#  {'content': '', 'position': 744, 'type': 'paragraph'},
#  {'content': '', 'position': 745, 'type': 'paragraph'},
#  {'content': '附件 7 投标一览表', 'position': 746, 'type': 'paragraph'},
#  {'content': '投标一览表', 'position': 747, 'type': 'paragraph'},
#  {'content': '', 'position': 748, 'type': 'paragraph'},
#  {'content': '项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）',
#   'position': 749,
#   'type': 'paragraph'},
#  {'content': '投标人名称（公章）：', 'position': 751, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表(签字或盖章)： 注：1.此表应按投标人须知的规定密封递交。',
#   'position': 752,
#   'type': 'paragraph'},
#  {'content': '2.此表中，投标总价应和分项报价表中的总价一致。', 'position': 753, 'type': 'paragraph'},
#  {'content': '3.此投标报价中须包含但不限于货物成本、包装费、检验检测费、仓储费、运输费（送货到招标人指定地点）、保险费、装卸费、售后服务等全部 '
#              '费用。',
#   'position': 754,
#   'type': 'paragraph'},
#  {'content': '', 'position': 755, 'type': 'paragraph'},
#  {'content': '', 'position': 756, 'type': 'paragraph'},
#  {'content': '', 'position': 757, 'type': 'paragraph'},
#  {'content': '', 'position': 758, 'type': 'paragraph'},
#  {'content': '附件 8 分项报价表', 'position': 759, 'type': 'paragraph'},
#  {'content': '分项报价表', 'position': 760, 'type': 'paragraph'},
#  {'content': '项目名称： 项目编号：', 'position': 761, 'type': 'paragraph'},
#  {'content': '报价单位：人民币元', 'position': 762, 'type': 'paragraph'},
#  {'content': '投标人名称（公章）：', 'position': 764, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表(签字或盖章)：', 'position': 765, 'type': 'paragraph'},
#  {'content': '注： 1.如果按单位计算的结果与总价不一致，以单价为准修正总价。',
#   'position': 766,
#   'type': 'paragraph'},
#  {'content': '2.如果不提供分项报价将视为没有实质性响应招标文件。 3.上述各项的分项报价总价应与投标一览表总价一致。',
#   'position': 767,
#   'type': 'paragraph'},
#  {'content': '', 'position': 768, 'type': 'paragraph'},
#  {'content': '附件 9 投标方案', 'position': 769, 'type': 'paragraph'},
#  {'content': '', 'position': 770, 'type': 'paragraph'},
#  {'content': '', 'position': 771, 'type': 'paragraph'},
#  {'content': '（格式自制）', 'position': 772, 'type': 'paragraph'},
#  {'content': '阐述对招标人采购需求的理解、对采购需求分析及对招标人采购需求拟定 投标方案。包括但不限于：',
#   'position': 773,
#   'type': 'paragraph'},
#  {'content': '·拟投入本项目的人员配备方案； ·货物质量保证方案；',
#   'position': 774,
#   'type': 'paragraph'},
#  {'content': '·食品安全卫生管理措施； ·配送方案', 'position': 775, 'type': 'paragraph'},
#  {'content': '·售后服务制度和承诺；', 'position': 776, 'type': 'paragraph'},
#  {'content': '·应急方案； ·检测报告；', 'position': 777, 'type': 'paragraph'},
#  {'content': '·投标人综合实力。', 'position': 778, 'type': 'paragraph'},
#  {'content': '', 'position': 779, 'type': 'paragraph'},
#  {'content': '', 'position': 780, 'type': 'paragraph'},
#  {'content': '', 'position': 781, 'type': 'paragraph'},
#  {'content': '', 'position': 782, 'type': 'paragraph'},
#  {'content': '注：1.投标人加盖公章。', 'position': 783, 'type': 'paragraph'},
#  {'content': '2.如果不提供投标人技术方案将视为没有实质性响应招标文件。',
#   'position': 784,
#   'type': 'paragraph'},
#  {'content': '', 'position': 785, 'type': 'paragraph'},
#  {'content': '附件 10 投标人资格声明', 'position': 786, 'type': 'paragraph'},
#  {'content': '', 'position': 787, 'type': 'paragraph'},
#  {'content': '', 'position': 788, 'type': 'paragraph'},
#  {'content': '致：招标人', 'position': 789, 'type': 'paragraph'},
#  {'content': '为响应你方 年 月 日的（项目编号）投标邀请，下述签字人 愿意参与投标，并提供满足招标需求中规定的（货物及服务），我方递交的投标 '
#              '文件中全部说明、材料、文件内容是真实的和有效的。',
#   'position': 790,
#   'type': 'paragraph'},
#  {'content': '我方详知：招标人可能要求提供进一步的资格材料，我方愿意配合你方，向 '
#              '有关机构和单位（如银行、会计师事务所、相关企业等）查证和获得有关资料。',
#   'position': 791,
#   'type': 'paragraph'},
#  {'content': '', 'position': 792, 'type': 'paragraph'},
#  {'content': '', 'position': 793, 'type': 'paragraph'},
#  {'content': '', 'position': 794, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表（签字或盖章）：', 'position': 795, 'type': 'paragraph'},
#  {'content': '', 'position': 796, 'type': 'paragraph'},
#  {'content': '', 'position': 797, 'type': 'paragraph'},
#  {'content': '投标人名称（公章）：', 'position': 798, 'type': 'paragraph'},
#  {'content': '', 'position': 799, 'type': 'paragraph'},
#  {'content': '', 'position': 800, 'type': 'paragraph'},
#  {'content': '日期： 年 月 日', 'position': 801, 'type': 'paragraph'},
#  {'content': '', 'position': 802, 'type': 'paragraph'},
#  {'content': '附件 11 资格证明文件', 'position': 803, 'type': 'paragraph'},
#  {'content': '1、有效的营业执照复印件（加盖公章）', 'position': 804, 'type': 'paragraph'},
#  {'content': '', 'position': 805, 'type': 'paragraph'},
#  {'content': '2、社会保险缴纳记录和依法纳税记录（近半年内任意一个月的依法缴纳社会保',
#   'position': 806,
#   'type': 'paragraph'},
#  {'content': '险记录复印件并加盖公章）', 'position': 807, 'type': 'paragraph'},
#  {'content': '', 'position': 808, 'type': 'paragraph'},
#  {'content': '3、提供近三年内，在经营活动中没有重大违法记录的声明（格式见附件 3）',
#   'position': 809,
#   'type': 'paragraph'},
#  {'content': '', 'position': 810, 'type': 'paragraph'},
#  {'content': '4、在“信用中国”和“中国政府采购网”网站查询的投标人信用记录的查询结',
#   'position': 811,
#   'type': 'paragraph'},
#  {'content': '果（查询时间为招标公告发布后至投标截止时间期间）（网页查询结果截图 打印并加盖公章）',
#   'position': 812,
#   'type': 'paragraph'},
#  {'content': '', 'position': 813, 'type': 'paragraph'},
#  {'content': '5、有效的《食品生产许可证》或《食品经营许可证》复印件加盖公章，若投标',
#   'position': 814,
#   'type': 'paragraph'},
#  {'content': '人为仅销售预包装食品的企业，须具有包含“食品经营（仅销售预包装食品）” 的有效营业执照或仅销售预包装食品备案证明材料并加盖公章。',
#   'position': 815,
#   'type': 'paragraph'},
#  {'content': '', 'position': 816, 'type': 'paragraph'},
#  {'content': '6、会计师事务所出具的上一年度（2023 年度）财务审计报告复印件并加盖公章，',
#   'position': 817,
#   'type': 'paragraph'},
#  {'content': '投标人尚未完成 2023 年度财务审计的须提供 2022 年度经审计的财务报告复 印件并加盖公章。若投标人为 2023 年 1 '
#              '月 1 日之后成立的公司，须提供财务 状况说明并加盖公章。',
#   'position': 818,
#   'type': 'paragraph'},
#  {'content': '', 'position': 819, 'type': 'paragraph'},
#  {'content': '附件 12 与投标人存在“单位负责人为同一人或者存在直接控股、管理关系”的',
#   'position': 820,
#   'type': 'paragraph'},
#  {'content': '其他法人单位信息', 'position': 821, 'type': 'paragraph'},
#  {'content': '', 'position': 822, 'type': 'paragraph'},
#  {'content': '', 'position': 823, 'type': 'paragraph'},
#  {'content': '', 'position': 824, 'type': 'paragraph'},
#  {'content': '与投标人在“单位负责人为同一人或者存在直接控股、管理关系”的其他法 '
#              '人单位信息如下（如有，须如实填写；如无，则须填写“无”；否则视为未响应）：',
#   'position': 825,
#   'type': 'paragraph'},
#  {'content': '', 'position': 826, 'type': 'paragraph'},
#  {'content': '', 'position': 828, 'type': 'paragraph'},
#  {'content': '投标人名称（公章）： 法定代表人或被授权代表(签字或盖章)： 日 期：',
#   'position': 829,
#   'type': 'paragraph'},
#  {'content': '', 'position': 830, 'type': 'paragraph'},
#  {'content': '附件 13 投标人认为必要的其他证明文件', 'position': 831, 'type': 'paragraph'},
#  {'content': '', 'position': 832, 'type': 'paragraph'},
#  {'content': '', 'position': 833, 'type': 'paragraph'},
#  {'content': '附件 14 技术规格偏离表', 'position': 834, 'type': 'paragraph'},
#  {'content': '投标人名称： （公章） 项目编号：', 'position': 835, 'type': 'paragraph'},
#  {'content': '', 'position': 836, 'type': 'paragraph'},
#  {'content': '', 'position': 838, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表（签字或盖章）：', 'position': 839, 'type': 'paragraph'},
#  {'content': '注：1、投标人的技术偏差必须如实填写，并应对偏差情况做出必要说明。投标 '
#              '人应对故意隐瞒技术偏差的行为承担责任。对招标文件有任何偏离应列 明“正偏离”或“负偏离”。',
#   'position': 840,
#   'type': 'paragraph'},
#  {'content': '2、对招标文件无偏离应标明“无偏离”。', 'position': 841, 'type': 'paragraph'},
#  {'content': '', 'position': 842, 'type': 'paragraph'},
#  {'content': '附件 15 商务条款偏离表', 'position': 843, 'type': 'paragraph'},
#  {'content': '投标人名称： （公章） 项目编号：', 'position': 844, 'type': 'paragraph'},
#  {'content': '', 'position': 845, 'type': 'paragraph'},
#  {'content': '', 'position': 847, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表（签字或盖章）：', 'position': 848, 'type': 'paragraph'},
#  {'content': '注：1、投标人如果对包括交货期、付款方式/条件、保质期及合同条款在内的 '
#              '商务条款的响应有任何偏离，请在本表中详细填写；对招标文件有任何 偏离应列明“正偏离”或“负偏离”。',
#   'position': 849,
#   'type': 'paragraph'},
#  {'content': '2、对招标文件无偏离应标明“无偏离”。', 'position': 850, 'type': 'paragraph'},
#  {'content': '', 'position': 851, 'type': 'paragraph'},
#  {'content': '', 'position': 852, 'type': 'paragraph'},
#  {'content': '附件 16 拟投入本项目的人员配备表', 'position': 853, 'type': 'paragraph'},
#  {'content': '', 'position': 854, 'type': 'paragraph'},
#  {'content': '', 'position': 855, 'type': 'paragraph'},
#  {'content': '项目名称： 项目编号：', 'position': 856, 'type': 'paragraph'},
#  {'content': '', 'position': 857, 'type': 'paragraph'},
#  {'content': '注：本表后附拟投入主要管理人和主要技术人员的社保证明（近半年内任意一个月 的证明材料）复印件加盖公章。',
#   'position': 859,
#   'type': 'paragraph'},
#  {'content': '', 'position': 860, 'type': 'paragraph'},
#  {'content': '', 'position': 861, 'type': 'paragraph'},
#  {'content': '', 'position': 862, 'type': 'paragraph'},
#  {'content': '', 'position': 863, 'type': 'paragraph'},
#  {'content': '', 'position': 864, 'type': 'paragraph'},
#  {'content': '投标人名称（公章）： 法定代表人或授权代表(签字或印章)：',
#   'position': 865,
#   'type': 'paragraph'},
#  {'content': '日 期：', 'position': 866, 'type': 'paragraph'},
#  {'content': '', 'position': 867, 'type': 'paragraph'},
#  {'content': '附件 17 中标服务费承诺书', 'position': 868, 'type': 'paragraph'},
#  {'content': '', 'position': 869, 'type': 'paragraph'},
#  {'content': '', 'position': 870, 'type': 'paragraph'},
#  {'content': '', 'position': 871, 'type': 'paragraph'},
#  {'content': '', 'position': 872, 'type': 'paragraph'},
#  {'content': '', 'position': 873, 'type': 'paragraph'},
#  {'content': '', 'position': 874, 'type': 'paragraph'},
#  {'content': '致：北京中外建工程管理有限公司：', 'position': 875, 'type': 'paragraph'},
#  {'content': '', 'position': 876, 'type': 'paragraph'},
#  {'content': '', 'position': 877, 'type': 'paragraph'},
#  {'content': '', 'position': 878, 'type': 'paragraph'},
#  {'content': '我们在贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节物资 采购项目（第一包： 一级压榨花生油） '
#              '招标项目中若获中标（项目编号： DLXM-2024-148-01），我们保证在签订经济合同的同时按招标文件的规定，以支 '
#              '票、汇票或现金， 向贵公司即北京中外建工程管理有限公司（地址：北京市丰台 区福宜街 5 号院 1 号楼新时代国际中心 A 座 '
#              '15 层，开户银行：中国民生银行股 份有限公司北京丽泽商务区支行，账号：619201915），一次性支付应该缴纳的 '
#              '中标服务费用。代理服务费支付按照招标文件中规定的标准执行。',
#   'position': 879,
#   'type': 'paragraph'},
#  {'content': '', 'position': 880, 'type': 'paragraph'},
#  {'content': '', 'position': 881, 'type': 'paragraph'},
#  {'content': '', 'position': 882, 'type': 'paragraph'},
#  {'content': '特此承诺！', 'position': 883, 'type': 'paragraph'},
#  {'content': '', 'position': 884, 'type': 'paragraph'},
#  {'content': '', 'position': 885, 'type': 'paragraph'},
#  {'content': '', 'position': 886, 'type': 'paragraph'},
#  {'content': '承诺方法定名称（盖章）： 承诺方授权代表（签字）： 地址：',
#   'position': 887,
#   'type': 'paragraph'},
#  {'content': '电话： 传真： 电传： 邮编： 承诺日期：', 'position': 888, 'type': 'paragraph'},
#  {'content': '', 'position': 889, 'type': 'paragraph'},
#  {'content': '附件 18 关于投标保证金的声明', 'position': 890, 'type': 'paragraph'},
#  {'content': '', 'position': 891, 'type': 'paragraph'},
#  {'content': '', 'position': 892, 'type': 'paragraph'},
#  {'content': '致：北京中外建工程管理有限公司', 'position': 893, 'type': 'paragraph'},
#  {'content': '', 'position': 894, 'type': 'paragraph'},
#  {'content': '', 'position': 895, 'type': 'paragraph'},
#  {'content': '我单位参与贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油），项目编号 '
#              'DLXM-2024-148-01。在 招投标活动结束后，请将投标保证金退至我单位以下账户：',
#   'position': 896,
#   'type': 'paragraph'},
#  {'content': '户 名： 开 户 行： 行 号： 账 号： 为此，我单位声明：',
#   'position': 897,
#   'type': 'paragraph'},
#  {'content': '以上账户信息真实有效，如我单位相关信息在此期间内发生变更，我单位负 '
#              '责及时通知贵公司。如由于填写信息不实、内容不清晰、我单位信息变更而未及 '
#              '时告知贵公司等问题，引发的退还保证金延误等问题，后果由我单位自行承担。',
#   'position': 898,
#   'type': 'paragraph'},
#  {'content': '', 'position': 899, 'type': 'paragraph'},
#  {'content': '', 'position': 900, 'type': 'paragraph'},
#  {'content': '投标人名称（盖章）：', 'position': 901, 'type': 'paragraph'},
#  {'content': '', 'position': 902, 'type': 'paragraph'},
#  {'content': '', 'position': 903, 'type': 'paragraph'},
#  {'content': '日期： 年 月 日', 'position': 904, 'type': 'paragraph'},
#  {'content': '', 'position': 905, 'type': 'paragraph'},
#  {'content': '', 'position': 906, 'type': 'paragraph'},
#  {'content': '', 'position': 907, 'type': 'paragraph'},
#  {'content': '注：1.此笔款项为本次招标项目的投标保证金。', 'position': 908, 'type': 'paragraph'},
#  {'content': '2.本声明须加盖投标人公章或财务专用章，并请勿加盖在银行信息上。',
#   'position': 909,
#   'type': 'paragraph'},
#  {'content': '3.此声明需与投标文件一并递交（请勿装订在投标文件中，需单独密封）。',
#   'position': 910,
#   'type': 'paragraph'},
#  {'content': '', 'position': 911, 'type': 'paragraph'},
#  {'content': '附件 19 开标会声明书', 'position': 912, 'type': 'paragraph'},
#  {'content': '关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目 （第一包：一级压榨花生油）开标会的声明书',
#   'position': 913,
#   'type': 'paragraph'},
#  {'content': '', 'position': 914, 'type': 'paragraph'},
#  {'content': '致：北京中外建工程管理有限公司', 'position': 915, 'type': 'paragraph'},
#  {'content': '', 'position': 916, 'type': 'paragraph'},
#  {'content': '', 'position': 917, 'type': 'paragraph'},
#  {'content': '', 'position': 918, 'type': 'paragraph'},
#  {'content': '本单位 （投标人名称） 关于北京京铁运恒采购供应站有限公司 2024 '
#              '年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： 2024 年 4 月 11 日 09 时 00 '
#              '分前通过 快递 方式（快递单号： ）递 交至开标地点，如投标文件、样品及本声明书未在递交截止时间前送达指定地点 '
#              '的，我单位默认放弃本次投标，并承担由此产生的一切后果。',
#   'position': 919,
#   'type': 'paragraph'},
#  {'content': '本单位 （投标人名称） 不参加 北京京铁运恒采购供应站有限公司 2024 '
#              '年端午节物资采购项目（第一包：一级压榨花生油）现场开标活动，承诺 认可开标过程以及由本项目招标人代为签署的一切过程文件。',
#   'position': 920,
#   'type': 'paragraph'},
#  {'content': '本单位以腾讯会议的方式参加北京京铁运恒采购供应站有限公司 2024 年端 '
#              '午节物资采购项目（第一包：一级压榨花生油）的开标活动，如因自身原因未能 '
#              '准时进入视频会场，我单位承诺认可本项目开标的全过程，并确认开标全部内容。',
#   'position': 921,
#   'type': 'paragraph'},
#  {'content': '特此声明！', 'position': 922, 'type': 'paragraph'},
#  {'content': '', 'position': 923, 'type': 'paragraph'},
#  {'content': '投标人名称：（公章）', 'position': 924, 'type': 'paragraph'},
#  {'content': '', 'position': 925, 'type': 'paragraph'},
#  {'content': '法定代表人或被授权代表(签字或盖章)： 年 月 日', 'position': 926, 'type': 'paragraph'}]
