# %% [markdown]
# #### 前期准备

# %%
# 获取当前notebook的绝对路径
import sys, os
from pathlib import Path
from pprint import pprint
from IPython.display import display, Markdown, HTML
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[4]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/clients/tiptap/tools/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
#project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2

# %%
from app.services.structuring.cache import Cache
cache = Cache(project_id)
raw_document = await cache.get_document('raw_document')
h1_document = await cache.get_document('h1_document')
h2h3_document = await cache.get_document('h2h3_document')
intro_document = await cache.get_document('intro_document')
final_document = await cache.get_document('final_document')
# Out:
# Redis连接成功
# 获取文档数据失败 final_document: cannot access local variable 'e' where it is not associated with a value

# %%
print("raw_document:",type(raw_document), len(raw_document))
print("h1_document:",type(h1_document), len(h1_document))
print("h2h3_document:",type(h2h3_document), len(h2h3_document))
print("intro_document:",type(intro_document), len(intro_document))
# print("final_document:",type(final_document), len(final_document))
# Out:
# raw_document: <class 'dict'> 2
# h1_document: <class 'dict'> 2
# h2h3_document: <class 'dict'> 2
# intro_document: <class 'dict'> 2

# %% [markdown]
# #### 验证 get_table_nodes_with_position

# %%
from app.clients.tiptap.tools import get_table_nodes_with_position
tables = get_table_nodes_with_position(raw_document)
print(len(tables))
from pprint import pprint
pprint(tables)
# Out:
# 24
# [{'node': {'content': [{'content': [{'attrs': {'colspan': 1,
#                                                'colwidth': None,
#                                                'rowspan': 1},
#                                      'content': [{'attrs': {'textAlign': 'left'},
#                                                   'content': [{'marks': [{'type': 'bold'}],
#                                                                'text': '招标内容',
#                                                                'type': 'text'}],
#                                                   'type': 'paragraph'}],
#                                      'type': 'tableCell'},
#                                     {'attrs': {'colspan': 1,
#                                                'colwidth': None,
#                                                'rowspan': 1},
#                                      'content': [{'attrs': {'textAlign': 'left'},
# ...

# %% [markdown]
# #### 验证 turn_tables_to_md_with_position

# %%
from app.clients.tiptap.tools import turn_tables_to_md_with_position
tables_md = await turn_tables_to_md_with_position(tables)
print(len(tables_md))
from pprint import pprint
pprint(tables_md)
# Out:
# 24
# [{'content': '| 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n'
#              '| --- | --- | --- | --- | --- |\n'
#              '| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 |',
#   'position': 83,
#   'type': 'table'},
#  {'content': '| 招标内容 | 规格 | 数量（桶） |\n'
#              '| --- | --- | --- |\n'
#              '| 一级压榨花生油 | 5L/桶 | 160000 |',
#   'position': 139,
#   'type': 'table'},
#  {'content': '| 指标项目 | 标准要求 |\n| --- | --- |',
#   'position': 144,
#   'type': 'table'},
#  {'content': '| 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n'
#              '| --- | --- |\n'
#              '| 色泽 | 淡黄色至橙黄色 |\n'
#              '| 透明度（20℃) | 澄清、透明 |\n'
#              '| 酸价(mg/g) | ≤1.5mg/g |\n'
#              '| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n'
#              '| 加热试验(280℃) | 无析出物，油色不得变深 |\n'
#              '| 水分及挥发物(％) | ≤0.1% |\n'
#              '| 不溶性杂质(％) | ≤0.05% |\n'
#              '| 溶剂残留(mg/kg) | 不得检出 |\n'
# ...

# %% [markdown]
# #### 验证 get_table_md_with_position

# %%
from app.clients.tiptap.tools import get_table_md_with_position
tables_md = await get_table_md_with_position(raw_document)
print(len(tables_md))
from pprint import pprint
pprint(tables_md)
# Out:
# 24
# [{'content': '| 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n'
#              '| --- | --- | --- | --- | --- |\n'
#              '| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 |',
#   'position': 83,
#   'type': 'table'},
#  {'content': '| 招标内容 | 规格 | 数量（桶） |\n'
#              '| --- | --- | --- |\n'
#              '| 一级压榨花生油 | 5L/桶 | 160000 |',
#   'position': 139,
#   'type': 'table'},
#  {'content': '| 指标项目 | 标准要求 |\n| --- | --- |',
#   'position': 144,
#   'type': 'table'},
#  {'content': '| 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n'
#              '| --- | --- |\n'
#              '| 色泽 | 淡黄色至橙黄色 |\n'
#              '| 透明度（20℃) | 澄清、透明 |\n'
#              '| 酸价(mg/g) | ≤1.5mg/g |\n'
#              '| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n'
#              '| 加热试验(280℃) | 无析出物，油色不得变深 |\n'
#              '| 水分及挥发物(％) | ≤0.1% |\n'
#              '| 不溶性杂质(％) | ≤0.05% |\n'
#              '| 溶剂残留(mg/kg) | 不得检出 |\n'
# ...

# %% [markdown]
# #### 验证 update_table_column_from_dict

# %%
from app.services.planning.step_funcs.preparation_for_planning import PreparationForPlanning
preparation_for_planning = PreparationForPlanning(project_id)
checklist = await preparation_for_planning.get_inspection_checklist()
print(type(checklist))
pprint(checklist)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'level': 1, 'textAlign': 'left'},
#               'content': [{'text': '📋 招标文件内容定位清单', 'type': 'text'}],
#               'type': 'heading'},
#              {'content': [{'attrs': {'textAlign': 'left'},
#                            'content': [{'marks': [{'type': 'bold'}],
#                                         'text': '使用说明',
#                                         'type': 'text'},
#                                        {'text': '：按清单逐项查找并记录章节位置，标记找不到的项目（可能不适用），重点关注A、B级信息',
#                                         'type': 'text'}],
#                            'type': 'paragraph'}],
#               'type': 'blockquote'},
#              {'type': 'horizontalRule'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '🚨 A级：投标决策必需信息', 'type': 'text'}],
#               'type': 'heading'},
#              {'content': [{'content': [{'attrs': {'colspan': 1,
# ...

# %%
type_dict = {
    "A1": "第一章，招标公告",
    "A2": "第二章，投标邀请",
    "B1": "第三章，投标人须知",
    "B2": "第四章，投标人须知前附表",
    "C1": "第五章，评标办法",
    "C3": "第六章，合同条款及格式",
    "E3": "第七章，项目需求",
}

# %%
from app.clients.tiptap.tools import update_all_tables_column_from_dict
updated_tiptap_doc = update_all_tables_column_from_dict(
    tiptap_doc=checklist, 
    dict_value=type_dict,
    key_col_index=0,
    value_col_index=3
)

from app.clients.tiptap.client import TiptapClient
updated_tiptap_doc_md = await TiptapClient().json_to_markdown(updated_tiptap_doc)
print(type(updated_tiptap_doc_md))
display(Markdown(updated_tiptap_doc_md))
# Out:
# <class 'str'>
# # 📋 招标文件内容定位清单
#
# > **使用说明**：按清单逐项查找并记录章节位置，标记找不到的项目（可能不适用），重点关注A、B级信息
#
# ---
#
# ## 🚨 A级：投标决策必需信息
#
# | 序号 | 信息类别 | 具体内容 | 所在章节 | 分析进展 |
# | --- | --- | --- | --- | --- |
# | A1 | ⏰ 时间节点 | 投标截止时间/开标时间 | 第一章，招标公告 |  |
# | A2 | 💰 保证金 | 投标保证金金额/缴纳方式 | 第二章，投标邀请 |  |
# | A3 | 💵 预算信息 | 项目预算/最高限价/控制价 |  |  |
# | A4 | 📜 资格要求 | 企业资质/业绩/人员/财务 |  |  |
# | A5 | 📊 评分标准 | 评分标准和权重分配 |  |  |
# | A6 | 📝 项目概况 | 项目基本信息（名称/地点/规模） |  |  |
# | A7 | ✅ 中标条件 | 中标条件/废标条件 |  |  |
#
# ---
#
# ## 🔧 B级：方案制定核心信息
#
# | 序号 | 信息类别 | 具体内容 | 所在章节 | 分析进展 |
# | --- | --- | --- | --- | --- |
# | B1 | 🛠️ 技术要求 | 技术要求/功能规格书 | 第三章，投标人须知 |  |
# | B2 | 📈 性能指标 | 性能指标/技术参数 | 第四章，投标人须知前附表 |  |
# | B3 | 📅 实施周期 | 项目实施周期/交付时间 |  |  |
# | B4 | ✔️ 验收标准 | 验收标准/测试要求 |  |  |
# | B5 | 📋 商务条款 | 商务条款/合同条件 |  |  |
# | B6 | 💳 付款方式 | 付款方式/付款节点 |  |  |
# | B7 | 🛡️ 质保要求 | 质保期/维保要求 |  |  |
# | B8 | 🔒 知识产权 | 知识产权要求 |  |  |
#
# ---
#
# ## 📄 C级：投标文件制作要求
#
# | 序号 | 信息类别 | 具体内容 | 所在章节 | 分析进展 |
# | --- | --- | --- | --- | --- |
# ...

# %% [markdown]
# #### 验证 print_defined_tables_columns

# %%
from app.services.planning.profs.checklists_keyinfo import get_checklist_keyinfo, get_example
checklist_md = get_checklist_keyinfo()
example_md = get_example()

# %%
from app.services.planning.profs.checklists_keyinfo import get_checklist_keyinfo, get_example
checklist_md = get_checklist_keyinfo()
from app.clients.tiptap.client import TiptapClient
tiptap_client = TiptapClient()
checklist_json = await tiptap_client.markdown_to_json(checklist_md)
print(type(checklist_json))
pprint(checklist_json)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'level': 1, 'textAlign': 'left'},
#               'content': [{'text': '📋 招标文件内容定位清单', 'type': 'text'}],
#               'type': 'heading'},
#              {'content': [{'attrs': {'textAlign': 'left'},
#                            'content': [{'marks': [{'type': 'bold'}],
#                                         'text': '使用说明',
#                                         'type': 'text'},
#                                        {'text': '：按清单逐项查找并记录章节位置，标记找不到的项目（可能不适用），重点关注A、B级信息',
#                                         'type': 'text'}],
#                            'type': 'paragraph'}],
#               'type': 'blockquote'},
#              {'type': 'horizontalRule'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '🚨 A级：投标决策必需信息', 'type': 'text'}],
#               'type': 'heading'},
#              {'content': [{'content': [{'attrs': {'colspan': 1,
# ...

# %%
from app.clients.tiptap.tools import print_defined_tables_columns
printed_columns = print_defined_tables_columns(checklist_json)
print(printed_columns)
# Out:
# A1: 投标截止时间/开标时间
# A2: 投标保证金金额/缴纳方式
# A3: 项目预算/最高限价/控制价
# A4: 企业资质/业绩/人员/财务
# A5: 评分标准和权重分配
# A6: 项目基本信息（名称/地点/规模）
# A7: 中标条件/废标条件
# B1: 技术要求/功能规格书
# B2: 性能指标/技术参数
# B3: 项目实施周期/交付时间
# B4: 验收标准/测试要求
# B5: 商务条款/合同条件
# B6: 付款方式/付款节点
# B7: 质保期/维保要求
# B8: 知识产权要求
# C1: 投标文件格式/装订要求
# C2: 技术标编制要求
# C3: 商务标编制要求
# C4: 资格标编制要求
# C5: 需要提供的证明材料清单
# C6: 投标文件份数要求
# D1: 实施地点/工作环境
# D2: 人员进场要求
# D3: 安全/保密要求
# D4: 培训要求
# D5: 接口对接要求
# D6: 项目管理要求
# E1: 现场踏勘安排
# E2: 答疑澄清安排
# E3: 联系人/联系方式
# E4: 投标地点/开标地点
# E5: 特殊规定/注意事项
