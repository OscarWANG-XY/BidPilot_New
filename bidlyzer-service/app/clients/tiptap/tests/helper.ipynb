# %%
# 获取当前notebook的绝对路径
import sys, os
from pathlib import Path
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[3]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/clients/tiptap/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
#project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2

# %%
from app.services.structuring.cache import Cache
cache = Cache(project_id)
raw_document = await cache.get_document('raw_document')
print(raw_document)
print(type(raw_document))
from pprint import pprint
pprint(raw_document)
# Out:
# Redis连接成功
# {'type': 'doc', 'content': [{'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '北京京铁运恒采购供应站有限公司', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '2024', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '年端午节物资采购项目', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '招标文件', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '项目名称', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': '：', 'type': 'text'}, {'text': '北京京铁运恒采购供应站有限公司', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '2024', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '年端午节', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '物资采购项目（第一包：一级压榨花生油）', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '项目编号：DLXM-2024-148-01', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '招', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '标', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '人：北京京铁运恒采购供应站有限公司', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '代理机构：北京中外建工程管理有限公司', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '2024', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '年', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '3', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '月', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '目', 'type': 'text', 'marks': [{'type': 'bold'}]}, {'text': ' ', 'type': 'text'}, {'text': '录', 'type': 'text', 'marks': [{'type': 'bold'}]}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'text': '第一章', 'type': 'text', 'marks': [{'type': 'link', 'attrs': {'rel': 'noopener noreferrer nofollow' ...
# <class 'dict'>
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招标文件',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目名称',
#                            'type': 'text'},
#                           {'text': '：', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目编号：DLXM-2024-148-01',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '标',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '人：北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '代理机构：北京中外建工程管理有限公司',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '3',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '月',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '目',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '录',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第一章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标公告 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '2',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第二章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标需求 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '5',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第三章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标人须知 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark8',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '前附表 8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark10',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '一、总则 12',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark12',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '二、招标文件 13',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark14',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '三、投标文件的编制 14',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark16',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '四、开标 18',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark18',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '五、评标 19',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark20',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '六、定标 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark22',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '七、合同授予 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark24',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '八、履约保证金 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark26',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '九、招标代理服务费的收取 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第四章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '评标办法及评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '22',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark30',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件一：资格审查表 25',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark32',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件二：符合性审查表 26',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件三：评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '错误!未定义书签。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第五章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '合同条款及格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第六章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标文件格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark39',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 1 投标函 43',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark41',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 2 投标保证书 44',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark43',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 3 无违法记录声明 45',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark45',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 4 法定代表人授权书 46',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark47',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 5 投标人情况简介 47',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark49',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 '
#                                    '48',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark51',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 7 投标一览表 49',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark53',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 8 分项报价表 50',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark55',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 9 投标方案 51',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark57',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 10 投标人资格声明 52',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark59',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 11 资格证明文件 53',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark61',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 12 与投标人存在“关系”的其他法人单位信息 54',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark63',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 13 投标人认为必要的其他证明文件 55',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark65',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 14 技术规格偏离表 56',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark67',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 15 商务条款偏离表 57',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark69',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 16 拟投入本项目的人员配备表 58',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark71',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 17 中标服务费承诺书 59',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark73',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 18 关于投标保证金的声明 60',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark75',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 19 开标会声明书 61',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '第一章',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '招标公告',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#                                    '北京中外建工程管理有限公司受招标人委托，就',
#                            'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'},
#                           {'text': '进行 国内公开招标采购，欢迎合格的投标人前来投标。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '一、项目编号：DLXM-2024-148-01',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '二、', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '采购组织类型：',
#                            'type': 'text'},
#                           {'text': '委托代理', 'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '三、采购方式：',
#                            'type': 'text'},
#                           {'text': '公开招标', 'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '四、招标最高限价：1840',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '万元',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '五、采购内容、数量及简要技术要求',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'content': [{'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '招标内容',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '规格',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
# ...
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '透明度（20℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '澄清、透明',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '酸价(mg/g)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤1.5mg/g',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '过氧化值(mmol/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤6.0mmol/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '加热试验(280℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '无析出物，油色不得变深',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '水分及挥发物(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.1%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不溶性杂质(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.05%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '溶剂残留(mg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不得检出',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素 '
#                                                                           'B1 '
#                                                                           '( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素总量( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'}],
#               'type': 'table'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '合同有效期内，如遇国家有关标准调整，则按新标准执行。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '*',
#                            'type': 'text'},
#                           {'text': '3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 '
#                                    '法》的规定。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '4.样品',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 '
#                                    '的样品规格不符合招标文件的，样品评分部分不得分。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#                                    '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 '
#                                    '应的质量要求或技术参数不一致，责令中标人在 24 小时内重新提供与要求相符的 '
#                                    '货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 '
#                                    '字体清晰，粘贴牢固。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.5 样品应与投标文件同时递交到指定地点（样品不退还）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '*5.',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '送达地点',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#                                    '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '*6.',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '交货时间',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 '
#                                    '标人送货计划通知为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '四、履约保证金',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 '
#                                    '保证金。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#                                    '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 '
#                                    '性退回中标人。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'}],
#  'type': 'doc'}

# %%
h2h3_document = await cache.get_document('h2h3_document')
print(type(h2h3_document))
pprint(h2h3_document)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招标文件',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目名称',
#                            'type': 'text'},
#                           {'text': '：', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目编号：DLXM-2024-148-01',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '标',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '人：北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '代理机构：北京中外建工程管理有限公司',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '3',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '月',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '目',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '录',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第一章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标公告 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '2',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第二章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标需求 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '5',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第三章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标人须知 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark8',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '前附表 8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark10',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '一、总则 12',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark12',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '二、招标文件 13',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark14',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '三、投标文件的编制 14',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark16',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '四、开标 18',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark18',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '五、评标 19',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark20',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '六、定标 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark22',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '七、合同授予 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark24',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '八、履约保证金 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark26',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '九、招标代理服务费的收取 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第四章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '评标办法及评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '22',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark30',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件一：资格审查表 25',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark32',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件二：符合性审查表 26',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件三：评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '错误!未定义书签。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第五章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '合同条款及格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第六章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标文件格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark39',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 1 投标函 43',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark41',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 2 投标保证书 44',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark43',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 3 无违法记录声明 45',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark45',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 4 法定代表人授权书 46',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark47',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 5 投标人情况简介 47',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark49',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 '
#                                    '48',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark51',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 7 投标一览表 49',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark53',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 8 分项报价表 50',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark55',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 9 投标方案 51',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark57',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 10 投标人资格声明 52',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark59',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 11 资格证明文件 53',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark61',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 12 与投标人存在“关系”的其他法人单位信息 54',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark63',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 13 投标人认为必要的其他证明文件 55',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark65',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 14 技术规格偏离表 56',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark67',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 15 商务条款偏离表 57',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark69',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 16 拟投入本项目的人员配备表 58',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark71',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 17 中标服务费承诺书 59',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark73',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 18 关于投标保证金的声明 60',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark75',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 19 开标会声明书 61',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'level': 1, 'textAlign': 'left'},
#               'content': [{'text': '第一章 招标公告', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#                                    '北京中外建工程管理有限公司受招标人委托，就',
#                            'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'},
#                           {'text': '进行 国内公开招标采购，欢迎合格的投标人前来投标。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '项目编号', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购组织类型', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购方式', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '招标最高限价', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购内容、数量及简要技术要求', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'content': [{'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '招标内容',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '规格',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '数量',
#                                                                   'type': 'text'},
#                                                                  {'text': ' ',
#                                                                   'type': 'text'},
#                                                                  {'marks': [{'type': 'bold'}],
#                                                                   'text': '（桶）',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '最高预算单价',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '(含税价)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '交货时间',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '一级压榨花 '
#                                                                           '生油',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '5L/桶',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '160000',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
# ...
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '淡黄色至橙黄色',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '透明度（20℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '澄清、透明',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '酸价(mg/g)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤1.5mg/g',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '过氧化值(mmol/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤6.0mmol/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '加热试验(280℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '无析出物，油色不得变深',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '水分及挥发物(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.1%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不溶性杂质(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.05%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '溶剂残留(mg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不得检出',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素 '
#                                                                           'B1 '
#                                                                           '( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素总量( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'}],
#               'type': 'table'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '合同有效期内，如遇国家有关标准调整，则按新标准执行。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '*',
#                            'type': 'text'},
#                           {'text': '3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 '
#                                    '法》的规定。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '4.样品', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 '
#                                    '的样品规格不符合招标文件的，样品评分部分不得分。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#                                    '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 '
#                                    '应的质量要求或技术参数不一致，责令中标人在 24 小时内重新提供与要求相符的 '
#                                    '货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 '
#                                    '字体清晰，粘贴牢固。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.5 样品应与投标文件同时递交到指定地点（样品不退还）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '*5. 送达地点', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#                                    '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '*6. 交货时间', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 '
#                                    '标人送货计划通知为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '四、履约保证金', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 '
#                                    '保证金。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#                                    '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 '
#                                    '性退回中标人。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'}],
#  'type': 'doc'}

# %%
intro_document = await cache.get_document('intro_document')
print(type(intro_document))
pprint(intro_document)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招标文件',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目名称',
#                            'type': 'text'},
#                           {'text': '：', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '项目编号：DLXM-2024-148-01',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '招',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '标',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '人：北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '代理机构：北京中外建工程管理有限公司',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '3',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '月',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '目',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '录',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第一章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标公告 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark2',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '2',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第二章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '招标需求 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark4',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '5',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第三章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标人须知 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark6',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark8',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '前附表 8',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark10',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '一、总则 12',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark12',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '二、招标文件 13',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark14',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '三、投标文件的编制 14',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark16',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '四、开标 18',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark18',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '五、评标 19',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark20',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '六、定标 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark22',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '七、合同授予 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark24',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '八、履约保证金 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark26',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '九、招标代理服务费的收取 21',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第四章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '评标办法及评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark28',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '22',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark30',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件一：资格审查表 25',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark32',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件二：符合性审查表 26',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件三：评分标准 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark33',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '错误!未定义书签。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第五章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '合同条款及格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark35',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '第六章',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': ' ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'},
#                                      {'type': 'bold'}],
#                            'text': '投标文件格式 ',
#                            'type': 'text'},
#                           {'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark37',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '31',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark39',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 1 投标函 43',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark41',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 2 投标保证书 44',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark43',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 3 无违法记录声明 45',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark45',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 4 法定代表人授权书 46',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark47',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 5 投标人情况简介 47',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark49',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 '
#                                    '48',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark51',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 7 投标一览表 49',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark53',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 8 分项报价表 50',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark55',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 9 投标方案 51',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark57',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 10 投标人资格声明 52',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark59',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 11 资格证明文件 53',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark61',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 12 与投标人存在“关系”的其他法人单位信息 54',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark63',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 13 投标人认为必要的其他证明文件 55',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark65',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 14 技术规格偏离表 56',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark67',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 15 商务条款偏离表 57',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark69',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 16 拟投入本项目的人员配备表 58',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark71',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 17 中标服务费承诺书 59',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark73',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 18 关于投标保证金的声明 60',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'attrs': {'class': 'tiptap-link',
#                                                 'href': '#bookmark75',
#                                                 'rel': 'noopener noreferrer '
#                                                        'nofollow',
#                                                 'target': '_blank'},
#                                       'type': 'link'}],
#                            'text': '附件 19 开标会声明书 61',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'level': 1, 'textAlign': 'left'},
#               'content': [{'text': '第一章 招标公告', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#                                    '北京中外建工程管理有限公司受招标人委托，就',
#                            'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目（第一包：一级压榨花生油）',
#                            'type': 'text'},
#                           {'text': '进行 国内公开招标采购，欢迎合格的投标人前来投标。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '项目编号', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购组织类型', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购方式', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '招标最高限价', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '采购内容、数量及简要技术要求', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'content': [{'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '招标内容',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '规格',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '数量',
#                                                                   'type': 'text'},
#                                                                  {'text': ' ',
#                                                                   'type': 'text'},
#                                                                  {'marks': [{'type': 'bold'}],
#                                                                   'text': '（桶）',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '最高预算单价',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '(含税价)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'marks': [{'type': 'bold'}],
#                                                                   'text': '交货时间',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '一级压榨花 '
#                                                                           '生油',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '5L/桶',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'type': 'paragraph'},
#                                                     {'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '160000',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
# ...
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '淡黄色至橙黄色',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '透明度（20℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '澄清、透明',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '酸价(mg/g)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤1.5mg/g',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '过氧化值(mmol/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤6.0mmol/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '加热试验(280℃)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '无析出物，油色不得变深',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '水分及挥发物(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.1%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不溶性杂质(％)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '≤0.05%',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '溶剂残留(mg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '不得检出',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素 '
#                                                                           'B1 '
#                                                                           '( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'},
#                           {'content': [{'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '黄曲霉毒素总量( '
#                                                                           'μg/kg)',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'},
#                                        {'attrs': {'colspan': 1,
#                                                   'colwidth': None,
#                                                   'rowspan': 1},
#                                         'content': [{'attrs': {'textAlign': 'left'},
#                                                      'content': [{'text': '<20 '
#                                                                           'μg/kg',
#                                                                   'type': 'text'}],
#                                                      'type': 'paragraph'}],
#                                         'type': 'tableCell'}],
#                            'type': 'tableRow'}],
#               'type': 'table'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '合同有效期内，如遇国家有关标准调整，则按新标准执行。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '*',
#                            'type': 'text'},
#                           {'text': '3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 '
#                                    '法》的规定。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '4.样品', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 '
#                                    '的样品规格不符合招标文件的，样品评分部分不得分。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#                                    '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 '
#                                    '应的质量要求或技术参数不一致，责令中标人在 24 小时内重新提供与要求相符的 '
#                                    '货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 '
#                                    '字体清晰，粘贴牢固。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '4.5 样品应与投标文件同时递交到指定地点（样品不退还）。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '*5. 送达地点', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#                                    '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'level': 3, 'textAlign': 'left'},
#               'content': [{'text': '*6. 交货时间', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 '
#                                    '标人送货计划通知为准。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'level': 2, 'textAlign': 'left'},
#               'content': [{'text': '四、履约保证金', 'type': 'text'}],
#               'type': 'heading'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 '
#                                    '保证金。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'text': '2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#                                    '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 '
#                                    '性退回中标人。',
#                            'type': 'text'}],
#               'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'}],
#  'type': 'doc'}

# %%
final_document = await cache.get_document('final_document')
print(type(final_document))
pprint(final_document)
# Out:
# 获取文档数据失败 final_document: cannot access local variable 'e' where it is not associated with a value
# <class 'NoneType'>
# None

# %%
final_document = intro_document

# %% [markdown]
# #### 验证 print_headings

# %%
from app.clients.tiptap.helpers import TiptapUtils
heandings = TiptapUtils.print_headings(final_document)
print(heandings[:100])
# Out:
# [H1] 第一章 招标公告
#   [H2] 项目编号
#   [H2] 采购组织类型
#   [H2] 采购方式
#   [H2] 招标最高限价
#   [H2] 采购内容、数量及简要技术要求
#   [H2] 合格投标人

# %% [markdown]
# #### 验证 find_all_headings

# %%
headings = TiptapUtils.find_all_headings(final_document)
from pprint import pprint
pprint(headings[:100])
# Out:
# [{'level': 1,
#   'node': {'attrs': {'level': 1, 'textAlign': 'left'},
#            'content': [{'text': '第一章 招标公告', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [75],
#   'title': '第一章 招标公告'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '项目编号', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [77],
#   'title': '项目编号'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购组织类型', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [78],
#   'title': '采购组织类型'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购方式', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [79],
#   'title': '采购方式'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '招标最高限价', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [80],
#   'title': '招标最高限价'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购内容、数量及简要技术要求', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [81],
#   'title': '采购内容、数量及简要技术要求'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '合格投标人的资格要求(本项目采用资格后审)', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [84],
#   'title': '合格投标人的资格要求(本项目采用资格后审)'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '招标公告的发布', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [97],
#   'title': '招标公告的发布'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '招标文件的发售', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [99],
#   'title': '招标文件的发售'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '投标保证金', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [107],
#   'title': '投标保证金'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '投标截止时间和地点', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [111],
#   'title': '投标截止时间和地点'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '开标时间及地点', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [115],
#   'title': '开标时间及地点'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '评标办法', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [118],
#   'title': '评标办法'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '业务咨询', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [119],
#   'title': '业务咨询'},
#  {'level': 1,
#   'node': {'attrs': {'level': 1, 'textAlign': 'left'},
#            'content': [{'text': '第二章 招标需求', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [129],
#   'title': '第二章 招标需求'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2},
#            'content': [{'text': '前言', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [130],
#   'title': '前言'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '一、概述', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [131],
#   'title': '一、概述'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '二、采购内容', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [138],
#   'title': '二、采购内容'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '三、技术和质量要求', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [141],
#   'title': '三、技术和质量要求'},
#  {'level': 3,
#   'node': {'attrs': {'level': 3, 'textAlign': 'left'},
#            'content': [{'text': '2.花生油主要技术参数', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [143],
#   'title': '2.花生油主要技术参数'},
#  {'level': 3,
#   'node': {'attrs': {'level': 3, 'textAlign': 'left'},
#            'content': [{'text': '4.样品', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [152],
#   'title': '4.样品'},
#  {'level': 3,
#   'node': {'attrs': {'level': 3, 'textAlign': 'left'},
#            'content': [{'text': '*5. 送达地点', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [158],
#   'title': '*5. 送达地点'},
#  {'level': 3,
#   'node': {'attrs': {'level': 3, 'textAlign': 'left'},
#            'content': [{'text': '*6. 交货时间', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [160],
#   'title': '*6. 交货时间'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '四、履约保证金', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [163],
#   'title': '四、履约保证金'}]

# %% [markdown]
# #### 验证 extract_tables_to_markdown

# %% [markdown]
# <font color="orange" size="3">
# 这里有有两个注意点：<br>
# 1. 因为调用了tiptap_client.json_to_markdown， 所以整个函数必须是异步<br>
# 2. _make_request()里已经处理 ['data'] 了，所以这里不需要再处理, result.strip() 就可以了<br>
# </font>

# %%
md_tables = await TiptapUtils.extract_tables_to_markdown(final_document)
print(md_tables)
pprint(md_tables)
# Out:
# ([{'markdown': 'index:0\n | 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n| --- | --- | --- | --- | --- |\n| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | '}, {'markdown': 'index:1\n | 招标内容 | 规格 | 数量（桶） |\n| --- | --- | --- |\n| 一级压榨花生油 | 5L/桶 | 160000 | '}, {'markdown': 'index:2\n | 指标项目 | 标准要求 |\n| --- | --- | '}, {'markdown': 'index:3\n | 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n| --- | --- |\n| 色泽 | 淡黄色至橙黄色 |\n| 透明度（20℃) | 澄清、透明 |\n| 酸价(mg/g) | ≤1.5mg/g |\n| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n| 加热试验(280℃) | 无析出物，油色不得变深 |\n| 水分及挥发物(％) | ≤0.1% |\n| 不溶性杂质(％) | ≤0.05% |\n| 溶剂残留(mg/kg) | 不得检出 |\n| 黄曲霉毒素 B1 ( μg/kg) | <20 μg/kg |\n| 黄曲霉毒素总量( μg/kg) | <20 μg/kg | '}], {0: [83], 1: [140], 2: [145], 3: [149]})
# ([{'markdown': 'index:0\n'
#                ' | 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n'
#                '| --- | --- | --- | --- | --- |\n'
#                '| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#                '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | '},
#   {'markdown': 'index:1\n'
#                ' | 招标内容 | 规格 | 数量（桶） |\n'
#                '| --- | --- | --- |\n'
#                '| 一级压榨花生油 | 5L/桶 | 160000 | '},
#   {'markdown': 'index:2\n | 指标项目 | 标准要求 |\n| --- | --- | '},
#   {'markdown': 'index:3\n'
#                ' | 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n'
#                '| --- | --- |\n'
#                '| 色泽 | 淡黄色至橙黄色 |\n'
#                '| 透明度（20℃) | 澄清、透明 |\n'
#                '| 酸价(mg/g) | ≤1.5mg/g |\n'
#                '| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n'
#                '| 加热试验(280℃) | 无析出物，油色不得变深 |\n'
#                '| 水分及挥发物(％) | ≤0.1% |\n'
#                '| 不溶性杂质(％) | ≤0.05% |\n'
#                '| 溶剂残留(mg/kg) | 不得检出 |\n'
#                '| 黄曲霉毒素 B1 ( μg/kg) | <20 μg/kg |\n'
#                '| 黄曲霉毒素总量( μg/kg) | <20 μg/kg | '}],
#  {0: [83], 1: [140], 2: [145], 3: [149]})
