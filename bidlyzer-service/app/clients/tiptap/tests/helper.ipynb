# %%
# 获取当前notebook的绝对路径
import sys, os
from pathlib import Path
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[3]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/clients/tiptap/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
#project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2

# %%
from app.services.structuring.cache import Cache
cache = Cache(project_id)
raw_document = await cache.get_document('raw_document')
print(raw_document)
print(type(raw_document))
from pprint import pprint
pprint(raw_document)
# Out:
# Redis连接成功
# ...

# %%
h2h3_document = await cache.get_document('h2h3_document')
print(type(h2h3_document))
pprint(h2h3_document)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
# ...

# %%
intro_document = await cache.get_document('intro_document')
print(type(intro_document))
pprint(intro_document)
# Out:
# <class 'dict'>
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
# ...

# %%
final_document = await cache.get_document('final_document')
print(type(final_document))
pprint(final_document)
# Out:
# 获取文档数据失败 final_document: cannot access local variable 'e' where it is not associated with a value
# <class 'NoneType'>
# None

# %%
final_document = intro_document

# %% [markdown]
# #### 验证 print_headings

# %%
from app.clients.tiptap.helpers import TiptapUtils
heandings = TiptapUtils.print_headings(final_document)
print(heandings[:100])
# Out:
# [H1] 第一章 招标公告
#   [H2] 项目编号
#   [H2] 采购组织类型
#   [H2] 采购方式
#   [H2] 招标最高限价
#   [H2] 采购内容、数量及简要技术要求
#   [H2] 合格投标人

# %% [markdown]
# #### 验证 find_all_headings

# %%
headings = TiptapUtils.find_all_headings(h2h3_document)
from pprint import pprint
pprint(headings[:100])
# Out:
# [{'level': 1,
#   'node': {'attrs': {'level': 1, 'textAlign': 'left'},
#            'content': [{'text': '第一章 招标公告', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [75],
#   'title': '第一章 招标公告'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '项目编号', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [77],
#   'title': '项目编号'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购组织类型', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [78],
#   'title': '采购组织类型'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购方式', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [79],
#   'title': '采购方式'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '招标最高限价', 'type': 'text'}],
# ...

# %% [markdown]
# #### 验证add_introduction_headings

# %%
intro_doc = TiptapUtils.add_introduction_headings(h2h3_document)
pprint(intro_doc)
# Out:
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
# ...

# %%
headings = TiptapUtils.print_headings(intro_doc)
print(headings)
# Out:
# [H1] 第一章 招标公告
#   [H2] 项目编号
#   [H2] 采购组织类型
#   [H2] 采购方式
#   [H2] 招标最高限价
#   [H2] 采购内容、数量及简要技术要求
#   [H2] 合格投标人的资格要求(本项目采用资格后审)
#   [H2] 招标公告的发布
#   [H2] 招标文件的发售
#   [H2] 投标保证金
#   [H2] 投标截止时间和地点
#   [H2] 开标时间及地点
#   [H2] 评标办法
#   [H2] 业务咨询
# [H1] 第二章 招标需求
#   [H2] 前言
#   [H2] 一、概述
#   [H2] 二、采购内容
#   [H2] 三、技术和质量要求
#     [H3] 2.花生油主要技术参数
#     [H3] 4.样品
#     [H3] *5. 送达地点
#     [H3] *6. 交货时间
#   [H2] 四、履约保证金
# [H1] 第三章 投标人须知
#   [H2] 一、总则
#     [H3] 前言
#     [H3] （一）适用范围
#     [H3] （二） 定义
#     [H3] （三） 招标方式
#     [H3] （四）投标委托
#     [H3] （五） 踏勘现场（本项目不适用）和投标费用
#     [H3] （六） 联合体投标
#     [H3] （七）转包
#     [H3] （八）、特别说明：
#     [H3] （九） 质疑和投诉
#   [H2] 二、招标文件
#     [H3] 前言
#     [H3] （一）招标文件的构成。本招标文件由以下部分组成：
#     [H3] （二） 投标人的风险
#     [H3] （三） 招标文件的澄清与修改
#     [H3] （四）、对招标文件的异议
#   [H2] 三、投标文件的编制
#     [H3] 前言
#     [H3] （一）、投标文件的组成
#     [H3] （二）、投标文件的语言及计量
#     [H3] （三）、投标报价
#     [H3] （四）、投标文件的有效期
#     [H3] （五）、投标保证金
#     [H3] （六）、投标文件的签署和份数
#     [H3] （七）、投标文件的包装、递交、修改和撤回
# ...

# %% [markdown]
# #### 验证 extract_tables_to_markdown

# %% [markdown]
# <font color="orange" size="3">
# 这里有有两个注意点：<br>
# 1. 因为调用了tiptap_client.json_to_markdown， 所以整个函数必须是异步<br>
# 2. _make_request()里已经处理 ['data'] 了，所以这里不需要再处理, result.strip() 就可以了<br>
# </font>

# %%
md_tables = await TiptapUtils.extract_tables_to_markdown(final_document)
print(md_tables)
pprint(md_tables)
# Out:
# ([{'markdown': 'index:0\n | 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n| --- | --- | --- | --- | --- |\n| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | '}, {'markdown': 'index:1\n | 招标内容 | 规格 | 数量（桶） |\n| --- | --- | --- |\n| 一级压榨花生油 | 5L/桶 | 160000 | '}, {'markdown': 'index:2\n | 指标项目 | 标准要求 |\n| --- | --- | '}, {'markdown': 'index:3\n | 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n| --- | --- |\n| 色泽 | 淡黄色至橙黄色 |\n| 透明度（20℃) | 澄清、透明 |\n| 酸价(mg/g) | ≤1.5mg/g |\n| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n| 加热试验(280℃) | 无析出物，油色不得变深 |\n| 水分及挥发物(％) | ≤0.1% |\n| 不溶性杂质(％) | ≤0.05% |\n| 溶剂残留(mg/kg) | 不得检出 |\n| 黄曲霉毒素 B1 ( μg/kg) | <20 μg/kg |\n| 黄曲霉毒素总量( μg/kg) | <20 μg/kg | '}, {'markdown': 'index:4\n | 序号 | 内容、要求 |\n| --- | --- |\n| 1 | 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油） |\n| 2 | 采购数量及单位：一级压榨花生油 160000 桶（5L/桶） |\n| *3 | 投标报价及费用：1 、具体供应货物价格须包含但不限于货物成本、包装、检验检测费、运输费（送 货到招标人指定地点）、保险费、装卸费、利润、税金、政策性规费、售后服务 等所有中标人应承担的全部费用。2 、不论投标结果如何，投标人均应自行承担所有与投标有关的全部费用。其它：1、招标代理服务
# ...
