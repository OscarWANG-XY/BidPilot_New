# %%
# 获取当前notebook的绝对路径
import sys, os
from pathlib import Path
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[3]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/clients/tiptap/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
#project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2

# %%
from app.services.planning.step_funcs.get_structure_context import GetStructureContext
structure_context = GetStructureContext(project_id)
final_document = await structure_context._get_final_document()
print(final_document)
print(type(final_document))
# Out:
# Redis连接成功
# ...

# %%
from pprint import pprint
pprint(final_document)
# Out:
# {'content': [{'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#              {'attrs': {'textAlign': 'left'},
#               'content': [{'marks': [{'type': 'bold'}],
#                            'text': '北京京铁运恒采购供应站有限公司',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '2024',
#                            'type': 'text'},
#                           {'text': ' ', 'type': 'text'},
#                           {'marks': [{'type': 'bold'}],
#                            'text': '年端午节物资采购项目',
#                            'type': 'text'}],
# ...

# %% [markdown]
# ## Nodes Tools

# %% [markdown]
# #### 验证 extract_text_from_node

# %%
from app.clients.tiptap.tools import extract_text_from_node
text = extract_text_from_node(final_document)
print(text)
print(len(text))
# Out:
# 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目招标文件项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油）项目编号：DLXM-2024-148-01招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司2024 年 3 月目 录第一章 招标公告 2第二章 招标需求 5第三章 投标人须知 8前附表 8一、总则 12二、招标文件 13三、投标文件的编制 14四、开标 18五、评标 19六、定标 21七、合同授予 21八、履约保证金 21九、招标代理服务费的收取 21第四章 评标办法及评分标准 22附件一：资格审查表 25附件二：符合性审查表 26附件三：评分标准 错误!未定义书签。第五章 合同条款及格式 31第六章 投标文件格式 31附件 1 投标函 43附件 2 投标保证书 44附件 3 无违法记录声明 45附件 4 法定代表人授权书 46附件 5 投标人情况简介 47附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 48附件 7 投标一览表 49附件 8 分项报价表 50附件 9 投标方案 51附件 10 投标人资格声明 52附件 11 资格证明文件 53附件 12 与投标人存在“关系”的其他法人单位信息 54附件 13 投标人认为必要的其他证明文件 55附件 14 技术规格偏离表 56附件 15 商务条款偏离表 57附件 16 拟投入本项目的人员配备表 58附件 17 中标服务费承诺书 59附件 18 关于投标保证金的声明 60附件 19 开标会声明书 61第一章 招标公告根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， 北京中外建工程管理有限公司受招标人委托，就北京京铁运恒采购 供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）进行 国内公开招标采购，欢迎合格的投标人前来投标。项目编号采购组织类型采购方式招标最高限价采购内容、数量及简要技术要求招标内容规格数量 （桶）最高预算单价(含税价)交货时间一级压榨花 生油5L/桶160000115 元/桶中标人接到中标通知书开始备 货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。合格投标人的资格要求(本项目采用资格后审)（1）
# ...

# %% [markdown]
# ## Paragraphs Tools

# %% [markdown]
# #### 验证 get_paragraph_nodes_with_position

# %%
from app.clients.tiptap.tools import get_paragraph_nodes_with_position
paragraphs = get_paragraph_nodes_with_position(final_document)
print(len(paragraphs))
from pprint import pprint
pprint(paragraphs)
# Out:
# 911
# [{'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 0,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 1,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 2,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 3,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 4,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
# ...

# %% [markdown]
# #### 验证 extract_indexed_paragraphs

# %%
from app.clients.tiptap.tools import get_paragraph_text_with_position
paragraphs = get_paragraph_text_with_position(final_document)
print(len(paragraphs))
from pprint import pprint
pprint(paragraphs)
# Out:
# 911
# [{'content': '', 'position': 0, 'type': 'paragraph'},
#  {'content': '', 'position': 1, 'type': 'paragraph'},
#  {'content': '', 'position': 2, 'type': 'paragraph'},
#  {'content': '', 'position': 3, 'type': 'paragraph'},
#  {'content': '', 'position': 4, 'type': 'paragraph'},
#  {'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#   'position': 5,
#   'type': 'paragraph'},
#  {'content': '', 'position': 6, 'type': 'paragraph'},
#  {'content': '', 'position': 7, 'type': 'paragraph'},
#  {'content': '', 'position': 8, 'type': 'paragraph'},
#  {'content': '', 'position': 9, 'type': 'paragraph'},
#  {'content': '', 'position': 10, 'type': 'paragraph'},
#  {'content': '', 'position': 11, 'type': 'paragraph'},
#  {'content': '', 'position': 12, 'type': 'paragraph'},
#  {'content': '招标文件', 'position': 13, 'type': 'paragraph'},
#  {'content': '', 'position': 14, 'type': 'paragraph'},
#  {'content': '', 'position': 15, 'type': 'paragraph'},
# ...

# %% [markdown]
# ## Table Tools

# %% [markdown]
# #### 验证 get_table_nodes_with_position

# %%
from app.clients.tiptap.tools import get_table_nodes_with_position
tables = get_table_nodes_with_position(final_document)
print(len(tables))
from pprint import pprint
pprint(tables)
# Out:
# 24
# [{'node': {'content': [{'content': [{'attrs': {'colspan': 1,
#                                                'colwidth': None,
#                                                'rowspan': 1},
#                                      'content': [{'attrs': {'textAlign': 'left'},
#                                                   'content': [{'marks': [{'type': 'bold'}],
#                                                                'text': '招标内容',
#                                                                'type': 'text'}],
#                                                   'type': 'paragraph'}],
#                                      'type': 'tableCell'},
#                                     {'attrs': {'colspan': 1,
#                                                'colwidth': None,
#                                                'rowspan': 1},
#                                      'content': [{'attrs': {'textAlign': 'left'},
# ...

# %% [markdown]
# #### 验证 turn_tables_to_md_with_position

# %%
from app.clients.tiptap.tools import turn_tables_to_md_with_position
tables_md = await turn_tables_to_md_with_position(tables)
print(len(tables_md))
from pprint import pprint
pprint(tables_md)
# Out:
# 24
# [{'content': '| 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n'
#              '| --- | --- | --- | --- | --- |\n'
#              '| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 |',
#   'position': 83,
#   'type': 'table'},
#  {'content': '| 招标内容 | 规格 | 数量（桶） |\n'
#              '| --- | --- | --- |\n'
#              '| 一级压榨花生油 | 5L/桶 | 160000 |',
#   'position': 140,
#   'type': 'table'},
#  {'content': '| 指标项目 | 标准要求 |\n| --- | --- |',
#   'position': 145,
#   'type': 'table'},
#  {'content': '| 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n'
#              '| --- | --- |\n'
#              '| 色泽 | 淡黄色至橙黄色 |\n'
#              '| 透明度（20℃) | 澄清、透明 |\n'
#              '| 酸价(mg/g) | ≤1.5mg/g |\n'
#              '| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n'
#              '| 加热试验(280℃) | 无析出物，油色不得变深 |\n'
#              '| 水分及挥发物(％) | ≤0.1% |\n'
#              '| 不溶性杂质(％) | ≤0.05% |\n'
#              '| 溶剂残留(mg/kg) | 不得检出 |\n'
# ...

# %% [markdown]
# #### 验证 get_table_md_with_position

# %%
from app.clients.tiptap.tools import get_table_md_with_position
tables_md = await get_table_md_with_position(final_document)
from pprint import pprint
pprint(tables_md)
# Out:
# [{'content': '| 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n'
#              '| --- | --- | --- | --- | --- |\n'
#              '| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 |',
#   'position': 83,
#   'type': 'table'},
#  {'content': '| 招标内容 | 规格 | 数量（桶） |\n'
#              '| --- | --- | --- |\n'
#              '| 一级压榨花生油 | 5L/桶 | 160000 |',
#   'position': 140,
#   'type': 'table'},
#  {'content': '| 指标项目 | 标准要求 |\n| --- | --- |',
#   'position': 145,
#   'type': 'table'},
#  {'content': '| 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n'
#              '| --- | --- |\n'
#              '| 色泽 | 淡黄色至橙黄色 |\n'
#              '| 透明度（20℃) | 澄清、透明 |\n'
#              '| 酸价(mg/g) | ≤1.5mg/g |\n'
#              '| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n'
#              '| 加热试验(280℃) | 无析出物，油色不得变深 |\n'
#              '| 水分及挥发物(％) | ≤0.1% |\n'
#              '| 不溶性杂质(％) | ≤0.05% |\n'
#              '| 溶剂残留(mg/kg) | 不得检出 |\n'
# ...

# %% [markdown]
# ## Document Tools

# %% [markdown]
# #### 验证 get_all_nodes_with_position

# %%
from app.clients.tiptap.tools import get_all_nodes_with_position
nodes = get_all_nodes_with_position(final_document)
print(len(nodes))
from pprint import pprint
pprint(nodes)
# Out:
# 935
# [{'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 0,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 1,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 2,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 3,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'}, 'type': 'paragraph'},
#   'position': 4,
#   'type': 'paragraph'},
#  {'node': {'attrs': {'textAlign': 'left'},
#            'content': [{'marks': [{'type': 'bold'}],
#                         'text': '北京京铁运恒采购供应站有限公司',
#                         'type': 'text'},
#                        {'text': ' ', 'type': 'text'},
#                        {'marks': [{'type': 'bold'}],
#                         'text': '2024',
#                         'type': 'text'},
# ...

# %% [markdown]
# #### 验证 get_paras_and_tables_md_with_position

# %%
from app.clients.tiptap.tools import get_paras_and_tables_md_with_position
document_md = await get_paras_and_tables_md_with_position(final_document)
from pprint import pprint
pprint(document_md)
# Out:
# [{'content': '', 'position': 0, 'type': 'paragraph'},
#  {'content': '', 'position': 1, 'type': 'paragraph'},
#  {'content': '', 'position': 2, 'type': 'paragraph'},
#  {'content': '', 'position': 3, 'type': 'paragraph'},
#  {'content': '', 'position': 4, 'type': 'paragraph'},
#  {'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#   'position': 5,
#   'type': 'paragraph'},
#  {'content': '', 'position': 6, 'type': 'paragraph'},
#  {'content': '', 'position': 7, 'type': 'paragraph'},
#  {'content': '', 'position': 8, 'type': 'paragraph'},
#  {'content': '', 'position': 9, 'type': 'paragraph'},
#  {'content': '', 'position': 10, 'type': 'paragraph'},
#  {'content': '', 'position': 11, 'type': 'paragraph'},
#  {'content': '', 'position': 12, 'type': 'paragraph'},
#  {'content': '招标文件', 'position': 13, 'type': 'paragraph'},
#  {'content': '', 'position': 14, 'type': 'paragraph'},
#  {'content': '', 'position': 15, 'type': 'paragraph'},
# ...

# %% [markdown]
# #### 验证 print_headings

# %%
from app.clients.tiptap.helpers import TiptapUtils
heandings = TiptapUtils.print_headings(final_document)
print(heandings[:100])
# Out:
# [H1] 第一章 招标公告
#   [H2] 项目编号
#   [H2] 采购组织类型
#   [H2] 采购方式
#   [H2] 招标最高限价
#   [H2] 采购内容、数量及简要技术要求
#   [H2] 合格投标人

# %% [markdown]
# #### 验证 find_all_headings

# %%
headings = TiptapUtils.find_all_headings(final_document)
from pprint import pprint
pprint(headings[:100])
# Out:
# [{'level': 1,
#   'node': {'attrs': {'level': 1, 'textAlign': 'left'},
#            'content': [{'text': '第一章 招标公告', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [75],
#   'title': '第一章 招标公告'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '项目编号', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [77],
#   'title': '项目编号'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购组织类型', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [78],
#   'title': '采购组织类型'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '采购方式', 'type': 'text'}],
#            'type': 'heading'},
#   'path': [79],
#   'title': '采购方式'},
#  {'level': 2,
#   'node': {'attrs': {'level': 2, 'textAlign': 'left'},
#            'content': [{'text': '招标最高限价', 'type': 'text'}],
# ...

# %% [markdown]
# #### 验证 extract_tables_to_markdown

# %% [markdown]
# <font color="orange" size="3">
# 这里有有两个注意点：<br>
# 1. 因为调用了tiptap_client.json_to_markdown， 所以整个函数必须是异步<br>
# 2. _make_request()里已经处理 ['data'] 了，所以这里不需要再处理, result.strip() 就可以了<br>
# </font>

# %%
md_tables = await TiptapUtils.extract_tables_to_markdown(final_document)
print(md_tables)
pprint(md_tables)
# Out:
# ([{'markdown': 'index:0\n | 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间 |\n| --- | --- | --- | --- | --- |\n| 一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | '}, {'markdown': 'index:1\n | 招标内容 | 规格 | 数量（桶） |\n| --- | --- | --- |\n| 一级压榨花生油 | 5L/桶 | 160000 | '}, {'markdown': 'index:2\n | 指标项目 | 标准要求 |\n| --- | --- | '}, {'markdown': 'index:3\n | 气味、滋味 | 具有花生油固有的气味和滋味，无异味 |\n| --- | --- |\n| 色泽 | 淡黄色至橙黄色 |\n| 透明度（20℃) | 澄清、透明 |\n| 酸价(mg/g) | ≤1.5mg/g |\n| 过氧化值(mmol/kg) | ≤6.0mmol/kg |\n| 加热试验(280℃) | 无析出物，油色不得变深 |\n| 水分及挥发物(％) | ≤0.1% |\n| 不溶性杂质(％) | ≤0.05% |\n| 溶剂残留(mg/kg) | 不得检出 |\n| 黄曲霉毒素 B1 ( μg/kg) | <20 μg/kg |\n| 黄曲霉毒素总量( μg/kg) | <20 μg/kg | '}, {'markdown': 'index:4\n | 序号 | 内容、要求 |\n| --- | --- |\n| 1 | 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油） |\n| 2 | 采购数量及单位：一级压榨花生油 160000 桶（5L/桶） |\n| *3 | 投标报价及费用：1 、具体供应货物价格须包含但不限于货物成本、包装、检验检测费、运输费（送 货到招标人指定地点）、保险费、装卸费、利润、税金、政策性规费、售后服务 等所有中标人应承担的全部费用。2 、不论投标结果如何，投标人均应自行承担所有与投标有关的全部费用。其它：1、招标代理服务
# ...
