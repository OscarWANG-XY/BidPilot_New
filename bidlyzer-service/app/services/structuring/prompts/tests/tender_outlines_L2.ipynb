# %%
# 获取当前notebook的绝对路径
import sys, os
# import asyncio
# import nest_asyncio
# nest_asyncio.apply()
from pathlib import Path
current_path = Path.cwd()  # 或者使用 %pwd magic命令
project_root = current_path.parents[4]  # 如果notebook在project_root/notebooks/下
print("notebook所在的路径：", current_path)
print("project_root：", project_root)
sys.path.append(str(project_root))
import FastAPI_setup
# Out:
# notebook所在的路径： /home/oscarwang/BidPilot_new/bidlyzer-service/app/services/structuring/prompts/tests
# project_root： /home/oscarwang/BidPilot_new/bidlyzer-service
# 当前环境: development
# FastAPI应用名称: Bidlyzer-Service
# API端口: 8001
# 数据库URL: postgres://postgres:123456@localhost:5432/bidpilot_new
# Redis URL: redis://:123456@localhost:6379/0
# FastAPI_setup.py 执行完毕

# %%
# project_id = "20563b61-7818-474b-9641-c40757bbd3fe"  # test1
project_id = "cc6bca8a-df5d-43d5-a931-875113df1f50"  # test2
from app.services.structuring.agent import DocumentStructureAgent
agent = DocumentStructureAgent(project_id)
h1_doc = await agent.state_manager.cache.get_document('h1_document')
print(h1_doc)
from app.clients.tiptap.helpers import TiptapUtils
heandings = TiptapUtils.print_headings(h1_doc)
print(heandings)
# Out:
# Redis连接成功
# {'type': 'doc', 'content': [{'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '北京京铁运恒采购供应站有限公司'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '2024'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '年端午节物资采购项目'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '招标文件'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '项目名称'}, {'type': 'text', 'text': '：'}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '北京京铁运恒采购供应站有限公司'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '2024'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '年端午节'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '物资采购项目（第一包：一级压榨花生油）'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '项目编号：DLXM-2024-148-01'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '招'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '标'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '人：北京京铁运恒采购供应站有限公司'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '代理机构：北京中外建工程管理有限公司'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '2024'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '年'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '3'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '月'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'bold'}], 'text': '目'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'marks': [{'type': 'bold'}], 'text': '录'}]}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}}, {'type': 'paragraph', 'attrs': {'textAlign': 'left'}, 'content': [{'type': 'text', 'marks': [{'type': 'link', 'attrs': {'href': '#bookmark2', 'target': '_blank', 'rel': 'no ...
# [H1] 第一章 招标公告
# [H1] 第二章 招标需求

# %%
from app.services.structuring.prompts.tender_outlines_L2 import TenderOutlinesL2PromptBuilder
prompt_builder = TenderOutlinesL2PromptBuilder(h1_doc)

# %%
prompt_config, task_inputs, meta = prompt_builder.output_params()
from pprint import pprint
pprint(prompt_config)
pprint(task_inputs)
pprint(meta)
# Out:
# {'llm_config': {'api_key': None,
#                 'base_url': 'https://dashscope.aliyuncs.com/compatible-mode/v1',
#                 'llm_model_name': 'qwen-max-0125',
#                 'max_workers': 4,
#                 'retry_times': 3,
#                 'streaming': True,
#                 'temperature': 0.2,
#                 'timeout': 60,
#                 'top_p': 0.6},
#  'prompt_template': '\n'
#                     '你将执行以下任务：\n'
#                     '\n'
#                     '【任务目标】\n'
#                     '{instruction}\n'
#                     '\n'
#                     '【输出格式】\n'
#                     '{output_format}\n'
#                     '\n'
#                     '以下是你将使用的内容：\n'
#                     '\n'
#                     '【材料A：主要上下文】\n'
#                     '{context}\n'
#                     '\n'
#                     '【材料B：补充信息】\n'
#                     '{supplement}\n'
#                     '\n'
#                     '请严格根据材料A和B完成任务。\n'
#                     '\n',
#  'system_role': '\n\n你是招投标领域的投标文件编写专家。\n\n'}
# [{'context': 'content: 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目 | index: 0\n'
#              'content: 招标文件 | index: 1\n'
#              'content: 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油） | '
#              'index: 2\n'
#              'content: 项目编号：DLXM-2024-148-01 | index: 3\n'
#              'content: 招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司 | index: 4\n'
#              'content: 2024 年 3 月 | index: 5\n'
#              'content: 目 录 | index: 6\n'
#              'content: 第一章 招标公告 2 | index: 7\n'
#              'content: 第二章 招标需求 5 | index: 8\n'
#              'content: 第三章 投标人须知 8 | index: 9\n'
#              'content: 前附表 8 | index: 10\n'
#              'content: 一、总则 12 | index: 11\n'
#              'content: 二、招标文件 13 | index: 12\n'
#              'content: 三、投标文件的编制 14 | index: 13\n'
#              'content: 四、开标 18 | index: 14\n'
#              'content: 五、评标 19 | index: 15\n'
#              'content: 六、定标 21 | index: 16\n'
#              'content: 七、合同授予 21 | index: 17\n'
#              'content: 八、履约保证金 21 | index: 18\n'
#              'content: 九、招标代理服务费的收取 21 | index: 19\n'
#              'content: 第四章 评标办法及评分标准 22 | index: 20\n'
#              'content: 附件一：资格审查表 25 | index: 21\n'
#              'content: 附件二：符合性审查表 26 | index: 22\n'
#              'content: 附件三：评分标准 错误!未定义书签。 | index: 23\n'
#              'content: 第五章 合同条款及格式 31 | index: 24\n'
#              'content: 第六章 投标文件格式 31 | index: 25\n'
#              'content: 附件 1 投标函 43 | index: 26\n'
#              'content: 附件 2 投标保证书 44 | index: 27\n'
#              'content: 附件 3 无违法记录声明 45 | index: 28\n'
#              'content: 附件 4 法定代表人授权书 46 | index: 29\n'
#              'content: 附件 5 投标人情况简介 47 | index: 30\n'
#              'content: 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 48 | index: '
#              '31\n'
#              'content: 附件 7 投标一览表 49 | index: 32\n'
#              'content: 附件 8 分项报价表 50 | index: 33\n'
#              'content: 附件 9 投标方案 51 | index: 34\n'
#              'content: 附件 10 投标人资格声明 52 | index: 35\n'
#              'content: 附件 11 资格证明文件 53 | index: 36\n'
#              'content: 附件 12 与投标人存在“关系”的其他法人单位信息 54 | index: 37\n'
#              'content: 附件 13 投标人认为必要的其他证明文件 55 | index: 38\n'
#              'content: 附件 14 技术规格偏离表 56 | index: 39\n'
#              'content: 附件 15 商务条款偏离表 57 | index: 40\n'
#              'content: 附件 16 拟投入本项目的人员配备表 58 | index: 41\n'
#              'content: 附件 17 中标服务费承诺书 59 | index: 42\n'
#              'content: 附件 18 关于投标保证金的声明 60 | index: 43\n'
#              'content: 附件 19 开标会声明书 61 | index: 44',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'},
#  {'context': 'content: 根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#              '北京中外建工程管理有限公司受招标人委托，就北京京铁运恒采购 供应站有限公司 2024 '
#              '年端午节物资采购项目（第一包：一级压榨花生油）进行 国内公开招标采购，欢迎合格的投标人前来投标。 | index: 45\n'
#              'content: 一、项目编号：DLXM-2024-148-01 | index: 46\n'
#              'content: 二、采购组织类型：委托代理 | index: 47\n'
#              'content: 三、采购方式：公开招标 | index: 48\n'
#              'content: 四、招标最高限价：1840 万元 | index: 49\n'
#              'content: 五、采购内容、数量及简要技术要求 | index: 50\n'
#              'content: 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间\n'
#              '一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | index: 51\n'
#              'content: 六、合格投标人的资格要求(本项目采用资格后审) | index: 52\n'
#              'content: （1）在中华人民共和国境内注册的、具有独立承担民事责任的能力； | index: 53\n'
#              'content: （2）具有依法缴纳税收和社会保险的良好记录； | index: 54\n'
#              'content: （3）近三年内，在经营活动中没有重大违法记录； | index: 55\n'
#              'content: （4）单位负责人为同一人或者存在直接控股、管理关系的不同投标人，不得 同时参加本项目的投标； | index: '
#              '56\n'
#              'content: （5）信用中国网站（www.creditchina.gov.cn）和中国政府采购网 | index: 57\n'
#              'content: （www.ccgp.gov.cn）查询信用记录中（查询时间为招标公告发布后至投标截止时 '
#              '间期间），被列入失信被执行人、重大税收违法案件当事人名单或政府采购严重 违法失信行为记录名单的投标人，不得参加本项目投标； | '
#              'index: 58\n'
#              'content: （6）具有有效的《食品生产许可证》或《食品经营许可证》。若投标人为仅 '
#              '销售预包装食品的企业，须具有包含“食品经营（仅销售预包装食品）”的有效 营业执照或仅销售预包装食品备案证明材料； | '
#              'index: 59\n'
#              'content: （7）投标人财务状况正常，须提供会计师事务所出具的上一年度（2023年度） '
#              '财务审计报告，投标人尚未完成2023年度财务审计的须提供2022年度经审计的财 | index: 60\n'
#              'content: 务报告；若投标人为2023年1月1日之后成立的公司，须提供财务状况说明； | index: 61\n'
#              'content: （8）法律、行政法规规定的其他条件； | index: 62\n'
#              'content: （9）本项目不接受联合体投标。 | index: 63\n'
#              'content: 七、招标公告的发布： | index: 64\n'
#              'content: 本项目招标公告同时在中国招标投标公共服务平台、国铁物资采购平台 https:// '
#              'cg.95306.cn/上发布。 | index: 65\n'
#              'content: 八、招标文件的发售： | index: 66\n'
#              'content: 1.发售时间：2024 年 3 月 22 日至 2024 年 3 月 26 日，上午 9:00-11:00；下 '
#              '午 1:30-4:30 （北京时间）。 | index: 67\n'
#              'content: 2.发售地点：北京中外建工程管理有限公司（地址： 北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 '
#              '15 层）。 | index: 68\n'
#              'content: 3.招标文件售价：人民币 500 元/包，招标文件售后不退。请投标人以电汇或 '
#              '网上银行转账方式购买招标文件，无需到现场购买，汇款后请将以下资料的扫描 '
#              '件发至招标代理机构指定邮箱（782144725@qq.com）：①汇款底单，②经办人的 '
#              '法定代表人授权委托书原件（加盖公章和法人章或法人签字），③经办人身份证 '
#              '复印件加盖公章。投标人将上述资料发至指定邮箱后电话联系采购代理机构填写 '
#              '相关表格并获取电子版招标文件。汇款附言栏内请写明汇款用途及本项目项目编 号。购买招标文件汇款账号： | index: 69\n'
#              'content: 账户名称：北京中外建工程管理有限公司 | index: 70\n'
#              'content: 开户行：中国民生银行股份有限公司北京丽泽商务区支行 账 号：619201915 | index: 71\n'
#              'content: 4.凡有意参加投标者，请投标人登录 https:// cg.95306.cn/网站，按要求 '
#              '和提示填写企业相关信息,完成注册并通过初审 (相关注册事宜可拨打 电话 010-51864501、010-51864508 '
#              '咨询，联系人：石先生、赵女士)。 | index: 72\n'
#              'content: 5.招标文件发售联系人和联系电话： 江女士、王女士、魏先生，电话： '
#              '010-83928607、010-83928608、13071152980。 | index: 73\n'
#              'content: 九、投标保证金： | index: 74\n'
#              'content: 投标保证金金额：人民币贰拾万元整(¥200000） | index: 75\n'
#              'content: 投标人应于 2024 年 4 月 11 日 09 时 00 分前将投标保证金以银行汇票（电汇）、 '
#              '支票等非现金形式交至北京中外建工程管理有限公司。 | index: 76\n'
#              'content: 十、投标截止时间和地点： | index: 77\n'
#              'content: 本项目投标文件采用邮寄方式或现场递交，如采用邮寄方式具体要求如下： '
#              '1.邮寄时间要求：请投标人采用正规快递货运公司（建议使用顺丰快递）邮寄 '
#              '递交投标文件（不接受无邮寄单据的非正规闪送），并请于投标截止时间（2024 年 4 月 11 日 09 时 00 '
#              '分）之前将投标文件邮寄到以下地点（北京市丰台区福宜 街 5 号院 1 号楼新时代国际中心 A 座 15 '
#              '层（北京中外建工程管理有限公司)）， | index: 78\n'
#              'content: 逾期送达或未按规定邮寄的投标文件恕不接受。 2.投标文件邮寄包装及标记要求： | index: 79\n'
#              'content: （ 2 ） 投 标 文 件 寄 出 后 ， 请 立 即 将 邮 寄 内 容 及 邮 寄 单 号 发 送 至 '
#              '782144725@qq.com 。邮件标题格式须为“XXXX（投标人全称）DLXM-2024-148-01 '
#              '邮寄单号”，并电话通知项目负责人：江女士、王女士、魏先生，电话：010-83928607、 '
#              '010-83928608、13071152980。 | index: 80\n'
#              'content: 十一、开标时间及地点： | index: 81\n'
#              'content: 开标时间：本次招标将于 2024 年 4 月 11 日 09 时 00 分（北京时间） | index: '
#              '82\n'
#              'content: 开标地点：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 14 层 '
#              '开标形式：本项目将采用线上方式组织开标。 | index: 83\n'
#              'content: 十二、评标办法：综合评分法。 | index: 84\n'
#              'content: 十三、业务咨询 | index: 85\n'
#              'content: 招标人：北京京铁运恒采购供应站有限公司 | index: 86\n'
#              'content: 地址：北京市丰台区北京西站东附楼瑞尔威写字楼 A1 座 A706 室 | index: 87\n'
#              'content: 联系方式：石先生 010-51864501 | index: 88\n'
#              'content: 招标代理机构：北京中外建工程管理有限公司 | index: 89\n'
#              'content: 地址：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 15 层 | index: 90\n'
#              'content: 联系人：江女士、王女士、魏先生 | index: 91\n'
#              'content: 联系电话：010-83928607、010-83928608、13071152980 '
#              'E-mail：782144725@qq.com | index: 92',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'},
#  {'context': 'content: 一、概述 | index: 93\n'
#              'content: 1.本招标项目是针对北京京铁运恒采购供应站有限公司所需货物的采购、供应、 运输、验收及售后服务进行的招标。 | '
#              'index: 94\n'
#              'content: 2.本项目的组织及解释权归招标人。 | index: 95\n'
#              'content: 3.招标文件中的技术要求是基本质量要求，投标人应根据自己的投标方案综合考 '
#              '虑详细的技术指标，但不得低于招标基本质量要求。 | index: 96\n'
#              'content: 4.投标人供应的产品，需符合国家《中华人民共和国产品质量法》、《中华人民 '
#              '共和国食品安全法》等相关法律规定的要求，符合卫生防疫部门、检验检疫部门 '
#              '的各项合格指标，并有完整的销售合格标注或证书,所有的产品可追溯供货源头， '
#              '在行业标准、国家标准等各项标准不一致时应以要求高的标准为准。 | index: 97\n'
#              'content: 5.投标人提供的所有货物都应具有合格证及质量检测报告。 | index: 98\n'
#              'content: 二、采购内容 | index: 99\n'
#              'content: 招标内容 | 规格 | 数量（桶）\n'
#              '一级压榨花生油 | 5L/桶 | 160000 | index: 100\n'
#              'content: 三、技术和质量要求 1.质量要求 | index: 101\n'
#              'content: 花生油质量不低于《花生油》(GB/T1534-2017)压榨成品花生油一级要求，指 标达到 '
#              'GB2716-2018、GB2760-2014 国家有关规定标准，清晰无浑浊、无异味、无 '
#              '污染、无变质，剩余保质期不少于产品保质期的三分之二。外包装完好，密封性 良好，采用 PET 材质，5L/桶，有 SC '
#              '标志，标明品名、品牌、生产厂家、净含量、 生产日期、保质期、批号、执行标准、具有产品合格证。品牌商标必须带有 R 标 志。 | '
#              'index: 102\n'
#              'content: 2.花生油主要技术参数 | index: 103\n'
#              'content: 指标项目 | 标准要求 | index: 104\n'
#              'content: 气味、滋味 | 具有花生油固有的气味和滋味，无异味\n'
#              '色泽 | 淡黄色至橙黄色 | index: 105\n'
#              'content: 合同有效期内，如遇国家有关标准调整，则按新标准执行。 | index: 106\n'
#              'content: *3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 法》的规定。 | index: '
#              '107\n'
#              'content: 4.样品 | index: 108\n'
#              'content: 4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。 | index: 109\n'
#              'content: 4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 '
#              '的样品规格不符合招标文件的，样品评分部分不得分。 | index: 110\n'
#              'content: 4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#              '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 应的质量要求或技术参数不一致，责令中标人在 24 '
#              '小时内重新提供与要求相符的 货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。 | index: 111\n'
#              'content: 4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 字体清晰，粘贴牢固。 | '
#              'index: 112\n'
#              'content: 4.5 样品应与投标文件同时递交到指定地点（样品不退还）。 | index: 113\n'
#              'content: *5. 送达地点 | index: 114\n'
#              'content: 按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#              '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。 | index: 115\n'
#              'content: *6. 交货时间 | index: 116\n'
#              'content: 中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 标人送货计划通知为准。 | index: '
#              '117\n'
#              'content: 四、履约保证金 | index: 118\n'
#              'content: 1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 保证金。 | index: '
#              '119\n'
#              'content: 2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#              '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 性退回中标人。 | index: 120',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'}]
# {'chapters_tokens': 5383,
#  'in_tokens': 5760,
#  'index_path_map': {0: [5],
#                     1: [13],
#                     2: [21],
#                     3: [22],
#                     4: [23],
#                     5: [31],
#                     6: [33],
#                     7: [36],
#                     8: [37],
#                     9: [38],
#                     10: [39],
#                     11: [40],
#                     12: [41],
#                     13: [42],
#                     14: [43],
#                     15: [44],
#                     16: [45],
#                     17: [46],
#                     18: [47],
#                     19: [48],
#                     20: [49],
#                     21: [50],
#                     22: [51],
#                     23: [52],
#                     24: [53],
#                     25: [54],
#                     26: [55],
#                     27: [56],
#                     28: [57],
#                     29: [58],
#                     30: [59],
#                     31: [60],
#                     32: [61],
#                     33: [62],
#                     34: [63],
#                     35: [64],
#                     36: [65],
#                     37: [66],
#                     38: [67],
#                     39: [68],
#                     40: [69],
#                     41: [70],
#                     42: [71],
#                     43: [72],
#                     44: [73],
#                     45: [76],
#                     46: [77],
#                     47: [78],
#                     48: [79],
#                     49: [80],
#                     50: [81],
#                     51: [83],
#                     52: [84],
#                     53: [85],
#                     54: [86],
#                     55: [87],
#                     56: [88],
#                     57: [89],
#                     58: [90],
#                     59: [91],
#                     60: [92],
#                     61: [94],
#                     62: [95],
#                     63: [96],
#                     64: [97],
#                     65: [98],
#                     66: [99],
#                     67: [100],
#                     68: [101],
#                     69: [102],
#                     70: [103],
#                     71: [104],
#                     72: [105],
#                     73: [106],
#                     74: [107],
#                     75: [108],
#                     76: [109],
#                     77: [111],
#                     78: [112],
#                     79: [113],
#                     80: [114],
#                     81: [115],
#                     82: [116],
#                     83: [117],
#                     84: [118],
#                     85: [119],
#                     86: [120],
#                     87: [121],
#                     88: [122],
#                     89: [123],
#                     90: [124],
#                     91: [125],
#                     92: [126],
#                     93: [130],
#                     94: [131],
#                     95: [132],
#                     96: [133],
#                     97: [134],
#                     98: [135],
#                     99: [137],
#                     100: [139],
#                     101: [140],
#                     102: [141],
#                     103: [142],
#                     104: [144],
#                     105: [148],
#                     106: [149],
#                     107: [150],
#                     108: [151],
#                     109: [152],
#                     110: [153],
#                     111: [154],
#                     112: [155],
#                     113: [156],
#                     114: [157],
#                     115: [158],
#                     116: [159],
#                     117: [160],
#                     118: [162],
#                     119: [163],
#                     120: [164]},
#  'instruction_tokens': 185,
#  'output_format_tokens': 102,
#  'prompt_template_tokens': 82,
#  'supplment_tokens': 8}

# %%
pprint(task_inputs)
# Out:
# [{'context': 'content: 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目 | index: 0\n'
#              'content: 招标文件 | index: 1\n'
#              'content: 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油） | '
#              'index: 2\n'
#              'content: 项目编号：DLXM-2024-148-01 | index: 3\n'
#              'content: 招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司 | index: 4\n'
#              'content: 2024 年 3 月 | index: 5\n'
#              'content: 目 录 | index: 6\n'
#              'content: 第一章 招标公告 2 | index: 7\n'
#              'content: 第二章 招标需求 5 | index: 8\n'
#              'content: 第三章 投标人须知 8 | index: 9\n'
#              'content: 前附表 8 | index: 10\n'
#              'content: 一、总则 12 | index: 11\n'
#              'content: 二、招标文件 13 | index: 12\n'
#              'content: 三、投标文件的编制 14 | index: 13\n'
#              'content: 四、开标 18 | index: 14\n'
#              'content: 五、评标 19 | index: 15\n'
#              'content: 六、定标 21 | index: 16\n'
#              'content: 七、合同授予 21 | index: 17\n'
#              'content: 八、履约保证金 21 | index: 18\n'
#              'content: 九、招标代理服务费的收取 21 | index: 19\n'
#              'content: 第四章 评标办法及评分标准 22 | index: 20\n'
#              'content: 附件一：资格审查表 25 | index: 21\n'
#              'content: 附件二：符合性审查表 26 | index: 22\n'
#              'content: 附件三：评分标准 错误!未定义书签。 | index: 23\n'
#              'content: 第五章 合同条款及格式 31 | index: 24\n'
#              'content: 第六章 投标文件格式 31 | index: 25\n'
#              'content: 附件 1 投标函 43 | index: 26\n'
#              'content: 附件 2 投标保证书 44 | index: 27\n'
#              'content: 附件 3 无违法记录声明 45 | index: 28\n'
#              'content: 附件 4 法定代表人授权书 46 | index: 29\n'
#              'content: 附件 5 投标人情况简介 47 | index: 30\n'
#              'content: 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 48 | index: '
#              '31\n'
#              'content: 附件 7 投标一览表 49 | index: 32\n'
#              'content: 附件 8 分项报价表 50 | index: 33\n'
#              'content: 附件 9 投标方案 51 | index: 34\n'
#              'content: 附件 10 投标人资格声明 52 | index: 35\n'
#              'content: 附件 11 资格证明文件 53 | index: 36\n'
#              'content: 附件 12 与投标人存在“关系”的其他法人单位信息 54 | index: 37\n'
#              'content: 附件 13 投标人认为必要的其他证明文件 55 | index: 38\n'
#              'content: 附件 14 技术规格偏离表 56 | index: 39\n'
#              'content: 附件 15 商务条款偏离表 57 | index: 40\n'
#              'content: 附件 16 拟投入本项目的人员配备表 58 | index: 41\n'
#              'content: 附件 17 中标服务费承诺书 59 | index: 42\n'
#              'content: 附件 18 关于投标保证金的声明 60 | index: 43\n'
#              'content: 附件 19 开标会声明书 61 | index: 44',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'},
#  {'context': 'content: 根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， '
#              '北京中外建工程管理有限公司受招标人委托，就北京京铁运恒采购 供应站有限公司 2024 '
#              '年端午节物资采购项目（第一包：一级压榨花生油）进行 国内公开招标采购，欢迎合格的投标人前来投标。 | index: 45\n'
#              'content: 一、项目编号：DLXM-2024-148-01 | index: 46\n'
#              'content: 二、采购组织类型：委托代理 | index: 47\n'
#              'content: 三、采购方式：公开招标 | index: 48\n'
#              'content: 四、招标最高限价：1840 万元 | index: 49\n'
#              'content: 五、采购内容、数量及简要技术要求 | index: 50\n'
#              'content: 招标内容 | 规格 | 数量 （桶） | 最高预算单价(含税价) | 交货时间\n'
#              '一级压榨花 生油 | 5L/桶 | 160000 | 115 元/桶 | 中标人接到中标通知书开始备 '
#              '货，签订合同后开始送货，实际 送货进度以招标人送货计划通 知为准。 | index: 51\n'
#              'content: 六、合格投标人的资格要求(本项目采用资格后审) | index: 52\n'
#              'content: （1）在中华人民共和国境内注册的、具有独立承担民事责任的能力； | index: 53\n'
#              'content: （2）具有依法缴纳税收和社会保险的良好记录； | index: 54\n'
#              'content: （3）近三年内，在经营活动中没有重大违法记录； | index: 55\n'
#              'content: （4）单位负责人为同一人或者存在直接控股、管理关系的不同投标人，不得 同时参加本项目的投标； | index: '
#              '56\n'
#              'content: （5）信用中国网站（www.creditchina.gov.cn）和中国政府采购网 | index: 57\n'
#              'content: （www.ccgp.gov.cn）查询信用记录中（查询时间为招标公告发布后至投标截止时 '
#              '间期间），被列入失信被执行人、重大税收违法案件当事人名单或政府采购严重 违法失信行为记录名单的投标人，不得参加本项目投标； | '
#              'index: 58\n'
#              'content: （6）具有有效的《食品生产许可证》或《食品经营许可证》。若投标人为仅 '
#              '销售预包装食品的企业，须具有包含“食品经营（仅销售预包装食品）”的有效 营业执照或仅销售预包装食品备案证明材料； | '
#              'index: 59\n'
#              'content: （7）投标人财务状况正常，须提供会计师事务所出具的上一年度（2023年度） '
#              '财务审计报告，投标人尚未完成2023年度财务审计的须提供2022年度经审计的财 | index: 60\n'
#              'content: 务报告；若投标人为2023年1月1日之后成立的公司，须提供财务状况说明； | index: 61\n'
#              'content: （8）法律、行政法规规定的其他条件； | index: 62\n'
#              'content: （9）本项目不接受联合体投标。 | index: 63\n'
#              'content: 七、招标公告的发布： | index: 64\n'
#              'content: 本项目招标公告同时在中国招标投标公共服务平台、国铁物资采购平台 https:// '
#              'cg.95306.cn/上发布。 | index: 65\n'
#              'content: 八、招标文件的发售： | index: 66\n'
#              'content: 1.发售时间：2024 年 3 月 22 日至 2024 年 3 月 26 日，上午 9:00-11:00；下 '
#              '午 1:30-4:30 （北京时间）。 | index: 67\n'
#              'content: 2.发售地点：北京中外建工程管理有限公司（地址： 北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 '
#              '15 层）。 | index: 68\n'
#              'content: 3.招标文件售价：人民币 500 元/包，招标文件售后不退。请投标人以电汇或 '
#              '网上银行转账方式购买招标文件，无需到现场购买，汇款后请将以下资料的扫描 '
#              '件发至招标代理机构指定邮箱（782144725@qq.com）：①汇款底单，②经办人的 '
#              '法定代表人授权委托书原件（加盖公章和法人章或法人签字），③经办人身份证 '
#              '复印件加盖公章。投标人将上述资料发至指定邮箱后电话联系采购代理机构填写 '
#              '相关表格并获取电子版招标文件。汇款附言栏内请写明汇款用途及本项目项目编 号。购买招标文件汇款账号： | index: 69\n'
#              'content: 账户名称：北京中外建工程管理有限公司 | index: 70\n'
#              'content: 开户行：中国民生银行股份有限公司北京丽泽商务区支行 账 号：619201915 | index: 71\n'
#              'content: 4.凡有意参加投标者，请投标人登录 https:// cg.95306.cn/网站，按要求 '
#              '和提示填写企业相关信息,完成注册并通过初审 (相关注册事宜可拨打 电话 010-51864501、010-51864508 '
#              '咨询，联系人：石先生、赵女士)。 | index: 72\n'
#              'content: 5.招标文件发售联系人和联系电话： 江女士、王女士、魏先生，电话： '
#              '010-83928607、010-83928608、13071152980。 | index: 73\n'
#              'content: 九、投标保证金： | index: 74\n'
#              'content: 投标保证金金额：人民币贰拾万元整(¥200000） | index: 75\n'
#              'content: 投标人应于 2024 年 4 月 11 日 09 时 00 分前将投标保证金以银行汇票（电汇）、 '
#              '支票等非现金形式交至北京中外建工程管理有限公司。 | index: 76\n'
#              'content: 十、投标截止时间和地点： | index: 77\n'
#              'content: 本项目投标文件采用邮寄方式或现场递交，如采用邮寄方式具体要求如下： '
#              '1.邮寄时间要求：请投标人采用正规快递货运公司（建议使用顺丰快递）邮寄 '
#              '递交投标文件（不接受无邮寄单据的非正规闪送），并请于投标截止时间（2024 年 4 月 11 日 09 时 00 '
#              '分）之前将投标文件邮寄到以下地点（北京市丰台区福宜 街 5 号院 1 号楼新时代国际中心 A 座 15 '
#              '层（北京中外建工程管理有限公司)）， | index: 78\n'
#              'content: 逾期送达或未按规定邮寄的投标文件恕不接受。 2.投标文件邮寄包装及标记要求： | index: 79\n'
#              'content: （ 2 ） 投 标 文 件 寄 出 后 ， 请 立 即 将 邮 寄 内 容 及 邮 寄 单 号 发 送 至 '
#              '782144725@qq.com 。邮件标题格式须为“XXXX（投标人全称）DLXM-2024-148-01 '
#              '邮寄单号”，并电话通知项目负责人：江女士、王女士、魏先生，电话：010-83928607、 '
#              '010-83928608、13071152980。 | index: 80\n'
#              'content: 十一、开标时间及地点： | index: 81\n'
#              'content: 开标时间：本次招标将于 2024 年 4 月 11 日 09 时 00 分（北京时间） | index: '
#              '82\n'
#              'content: 开标地点：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 14 层 '
#              '开标形式：本项目将采用线上方式组织开标。 | index: 83\n'
#              'content: 十二、评标办法：综合评分法。 | index: 84\n'
#              'content: 十三、业务咨询 | index: 85\n'
#              'content: 招标人：北京京铁运恒采购供应站有限公司 | index: 86\n'
#              'content: 地址：北京市丰台区北京西站东附楼瑞尔威写字楼 A1 座 A706 室 | index: 87\n'
#              'content: 联系方式：石先生 010-51864501 | index: 88\n'
#              'content: 招标代理机构：北京中外建工程管理有限公司 | index: 89\n'
#              'content: 地址：北京市丰台区福宜街 5 号院 1 号楼新时代国际中心 A 座 15 层 | index: 90\n'
#              'content: 联系人：江女士、王女士、魏先生 | index: 91\n'
#              'content: 联系电话：010-83928607、010-83928608、13071152980 '
#              'E-mail：782144725@qq.com | index: 92',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'},
#  {'context': 'content: 一、概述 | index: 93\n'
#              'content: 1.本招标项目是针对北京京铁运恒采购供应站有限公司所需货物的采购、供应、 运输、验收及售后服务进行的招标。 | '
#              'index: 94\n'
#              'content: 2.本项目的组织及解释权归招标人。 | index: 95\n'
#              'content: 3.招标文件中的技术要求是基本质量要求，投标人应根据自己的投标方案综合考 '
#              '虑详细的技术指标，但不得低于招标基本质量要求。 | index: 96\n'
#              'content: 4.投标人供应的产品，需符合国家《中华人民共和国产品质量法》、《中华人民 '
#              '共和国食品安全法》等相关法律规定的要求，符合卫生防疫部门、检验检疫部门 '
#              '的各项合格指标，并有完整的销售合格标注或证书,所有的产品可追溯供货源头， '
#              '在行业标准、国家标准等各项标准不一致时应以要求高的标准为准。 | index: 97\n'
#              'content: 5.投标人提供的所有货物都应具有合格证及质量检测报告。 | index: 98\n'
#              'content: 二、采购内容 | index: 99\n'
#              'content: 招标内容 | 规格 | 数量（桶）\n'
#              '一级压榨花生油 | 5L/桶 | 160000 | index: 100\n'
#              'content: 三、技术和质量要求 1.质量要求 | index: 101\n'
#              'content: 花生油质量不低于《花生油》(GB/T1534-2017)压榨成品花生油一级要求，指 标达到 '
#              'GB2716-2018、GB2760-2014 国家有关规定标准，清晰无浑浊、无异味、无 '
#              '污染、无变质，剩余保质期不少于产品保质期的三分之二。外包装完好，密封性 良好，采用 PET 材质，5L/桶，有 SC '
#              '标志，标明品名、品牌、生产厂家、净含量、 生产日期、保质期、批号、执行标准、具有产品合格证。品牌商标必须带有 R 标 志。 | '
#              'index: 102\n'
#              'content: 2.花生油主要技术参数 | index: 103\n'
#              'content: 指标项目 | 标准要求 | index: 104\n'
#              'content: 气味、滋味 | 具有花生油固有的气味和滋味，无异味\n'
#              '色泽 | 淡黄色至橙黄色 | index: 105\n'
#              'content: 合同有效期内，如遇国家有关标准调整，则按新标准执行。 | index: 106\n'
#              'content: *3.一级压榨花生油规格为 5L/桶。净含量应符合《定量包装商品计量监督管理办 法》的规定。 | index: '
#              '107\n'
#              'content: 4.样品 | index: 108\n'
#              'content: 4.1 投标人须提供：一级压榨花生油 3 桶（净含量为：5L/桶）。 | index: 109\n'
#              'content: 4.2 所提供的样品应与招标文件要求的实质性技术指标一致。未提供样品或提供 '
#              '的样品规格不符合招标文件的，样品评分部分不得分。 | index: 110\n'
#              'content: 4.3 中标人提供的产品样品将封存由招标人保管，用于交货时对样验收。招标人 '
#              '在验收过程中若发现其提供的实物与样品不符，或样品与招标文件要求或投标响 应的质量要求或技术参数不一致，责令中标人在 24 '
#              '小时内重新提供与要求相符的 货物，如无法提供合格产品，中标人将承担由此给招标人造成的全部损失。 | index: 111\n'
#              'content: 4.4 投标人提供的样品上均应粘贴标签，并标明货物名称、投标人名称，标签应 字体清晰，粘贴牢固。 | '
#              'index: 112\n'
#              'content: 4.5 样品应与投标文件同时递交到指定地点（样品不退还）。 | index: 113\n'
#              'content: *5. 送达地点 | index: 114\n'
#              'content: 按照北京京铁运恒采购供应站有限公司要求送达到指定物流公司库房(物流 '
#              '公司地址主要为京津冀地区)，具体配送地点按招标人要求及最终签订合同为准。 | index: 115\n'
#              'content: *6. 交货时间 | index: 116\n'
#              'content: 中标人接到中标通知书开始备货，签订合同后开始送货，实际送货进度以招 标人送货计划通知为准。 | index: '
#              '117\n'
#              'content: 四、履约保证金 | index: 118\n'
#              'content: 1.中标人应在合同签订后 7 个工作日内向招标人提交合同总价款 10％的履约 保证金。 | index: '
#              '119\n'
#              'content: 2.中标人完成供货并验收合格，双方结账完毕后履约保证金转为质量保证金。 '
#              '三个月后，在商品没有出现任何问题的情况下，招标人将质量保证金不计息一次 性退回中标人。 | index: 120',
#   'instruction': '\n'
#                  '我会提供招标文件提取的文档片段（材料A），\n'
#                  '文档片段可能是文档开头的封面和目录，也可能是文档的章节片段。\n'
#                  '\n'
#                  '请忽略封面或目录，对于章节片段请完成以下任务：\n'
#                  '1. 识别正文中的标题\n'
#                  '2. 请注意区分章节开头的目录和正文的标题，不要将目录的标题作为正文的标题。\n'
#                  '3. 请注意区分列表和正文的标题，不要将列表项作为正文的标题。\n'
#                  '4. 请注意包含章节末尾的附件标题，但忽略章节开头的附件标题目录。\n',
#   'output_format': '\n'
#                    '        \n'
#                    '- 只输出符合JSON格式的数据，不要添加解释、注释或 Markdown 标记。\n'
#                    '- 示例：\n'
#                    '[\n'
#                    '    {"index": int, "level": int, "title": str}, \n'
#                    '    {"index": int, "level": int, "title": str}\n'
#                    ']\n'
#                    '- 一个标题一条数据， 如果只有一个层级的标题，则只输出一个层级。\n'
#                    '- 如未识别到标题，返回空列表。\n'
#                    '\n',
#   'supplement': '此任务无补充内容'}]
