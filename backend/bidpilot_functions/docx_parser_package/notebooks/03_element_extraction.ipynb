# %%
import sys
from pathlib import Path
sys.path.append('..')

from docx_parser._01_xml_loader import DocxXMLLoader
from docx_parser._02_xml_parser import DocxXMLParser
from docx_parser._03_element_extractor import DocumentElementExtractor, ElementType

# %%
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case3_北京铁运投标人须知.docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case3st_北京铁运投标人须知.docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case 9 _样式测试.docx"
doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case8：招标文件-第1包：一级压榨花生油.docx"
#doc_path = "C:/Users/huiwa/Documents/_CursorChat_Extra/Langchain_Jupyter/.LoRA微调/招标文件_微调库/WORD/[1].docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/Case6_中国区零食包框架供应商采购项目招采文件.docx"

# %%
# 1. 加载文档
loader = DocxXMLLoader(doc_path)  # 创建DocxXMLLoader 加载器 实例 
raw_content = loader.extract_raw()  # 加载原始文档内容
parser = DocxXMLParser(raw_content)  # 创建DocxXMLParser 解析器 实例
# Out:
# 2025-02-13 08:35:57,458 - docx_parser._01_xml_loader - INFO - 从 C:\Users\huiwa\Downloads\文本分析测试\CaseTest\case8：招标文件-第1包：一级压榨花生油.docx 成功提取 raw XML content
# 2025-02-13 08:35:57,475 - docx_parser._02_xml_parser - INFO - Successfully parsed XML content
# 2025-02-13 08:35:57,476 - docx_parser._02_xml_parser - INFO - DocxXMLParser initialized successfully

# %%
# 2. 创建元素提取器
extractor = DocumentElementExtractor(parser)

# %%
# 3. 提取所有元素
elements = extractor.extract_all_elements()
# Out:
# 2025-02-13 08:36:00,348 - docx_parser._03_element_extractor - INFO - Starting element extraction...
# 2025-02-13 08:36:00,349 - docx_parser._03_element_extractor - DEBUG - Found 928 total elements
# 2025-02-13 08:36:00,350 - docx_parser._03_element_extractor - DEBUG - Processing element 1, type: ElementType.PARAGRAPH
# 2025-02-13 08:36:00,350 - docx_parser._03_element_extractor - DEBUG - Element 1 was skipped or pending
# 2025-02-13 08:36:00,350 - docx_parser._03_element_extractor - DEBUG - Processing element 2, type: ElementType.PARAGRAPH
# 2025-02-13 08:36:00,351 - docx_parser._03_element_extractor - DEBUG - Element 2 was skipped or pending
# 2025-02-13 08:36:00,351 - docx_parser._03_element_extractor - DEBUG - Processing element 3, type: ElementType.PARAGRAPH
# 2025-02-13 08:36:00,352 - docx_parser._03_element_extractor - DEBUG - Element 3 was skipped or pending
# ...

# %%
print(type(elements))
# Out:
# <class 'list'>

# %%
# 1. 检查 elements 的类型和内部元素类型
print("Elements type:", type(elements))
print("First element type:", type(elements[0]))

# 2. 使用 vars() 或 __dict__ 查看完整的属性结构
from pprint import pprint
print("\nFirst element complete structure:")
pprint(vars(elements[0]))

# 3. 检查是否可序列化为 JSON
import json
try:
    # 尝试序列化第一个元素
    element_dict = elements[0].__dict__
    json_str = json.dumps(element_dict, default=str)  # default=str 处理不可序列化的对象
    print("\nCan be serialized to JSON: Yes")
except Exception as e:
    print("\nCan be serialized to JSON:", str(e))

# 4. 打印所有可用的属性和方法
print("\nAll available attributes and methods:")
print(dir(elements[0]))
# Out:
# Elements type: <class 'list'>
# First element type: <class 'docx_parser._03_element_extractor.ParagraphElement'>
#
# First element complete structure:
# {'alignment': 'left',
#  'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#  'element_type': <ElementType.PARAGRAPH: 'paragraph'>,
#  'first_line_tabs': 0,
#  'heading_info': {'converted_to_non_heading': True,
#                   'has_heading_style': False,
#                   'has_outline_level': True,
#                   'original_heading_level': 1,
#                   'original_heading_type': 'outline',
#                   'original_is_heading': True,
#                   'style_id': '2',
#                   'toc_matched': False},
#  'heading_level': None,
#  'heading_type': '',
#  'indentation': 1733,
#  'is_heading': False,
#  'is_toc': False,
#  'raw_xml': '<w:p '
#             'xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" '
#             'xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" '
# ...

# %%
# 4. 基本统计
print(f"\n=== 基本统计 ===")
print(f"总元素数量: {len(elements)}")
print(type(elements))
print(elements[0],elements[1])
print(type(elements[0]),type(elements[1]))
from pprint import pprint
pprint(elements[0])
pprint(elements[1])
# Out:
# === 基本统计 ===
# 总元素数量: 654
# <class 'list'>
# ...

# %%
print(elements[0].__dict__)
print(elements[0].element_type)
print(elements[0].sequence_number)
print(elements[0].content)
# Out:
# {'element_type': <ElementType.PARAGRAPH: 'paragraph'>, 'sequence_number': 1, 'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目', 'raw_xml': '<w:p xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/
# ...

# %%
for element in elements[0:10]:
    element_dict = element.__dict__
    print(element_dict['element_type'])
print(type(elements[0]),type(elements[3]))
# Out:
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# ElementType.PARAGRAPH
# <class 'docx_parser._03_element_extractor.ParagraphElement'> <class 'docx_parser._03_element_extractor.ParagraphElement'>

# %%
from pprint import pprint
for element in elements[0:100]:
    element_dict = element.__dict__
    #element_dict.pop('raw_xml', None)
    pprint(element_dict)
# Out:
# {'alignment': 'left',
#  'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#  'element_type': <ElementType.PARAGRAPH: 'paragraph'>,
#  'first_line_tabs': 0,
#  'heading_info': {'converted_to_non_heading': True,
#                   'has_heading_style': False,
#                   'has_outline_level': True,
#                   'original_heading_level': 1,
#                   'original_heading_type': 'outline',
#                   'original_is_heading': True,
#                   'style_id': '2',
#                   'toc_matched': False},
#  'heading_level': None,
#  'heading_type': '',
#  'indentation': 1733,
#  'is_heading': False,
#  'is_toc': False,
#  'raw_xml': '<w:p '
#             'xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" '
#             'xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" '
#             'xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" '
# ...

# %%
from pprint import pprint
for element in elements:
    element_dict = element.__dict__
    element_dict.pop('raw_xml', None)
    pprint(element_dict)
# Out:
# {'alignment': 'left',
#  'content': '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目',
#  'element_type': <ElementType.PARAGRAPH: 'paragraph'>,
#  'first_line_tabs': 0,
#  'heading_info': {'converted_to_non_heading': True,
#                   'has_heading_style': False,
#                   'has_outline_level': True,
#                   'original_heading_level': 1,
#                   'original_heading_type': 'outline',
#                   'original_is_heading': True,
#                   'style_id': '2',
#                   'toc_matched': False},
#  'heading_level': None,
#  'heading_type': '',
#  'indentation': 1733,
#  'is_heading': False,
#  'is_toc': False,
#  'sequence_number': 1,
#  'style_id': '2',
#  'toc_info': None}
# {'alignment': 'left',
#  'content': '招标文件',
#  'element_type': <ElementType.PARAGRAPH: 'paragraph'>,
#  'first_line_tabs': 0,
#  'heading_info': {'converted_to_non_heading': True,
#                   'has_heading_style': False,
#                   'has_outline_level': True,
# ...

# %%
# 假设 elements 是已经提取的 DocumentElement 列表
toc_elements = [
    (elem.content, elem.toc_info['page_number']) 
    for elem in elements 
    if hasattr(elem, 'is_toc') and elem.is_toc
]

# 按顺序打印内容和页码
for content, page_number in toc_elements:
    print(f"{content} (页码: {page_number})")
# Out:
#                     目    录 (页码: None)
# 第一章  招标公告 (页码: 2)
# 第二章  招标需求 (页码: 5)
# 第三章  投标人须知 (页码: 8)
# 前附表 (页码: 8)
# 一、总则 (页码: 12)
# 二、招标文件 (页码: 13)
# 三、投标文件的编制 (页码: 14)
# 四、开标 (页码: 18)
# 五、评标 (页码: 19)
# 六、定标 (页码: 21)
# 七、合同授予 (页码: 21)
# 八、履约保证金 (页码: 21)
# 九、招标代理服务费的收取 (页码: 21)
# 第四章  评标办法及评分标准 (页码: 22)
# 附件一：资格审查表 (页码: 25)
# 附件二：符合性审查表 (页码: 26)
# 附件三：评分标准 (页码: 27)
# 第五章  合同条款及格式 (页码: 31)
# 第六章  投标文件格式 (页码: 31)
# 附件 1 投标函 (页码: 43)
# 附件 2 投标保证书 (页码: 44)
# 附件 3 无违法记录声明 (页码: 45)
# 附件 4 法定代表人授权书 (页码: 46)
# 附件 5 投标人情况简介 (页码: 47)
# 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表 (页码: 48)
# 附件 7 投标一览表 (页码: 49)
# 附件 8 分项报价表 (页码: 50)
# 附件 9 投标方案 (页码: 51)
# 附件 10 投标人资格声明 (页码: 52)
# 附件 11 资格证明文件 (页码: 53)
# 附件 12 与投标人存在“关系”的其他法人单位信息 (页码: 54)
# 附件 13 投标人认为必要的其他证明文件 (页码: 55)
# 附件 14 技术规格偏离表 (页码: 56)
# 附件 15 商务条款偏离表 (页码: 57)
# 附件 16 拟投入本项目的人员配备表 (页码: 58)
# 附件 17 中标服务费承诺书 (页码: 59)
# 附件 18 关于投标保证金的声明 (页码: 60)
# 附件 19 开标会声明书 (页码: 61)

# %%
for element in elements:
    if element.element_type == ElementType.PARAGRAPH and element.is_heading:
        print(f"L{element.heading_level}: {element.content}")
# Out:
# L1: 第一章 招标公告
# L1: 第二章 招标需求
# L1: 第三章 投标人须知
# L2: 前附表
# L2: 一、总则
# L2: 二、招标文件
# L2: 三、投标文件的编制
# L2: 四、开标
# L2: 五、评标
# L2: 六、定标
# L2: 七、合同授予
# L2: 八、履约保证金
# L2: 九、招标代理服务费的收取
# L1: 第四章 评标办法及评分标准
# L2: 附件一：资格审查表
# L2: 附件二：符合性审查表
# L2: 附件三：评分标准
# L1: 第五章 合同条款及格式
# L1: 第六章 投标文件格式
# L2: 附件 1 投标函
# L2: 附件 2 投标保证书
# L2: 附件 3 无违法记录声明
# L2: 附件 4 法定代表人授权书
# L2: 附件 5 投标人情况简介
# L2: 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表
# L2: 附件 7 投标一览表
# L2: 附件 8 分项报价表
# L2: 附件 9 投标方案
# L2: 附件 10 投标人资格声明
# L2: 附件 11 资格证明文件
# L2: 附件 12 与投标人存在“关系”的其他法人单位信息
# L2: 附件 13 投标人认为必要的其他证明文件
# L2: 附件 14 技术规格偏离表
# L2: 附件 15 商务条款偏离表
# L2: 附件 16 拟投入本项目的人员配备表
# L2: 附件 17 中标服务费承诺书
# L2: 附件 18 关于投标保证金的声明
# L2: 附件 19 开标会声明书

# %%
# 筛选出原来是标题但现在不是标题的元素
converted_headings = [
    elem for elem in elements 
    if elem.element_type == ElementType.PARAGRAPH 
    and elem.heading_info 
    and elem.heading_info.get('original_is_heading') 
    and not elem.is_heading
]

# 打印这些元素的信息
for elem in converted_headings:
    print(f"Content: {elem.content}")
    print(f"Original heading level: {elem.heading_info.get('original_heading_level')}")
    print(f"Original heading type: {elem.heading_info.get('original_heading_type')}")
    print("---")
# Out:
# Content: 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目
# Original heading level: 1
# Original heading type: outline
# ---
# Content: 招标文件
# Original heading level: 1
# Original heading type: outline
# ---
# Content: 买卖合同
# Original heading level: 10
# Original heading type: outline
# ---

# %%
# 打印所有段落的第一行
for element in elements:
    if element.element_type == ElementType.PARAGRAPH:
        print(f"第一行: {element.content.strip().split('\n')[0]}")
# Out:
# 第一行: 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目
# 第一行: 招标文件
# 第一行: 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油）
# 第一行: 项目编号：DLXM-2024-148-01
# 第一行: 招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司
# 第一行: 2024 年 3 月
# 第一行: 目    录
# 第一行: 第一章  招标公告
# 第一行: 第二章  招标需求
# 第一行: 第三章  投标人须知
# 第一行: 前附表
# 第一行: 一、总则
# 第一行: 二、招标文件
# 第一行: 三、投标文件的编制
# 第一行: 四、开标
# 第一行: 五、评标
# 第一行: 六、定标
# 第一行: 七、合同授予
# 第一行: 八、履约保证金
# 第一行: 九、招标代理服务费的收取
# 第一行: 第四章  评标办法及评分标准
# 第一行: 附件一：资格审查表
# 第一行: 附件二：符合性审查表
# 第一行: 附件三：评分标准
# 第一行: 第五章  合同条款及格式
# 第一行: 第六章  投标文件格式
# 第一行: 附件 1 投标函
# 第一行: 附件 2 投标保证书
# 第一行: 附件 3 无违法记录声明
# 第一行: 附件 4 法定代表人授权书
# 第一行: 附件 5 投标人情况简介
# 第一行: 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表
# 第一行: 附件 7 投标一览表
# 第一行: 附件 8 分项报价表
# 第一行: 附件 9 投标方案
# 第一行: 附件 10 投标人资格声明
# 第一行: 附件 11 资格证明文件
# 第一行: 附件 12 与投标人存在“关系”的其他法人单位信息
# 第一行: 附件 13 投标人认为必要的其他证明文件
# 第一行: 附件 14 技术规格偏离表
# 第一行: 附件 15 商务条款偏离表
# 第一行: 附件 16 拟投入本项目的人员配备表
# 第一行: 附件 17 中标服务费承诺书
# 第一行: 附件 18 关于投标保证金的声明
# 第一行: 附件 19 开标会声明书
# 第一行: 第一章 招标公告
# ...
