# %%
import sys
from pathlib import Path

# 获取当前文件的路径
current_path = Path().absolute()
# 添加项目根目录（包含 docx_parser 和 llm_structuring 的目录）到系统路径
root_path = current_path.parent.parent
sys.path.append(str(root_path))

from docx_parser_package.docx_parser.pipeline import DocxParserPipeline
from llm_structurer_package.llm_structurer._02_parts_creator import PartsCreator

# %%
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case3_北京铁运投标人须知.docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case3st_北京铁运投标人须知.docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case 9 _样式测试.docx"
doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/case8：招标文件-第1包：一级压榨花生油.docx"
#doc_path = "C:/Users/huiwa/Documents/_CursorChat_Extra/Langchain_Jupyter/.LoRA微调/招标文件_微调库/WORD/[2].docx"
#doc_path = "C:/Users/huiwa/Downloads/文本分析测试/CaseTest/Case6_中国区零食包框架供应商采购项目招采文件.docx"

# %%
# 基本用法
pipeline = DocxParserPipeline(doc_path)
elements = pipeline.process()
# Out:
# 2024-12-27 01:24:15,914 - docx_parser_package.docx_parser._01_xml_loader - INFO - 从 C:\Users\huiwa\Downloads\文本分析测试\CaseTest\case8：招标文件-第1包：一级压榨花生油.docx 成功提取 raw XML content
# 2024-12-27 01:24:15,915 - docx_parser_package.docx_parser.pipeline - INFO - 成功加载文档: C:\Users\huiwa\Downloads\文本分析测试\CaseTest\case8：招标文件-第1包：一级压榨花生油.docx
# 2024-12-27 01:24:15,932 - docx_parser_package.docx_parser._02_xml_parser - INFO - Successfully parsed XML content
# 2024-12-27 01:24:15,933 - docx_parser_package.docx_parser._02_xml_parser - INFO - DocxXMLParser initialized successfully
# 2024-12-27 01:24:15,933 - docx_parser_package.docx_parser.pipeline - INFO - 成功解析XML结构
# 2024-12-27 01:24:15,942 - docx_parser_package.docx_parser._03_element_extractor - INFO - Starting element extraction...
# 2024-12-27 01:24:15,942 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Found 928 total elements
# 2024-12-27 01:24:15,943 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 1, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,943 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 1 was skipped or pending
# 2024-12-27 01:24:15,943 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 2, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,944 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 2 was skipped or pending
# 2024-12-27 01:24:15,944 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 3, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,945 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 3 was skipped or pending
# 2024-12-27 01:24:15,945 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 4, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,945 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 4 was skipped or pending
# 2024-12-27 01:24:15,946 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 5, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,946 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 5 was skipped or pending
# 2024-12-27 01:24:15,947 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 6, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,947 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目' (original: '北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目')
# 2024-12-27 01:24:15,948 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,948 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Converted unmatched heading to non-heading: ParagraphElement(element_type=<ElementType.PARAGRAPH: 'paragraph'>, sequence_number=1, content='北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目', raw_xml='<w:p xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape" xmlns:wpsCustomData="http://www.wps.cn/officeDocument/2013/wpsCustomData" w14:paraId="66779002">\n  <w:pPr>\n    <w:pStyle w:val="2"/>\n    <w:spacing w:before="139" w:line="295" w:lineRule="auto"/>\n    <w:ind w:left="1733" w:right="805" w:hanging="581"/>\n    <w:outlineLvl w:val="0"/>\n    <w:rPr>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n  </w:pPr>\n  <w:r>\n    <w:rPr>\n      <w:b/>\n      <w:bCs/>\n      <w:spacing w:val="-10"/>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n    <w:t>北京京铁运恒采购供应站有限公司</w:t>\n  </w:r>\n  <w:r>\n    <w:rPr>\n      <w:spacing w:val="8"/>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n    <w:t xml:space="preserve"> </w:t>\n  </w:r>\n  <w:r>\n    <w:rPr>\n      <w:b/>\n      <w:bCs/>\n      <w:spacing w:val="-10"/>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n    <w:t>2024</w:t>\n  </w:r>\n  <w:r>\n    <w:rPr>\n      <w:spacing w:val="-84"/>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n    <w:t xml:space="preserve"> </w:t>\n  </w:r>\n  <w:r>\n    <w:rPr>\n      <w:b/>\n      <w:bCs/>\n      <w:spacing w:val="-10"/>\n      <w:sz w:val="43"/>\n      <w:szCs w:val="43"/>\n    </w:rPr>\n    <w:t>年端午节物资采购项目</w:t>\n  </w:r>\n</w:p>\n', style_id='2', is_heading=False, heading_level=None, heading_type='', heading_info={'original_heading_level': 1, 'original_is_heading': True, 'original_heading_type': 'outline', 'has_outline_level': True, 'has_heading_style': False, 'style_id': '2', 'toc_matched': False, 'converted_to_non_heading': True}, alignment='left', indentation=1733, first_line_tabs=0, is_toc=False, toc_info=None)
# 2024-12-27 01:24:15,948 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 6
# 2024-12-27 01:24:15,949 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 7, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,949 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 7 was skipped or pending
# 2024-12-27 01:24:15,950 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 8, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,950 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 8 was skipped or pending
# 2024-12-27 01:24:15,951 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 9, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,951 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 9 was skipped or pending
# 2024-12-27 01:24:15,951 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 10, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,952 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 10 was skipped or pending
# 2024-12-27 01:24:15,952 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 11, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,953 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 11 was skipped or pending
# 2024-12-27 01:24:15,953 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 12, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,953 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 12 was skipped or pending
# 2024-12-27 01:24:15,954 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 13, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,954 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 13 was skipped or pending
# 2024-12-27 01:24:15,955 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 14, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,955 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '招标文件' (original: '招标文件')
# 2024-12-27 01:24:15,955 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,956 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Converted unmatched heading to non-heading: ParagraphElement(element_type=<ElementType.PARAGRAPH: 'paragraph'>, sequence_number=2, content='招标文件', raw_xml='<w:p xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape" xmlns:wpsCustomData="http://www.wps.cn/officeDocument/2013/wpsCustomData" w14:paraId="44E920F7">\n  <w:pPr>\n    <w:pStyle w:val="2"/>\n    <w:spacing w:before="273" w:line="220" w:lineRule="auto"/>\n    <w:ind w:left="2607"/>\n    <w:outlineLvl w:val="0"/>\n    <w:rPr>\n      <w:sz w:val="84"/>\n      <w:szCs w:val="84"/>\n    </w:rPr>\n  </w:pPr>\n  <w:r>\n    <w:rPr>\n      <w:b/>\n      <w:bCs/>\n      <w:spacing w:val="-25"/>\n      <w:sz w:val="84"/>\n      <w:szCs w:val="84"/>\n    </w:rPr>\n    <w:t>招标文件</w:t>\n  </w:r>\n</w:p>\n', style_id='2', is_heading=False, heading_level=None, heading_type='', heading_info={'original_heading_level': 1, 'original_is_heading': True, 'original_heading_type': 'outline', 'has_outline_level': True, 'has_heading_style': False, 'style_id': '2', 'toc_matched': False, 'converted_to_non_heading': True}, alignment='left', indentation=2607, first_line_tabs=0, is_toc=False, toc_info=None)
# 2024-12-27 01:24:15,956 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 14
# 2024-12-27 01:24:15,957 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 15, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,957 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 15 was skipped or pending
# 2024-12-27 01:24:15,957 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 16, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,958 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 16 was skipped or pending
# 2024-12-27 01:24:15,958 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 17, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,959 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 17 was skipped or pending
# 2024-12-27 01:24:15,959 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 18, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,960 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 18 was skipped or pending
# 2024-12-27 01:24:15,960 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 19, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,960 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 19 was skipped or pending
# 2024-12-27 01:24:15,960 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 20, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,961 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 20 was skipped or pending
# 2024-12-27 01:24:15,961 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 21, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,962 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 21 was skipped or pending
# 2024-12-27 01:24:15,962 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 22, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,963 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油）' (original: '        项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油）')
# 2024-12-27 01:24:15,963 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,963 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 22
# 2024-12-27 01:24:15,964 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 23, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,965 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '项目编号：DLXM-2024-148-01' (original: '项目编号：DLXM-2024-148-01')
# 2024-12-27 01:24:15,965 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,965 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 23
# 2024-12-27 01:24:15,966 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 24, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,967 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司' (original: '招 标 人：北京京铁运恒采购供应站有限公司 代理机构：北京中外建工程管理有限公司')
# 2024-12-27 01:24:15,967 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,968 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 24
# 2024-12-27 01:24:15,968 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 25, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,968 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 25 was skipped or pending
# 2024-12-27 01:24:15,969 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 26, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,969 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 26 was skipped or pending
# 2024-12-27 01:24:15,969 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 27, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,970 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 27 was skipped or pending
# 2024-12-27 01:24:15,970 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 28, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,971 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 28 was skipped or pending
# 2024-12-27 01:24:15,971 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 29, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,971 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 29 was skipped or pending
# 2024-12-27 01:24:15,972 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 30, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,972 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 30 was skipped or pending
# 2024-12-27 01:24:15,973 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 31, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,973 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 31 was skipped or pending
# 2024-12-27 01:24:15,973 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 32, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,974 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '2024 年 3 月' (original: '                2024 年 3 月')
# 2024-12-27 01:24:15,974 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - TOC map is empty, no matching possible
# 2024-12-27 01:24:15,975 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 32
# 2024-12-27 01:24:15,975 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 33, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,976 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 33 was skipped or pending
# 2024-12-27 01:24:15,976 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 34, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,977 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '目    录', page: None
# 2024-12-27 01:24:15,977 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '目    录', page: None
# 2024-12-27 01:24:15,977 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC title: '目    录'
# 2024-12-27 01:24:15,977 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC title: '目    录'
# 2024-12-27 01:24:15,978 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 34
# 2024-12-27 01:24:15,980 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 35, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,982 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '', page: None
# 2024-12-27 01:24:15,982 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '', page: None
# 2024-12-27 01:24:15,985 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - No valid indent found, returning level 1
# 2024-12-27 01:24:15,985 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - No valid indent found, returning level 1
# 2024-12-27 01:24:15,987 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 35 was skipped or pending
# 2024-12-27 01:24:15,988 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 36, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,989 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '', page: None
# 2024-12-27 01:24:15,989 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '', page: None
# 2024-12-27 01:24:15,990 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - No valid indent found, returning level 1
# 2024-12-27 01:24:15,990 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - No valid indent found, returning level 1
# 2024-12-27 01:24:15,991 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 36 was skipped or pending
# 2024-12-27 01:24:15,992 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 37, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:15,994 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第一章  招标公告', page: 2
# 2024-12-27 01:24:15,994 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第一章  招标公告', page: 2
# 2024-12-27 01:24:15,995 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:15,995 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,002 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found 41 TOC elements
# 2024-12-27 01:24:16,002 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found 41 TOC elements
# 2024-12-27 01:24:16,003 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 3797
# 2024-12-27 01:24:16,003 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 3797
# 2024-12-27 01:24:16,005 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,005 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,007 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,007 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,008 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,008 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,009 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,009 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,010 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,010 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,011 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,011 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,012 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 440
# 2024-12-27 01:24:16,012 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 440
# 2024-12-27 01:24:16,012 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 460
# 2024-12-27 01:24:16,012 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 460
# 2024-12-27 01:24:16,013 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,013 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,014 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 441
# 2024-12-27 01:24:16,014 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 441
# 2024-12-27 01:24:16,016 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 439
# 2024-12-27 01:24:16,016 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 439
# 2024-12-27 01:24:16,017 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,017 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 443
# 2024-12-27 01:24:16,018 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 445
# 2024-12-27 01:24:16,018 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 445
# 2024-12-27 01:24:16,019 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,019 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,020 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,020 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,020 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,020 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,021 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,021 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,022 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,022 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,023 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,023 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 20
# 2024-12-27 01:24:16,024 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,024 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,025 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,025 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,026 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,026 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,026 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,026 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,027 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,027 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,028 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,028 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,029 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,029 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,030 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,030 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,031 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,031 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,031 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,031 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,032 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,032 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,033 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,033 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,034 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,034 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,035 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,035 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,035 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,035 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,036 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,036 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,037 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,037 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,038 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,038 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,038 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,038 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found indent value: 456
# 2024-12-27 01:24:16,039 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Original indents: [20, 20, 20, 20, 20, 20, 439, 440, 441, 443, 443, 443, 443, 443, 445, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 460, 3797]
# 2024-12-27 01:24:16,039 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Original indents: [20, 20, 20, 20, 20, 20, 439, 440, 441, 443, 443, 443, 443, 443, 445, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 456, 460, 3797]
# 2024-12-27 01:24:16,039 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Grouped indents: [20, 456, 3797]
# 2024-12-27 01:24:16,039 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Grouped indents: [20, 456, 3797]
# 2024-12-27 01:24:16,040 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Built TOC indent map: {(16, 24): 1, (364, 547): 2, (3037, 4556): 3}
# 2024-12-27 01:24:16,040 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Built TOC indent map: {(16, 24): 1, (364, 547): 2, (3037, 4556): 3}
# 2024-12-27 01:24:16,041 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,041 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,042 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 37
# 2024-12-27 01:24:16,042 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 38, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,043 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第二章  招标需求', page: 5
# 2024-12-27 01:24:16,043 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第二章  招标需求', page: 5
# 2024-12-27 01:24:16,044 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,044 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,044 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,044 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,045 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 38
# 2024-12-27 01:24:16,046 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 39, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,047 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第三章  投标人须知', page: 8
# 2024-12-27 01:24:16,047 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第三章  投标人须知', page: 8
# 2024-12-27 01:24:16,047 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,047 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,048 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,048 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,049 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 39
# 2024-12-27 01:24:16,050 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 40, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,050 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '前附表', page: 8
# 2024-12-27 01:24:16,050 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '前附表', page: 8
# 2024-12-27 01:24:16,051 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,051 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,051 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,051 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,052 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 40
# 2024-12-27 01:24:16,053 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 41, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,054 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '一、总则', page: 12
# 2024-12-27 01:24:16,054 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '一、总则', page: 12
# 2024-12-27 01:24:16,054 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,054 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,055 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,055 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,056 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 41
# 2024-12-27 01:24:16,056 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 42, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,057 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '二、招标文件', page: 13
# 2024-12-27 01:24:16,057 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '二、招标文件', page: 13
# 2024-12-27 01:24:16,058 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,058 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,058 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,058 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,060 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 42
# 2024-12-27 01:24:16,060 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 43, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,061 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '三、投标文件的编制', page: 14
# 2024-12-27 01:24:16,061 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '三、投标文件的编制', page: 14
# 2024-12-27 01:24:16,062 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 440
# 2024-12-27 01:24:16,062 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 440
# 2024-12-27 01:24:16,062 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 440 (range: 364-547)
# 2024-12-27 01:24:16,062 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 440 (range: 364-547)
# 2024-12-27 01:24:16,064 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 43
# 2024-12-27 01:24:16,064 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 44, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,065 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '四、开标', page: 18
# 2024-12-27 01:24:16,065 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '四、开标', page: 18
# 2024-12-27 01:24:16,066 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 460
# 2024-12-27 01:24:16,066 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 460
# 2024-12-27 01:24:16,067 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 460 (range: 364-547)
# 2024-12-27 01:24:16,067 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 460 (range: 364-547)
# 2024-12-27 01:24:16,068 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 44
# 2024-12-27 01:24:16,068 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 45, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,070 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '五、评标', page: 19
# 2024-12-27 01:24:16,070 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '五、评标', page: 19
# 2024-12-27 01:24:16,070 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,070 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,071 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,071 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,072 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 45
# 2024-12-27 01:24:16,073 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 46, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,074 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '六、定标', page: 21
# 2024-12-27 01:24:16,074 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '六、定标', page: 21
# 2024-12-27 01:24:16,074 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 441
# 2024-12-27 01:24:16,074 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 441
# 2024-12-27 01:24:16,075 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 441 (range: 364-547)
# 2024-12-27 01:24:16,075 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 441 (range: 364-547)
# 2024-12-27 01:24:16,077 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 46
# 2024-12-27 01:24:16,077 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 47, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,078 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '七、合同授予', page: 21
# 2024-12-27 01:24:16,078 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '七、合同授予', page: 21
# 2024-12-27 01:24:16,079 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 439
# 2024-12-27 01:24:16,079 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 439
# 2024-12-27 01:24:16,079 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 439 (range: 364-547)
# 2024-12-27 01:24:16,079 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 439 (range: 364-547)
# 2024-12-27 01:24:16,080 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 47
# 2024-12-27 01:24:16,081 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 48, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,082 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '八、履约保证金', page: 21
# 2024-12-27 01:24:16,082 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '八、履约保证金', page: 21
# 2024-12-27 01:24:16,082 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,082 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 443
# 2024-12-27 01:24:16,083 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,083 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 443 (range: 364-547)
# 2024-12-27 01:24:16,084 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 48
# 2024-12-27 01:24:16,084 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 49, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,085 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '九、招标代理服务费的收取', page: 21
# 2024-12-27 01:24:16,085 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '九、招标代理服务费的收取', page: 21
# 2024-12-27 01:24:16,086 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 445
# 2024-12-27 01:24:16,086 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 445
# 2024-12-27 01:24:16,087 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 445 (range: 364-547)
# 2024-12-27 01:24:16,087 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 2 for indent 445 (range: 364-547)
# 2024-12-27 01:24:16,088 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 49
# 2024-12-27 01:24:16,088 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 50, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:16,089 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第四章  评标办法及评分标准', page: 22
# 2024-12-27 01:24:16,089 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Cleaned TOC content: '第四章  评标办法及评分标准', page: 22
# 2024-12-27 01:24:16,089 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,089 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Current element indent: 20
# 2024-12-27 01:24:16,090 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,090 - docx_parser_package.docx_parser._03_element_extractor.ParagraphExtractor - DEBUG - Found TOC level 1 for indent 20 (range: 16-24)
# 2024-12-27 01:24:16,091 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 50
# ...
# 2024-12-27 01:24:18,245 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 916, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,246 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 916 was skipped or pending
# 2024-12-27 01:24:18,246 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 917, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,247 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '致：北京中外建工程管理有限公司' (original: '致：北京中外建工程管理有限公司')
# 2024-12-27 01:24:18,247 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,248 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '致：北京中外建工程管理有限公司'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,248 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 917
# 2024-12-27 01:24:18,249 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 918, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,249 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 918 was skipped or pending
# 2024-12-27 01:24:18,250 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 919, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,250 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 919 was skipped or pending
# 2024-12-27 01:24:18,251 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 920, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,251 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 920 was skipped or pending
# 2024-12-27 01:24:18,252 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 921, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,252 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '本单位 （投标人名称） 关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： 2024 年 4 月 11 日 09 时 00 分前通过 快递 方式（快递单号： ）递 交至开标地点，如投标文件、样品及本声明书未在递交截止时间前送达指定地点 的，我单位默认放弃本次投标，并承担由此产生的一切后果。' (original: '本单位   （投标人名称）    关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： 2024 年 4 月 11 日 09 时 00 分前通过 快递 方式（快递单号：          ）递 交至开标地点，如投标文件、样品及本声明书未在递交截止时间前送达指定地点 的，我单位默认放弃本次投标，并承担由此产生的一切后果。')
# 2024-12-27 01:24:18,253 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,253 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '本单位 （投标人名称） 关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： 2024 年 4 月 11 日 09 时 00 分前通过 快递 方式（快递单号： ）递 交至开标地点，如投标文件、样品及本声明书未在递交截止时间前送达指定地点 的，我单位默认放弃本次投标，并承担由此产生的一切后果。'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,254 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 921
# 2024-12-27 01:24:18,254 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 922, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,255 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '本单位 （投标人名称） 不参加 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）现场开标活动，承诺 认可开标过程以及由本项目招标人代为签署的一切过程文件。' (original: '本单位     （投标人名称）     不参加  北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）现场开标活动，承诺 认可开标过程以及由本项目招标人代为签署的一切过程文件。')
# 2024-12-27 01:24:18,256 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,256 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '本单位 （投标人名称） 不参加 北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）现场开标活动，承诺 认可开标过程以及由本项目招标人代为签署的一切过程文件。'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,256 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 922
# 2024-12-27 01:24:18,257 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 923, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,258 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '本单位以腾讯会议的方式参加北京京铁运恒采购供应站有限公司 2024 年端 午节物资采购项目（第一包：一级压榨花生油）的开标活动，如因自身原因未能 准时进入视频会场，我单位承诺认可本项目开标的全过程，并确认开标全部内容。' (original: '本单位以腾讯会议的方式参加北京京铁运恒采购供应站有限公司 2024 年端 午节物资采购项目（第一包：一级压榨花生油）的开标活动，如因自身原因未能 准时进入视频会场，我单位承诺认可本项目开标的全过程，并确认开标全部内容。')
# 2024-12-27 01:24:18,258 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,259 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '本单位以腾讯会议的方式参加北京京铁运恒采购供应站有限公司 2024 年端 午节物资采购项目（第一包：一级压榨花生油）的开标活动，如因自身原因未能 准时进入视频会场，我单位承诺认可本项目开标的全过程，并确认开标全部内容。'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,259 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 923
# 2024-12-27 01:24:18,261 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 924, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,262 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '特此声明！' (original: '特此声明！')
# 2024-12-27 01:24:18,263 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,263 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '特此声明！'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,264 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 924
# 2024-12-27 01:24:18,265 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 925, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,266 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 925 was skipped or pending
# 2024-12-27 01:24:18,266 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 926, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,267 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '投标人名称：（公章）' (original: '                    投标人名称：（公章）')
# 2024-12-27 01:24:18,268 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,268 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '投标人名称：（公章）'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,269 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 926
# 2024-12-27 01:24:18,270 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 927, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,271 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Element 927 was skipped or pending
# 2024-12-27 01:24:18,271 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Processing element 928, type: ElementType.PARAGRAPH
# 2024-12-27 01:24:18,272 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Trying to match content: '法定代表人或被授权代表(签字或盖章)： 年 月 日' (original: '                            法定代表人或被授权代表(签字或盖章)： 年   月   日')
# 2024-12-27 01:24:18,273 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Available TOC entries: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,273 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - No match found for: '法定代表人或被授权代表(签字或盖章)： 年 月 日'. Available keys: ['第一章 招标公告', '第二章 招标需求', '第三章 投标人须知', '前附表', '一、总则', '二、招标文件', '三、投标文件的编制', '四、开标', '五、评标', '六、定标', '七、合同授予', '八、履约保证金', '九、招标代理服务费的收取', '第四章 评标办法及评分标准', '附件一：资格审查表', '附件二：符合性审查表', '附件三：评分标准', '第五章 合同条款及格式', '第六章 投标文件格式', '附件 1 投标函', '附件 2 投标保证书', '附件 3 无违法记录声明', '附件 4 法定代表人授权书', '附件 5 投标人情况简介', '附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表', '附件 7 投标一览表', '附件 8 分项报价表', '附件 9 投标方案', '附件 10 投标人资格声明', '附件 11 资格证明文件', '附件 12 与投标人存在“关系”的其他法人单位信息', '附件 13 投标人认为必要的其他证明文件', '附件 14 技术规格偏离表', '附件 15 商务条款偏离表', '附件 16 拟投入本项目的人员配备表', '附件 17 中标服务费承诺书', '附件 18 关于投标保证金的声明', '附件 19 开标会声明书']
# 2024-12-27 01:24:18,274 - docx_parser_package.docx_parser._03_element_extractor - DEBUG - Successfully extracted ElementType.PARAGRAPH element 928
# 2024-12-27 01:24:18,275 - docx_parser_package.docx_parser._03_element_extractor - INFO - Extraction complete. Total elements extracted: 655
# 2024-12-27 01:24:18,275 - docx_parser_package.docx_parser.pipeline - INFO - 成功提取655个元素

# %% [markdown]
# #### 测试_02_parts_creator.py

# %%
# 初始化并测试
creator = PartsCreator()
parts = creator.output_parts(elements)

# %%
for part in parts:
    print(f"{part['part_sequence']}: {part['part_level']},{part['No_of_elm']} 个, 总长: {part['part_length']} , 内容: {part['pure_content_length']}: {part['part_name']}")
# Out:
# 1: chapter,49 个, 总长: 3145 , 内容: 2335: 第一章 招标公告
# 2: chapter,30 个, 总长: 2140 , 内容: 1643: 第二章 招标需求
# 3: chapter,1 个, 总长: 25 , 内容: 10: 第三章 投标人须知
# 4: section,5 个, 总长: 2808 , 内容: 2727: 前附表
# 5: section,29 个, 总长: 1687 , 内容: 1208: 一、总则
# 6: section,16 个, 总长: 904 , 内容: 646: 二、招标文件
# 7: section,81 个, 总长: 4601 , 内容: 3239: 三、投标文件的编制
# 8: section,11 个, 总长: 563 , 内容: 381: 四、开标
# 9: section,27 个, 总长: 1647 , 内容: 1200: 五、评标
# 10: section,4 个, 总长: 233 , 内容: 169: 六、定标
# 11: section,2 个, 总长: 113 , 内容: 83: 七、合同授予
# 12: section,2 个, 总长: 85 , 内容: 55: 八、履约保证金
# 13: section,6 个, 总长: 439 , 内容: 342: 九、招标代理服务费的收取
# 14: chapter,44 个, 总长: 2848 , 内容: 2109: 第四章 评标办法及评分标准
# 15: section,3 个, 总长: 1079 , 内容: 1032: 附件一：资格审查表
# 16: section,2 个, 总长: 529 , 内容: 499: 附件二：符合性审查表
# 17: section,9 个, 总长: 3556 , 内容: 3407: 附件三：评分标准
# 18: chapter,135 个, 总长: 9981 , 内容: 7734: 第五章 合同条款及格式
# 19: chapter,14 个, 总长: 565 , 内容: 342: 第六章 投标文件格式
# 20: section,17 个, 总长: 780 , 内容: 500: 附件 1 投标函
# 21: section,8 个, 总长: 360 , 内容: 229: 附件 2 投标保证书
# 22: section,8 个, 总长: 227 , 内容: 97: 附件 3 无违法记录声明
# 23: section,8 个, 总长: 377 , 内容: 246: 附件 4 法定代表人授权书
# 24: section,3 个, 总长: 1360 , 内容: 1314: 附件 5 投标人情况简介
# 25: section,3 个, 总长: 241 , 内容: 194: 附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表
# 26: section,8 个, 总长: 557 , 内容: 426: 附件 7 投标一览表
# 27: section,9 个, 总长: 528 , 内容: 381: 附件 8 分项报价表
# 28: section,10 个, 总长: 363 , 内容: 198: 附件 9 投标方案
# 29: section,7 个, 总长: 334 , 内容: 219: 附件 10 投标人资格声明
# 30: section,15 个, 总长: 892 , 内容: 645: 附件 11 资格证明文件
# 31: section,1 个, 总长: 32 , 内容: 17: 附件 13 投标人认为必要的其他证明文件
# 32: section,6 个, 总长: 462 , 内容: 365: 附件 14 技术规格偏离表
# 33: section,6 个, 总长: 435 , 内容: 338: 附件 15 商务条款偏离表
# 34: section,6 个, 总长: 272 , 内容: 174: 附件 16 拟投入本项目的人员配备表
# 35: section,6 个, 总长: 442 , 内容: 345: 附件 17 中标服务费承诺书
# 36: section,10 个, 总长: 537 , 内容: 372: 附件 18 关于投标保证金的声明
# 37: section,9 个, 总长: 664 , 内容: 517: 附件 19 开标会声明书

# %%
from pprint import pprint
pprint(parts[10])
# Out:
# {'No_of_elm': 2,
#  'content': '元素：299\n'
#             '类型：Section 标题\n'
#             '内容：七、合同授予\n'
#             '\n'
#             '\n'
#             '元素：300\n'
#             '类型：初筛为待定\n'
#             '内容：1.招标人与中标人应当在《中标通知书》发出之日起 30  日内签订合同。 '
#             '2.中标人拖延、拒签合同的,将被扣罚投标保证金并取消中标资格。\n'
#             '\n',
#  'part_length': 113,
#  'part_level': 'section',
#  'part_name': '七、合同授予',
#  'part_sequence': 11,
#  'pure_content_length': 83}

# %%
print(parts[10]['content'])
# Out:
# 元素：299
# 类型：Section 标题
# 内容：七、合同授予
#
#
# 元素：300
# 类型：初筛为待定
# 内容：1.招标人与中标人应当在《中标通知书》发出之日起 30  日内签订合同。 2.中标人拖延、拒签合同的,将被扣罚投标保证金并取消中标资格。

# %%
# 7. 显示处理结果
#from pprint import pprint
print(f"总共识别出 {len(parts)} 个文档部分\n")
print("=" * 50)

for i, part in enumerate(parts, 1):
    print(f"\n第 {i} 部分:")
    print("-" * 50)
    print(part['content'][:300]) # 打印内容的第一行
    print(f"纯文本长度：{part['pure_content_length']} tokens")
    print(f"Part长度：{part['part_length']} tokens")
    print("=" * 50)
# Out:
# 总共识别出 37 个文档部分
#
# ==================================================
#
# 第 1 部分:
# --------------------------------------------------
# 元素：46
# 类型：Chapter 标题
# 内容：第一章 招标公告
#
#
# 元素：47
# 类型：初筛为正文
# 内容：根据《中华人民共和国招标投标法》、《中华人民共和国招标投标法实施条 例》等规定， 北京中外建工程管理有限公司受招标人委托，就北京京铁运恒采购 供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）进行  国内公开招标采购，欢迎合格的投标人前来投标。
#
#
# 元素：48
# 类型：初筛为待定
# 内容：一、项目编号：DLXM-2024-148-01
#
#
# 元素：49
# 类型：初筛为待定
# 内容：二、采购组织类型：委托代理
#
#
# 元素：50
# 类型：初筛为待定
# 内容：三、采购方式：公开招标
#
#
# 元素
# 纯文本长度：2335 tokens
# Part长度：3145 tokens
# ==================================================
#
# 第 2 部分:
# --------------------------------------------------
# 元素：95
# 类型：Chapter 标题
# 内容：第二章 招标需求
#
#
# 元素：96
# 类型：初筛为待定
# 内容：一、概述
#
#
# 元素：97
# 类型：初筛为待定
# 内容：1.本招标项目是针对北京京铁运恒采购供应站有限公司所需货物的采购、供应、 运输、验收及售后服务进行的招标。
#
#
# 元素：98
# 类型：初筛为待定
# 内容：2.本项目的组织及解释权归招标人。
#
#
# 元素：99
# 类型：初筛为待定
# 内容：3.招标文件中的技术要求是基本质量要求，投标人应根据自己的投标方案综合考 虑详细的技术指标，但不得低于招标基本质量要求。
#
#
# 元素：100
# 类型：初筛为正文
# 内容：4.投标人供应的产品，需符合国家《中华人民共和国产品质量法
# 纯文本长度：1643 tokens
# Part长度：2140 tokens
# ==================================================
#
# 第 3 部分:
# --------------------------------------------------
# 元素：125
# 类型：Chapter 标题
# 内容：第三章 投标人须知
#
#
# 纯文本长度：10 tokens
# Part长度：25 tokens
# ==================================================
#
# 第 4 部分:
# --------------------------------------------------
# 元素：126
# 类型：Section 标题
# 内容：前附表
#
#
# 元素：127
# 类型：初筛为正文
# 内容：| 序号 | [合并单元格 →6] 内容、要求 |  |  |  |  |  |
# |---|---|---|---|---|---|---|
# | 1 | [合并单元格 →6] 项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第 一包：一级压榨花生油） |  |  |  |  |  |
# | 2 | [合并单元格 →6] 采购数量及单位：一级压榨花生油   160000   桶（5L/桶） |  |  |  |  |  |
# | [合并单元格 ↓2] *3 | [合并单元格 →
# 纯文本长度：2727 tokens
# Part长度：2808 tokens
# ==================================================
#
# 第 5 部分:
# --------------------------------------------------
# 元素：131
# 类型：Section 标题
# 内容：一、总则
#
#
# 元素：132
# 类型：初筛为待定
# 内容：（一）适用范围
#
#
# 元素：133
# 类型：初筛为待定
# 内容：本招标文件适用于北京京铁运恒采购供应站有限公司 2024 年端午节物资采  购项目的招标、投标、评标、定标、验收、合同履约、付款等行为（法律、法规 另有规定的，从其规定）。
#
#
# 元素：134
# 类型：初筛为待定
# 内容：（二） 定义
#
#
# 元素：135
# 类型：初筛为待定
# 内容：1.“招标人”系指组织本次招标的代理机构和采购单位。 2.“投标人”系指向招标人提交投标文件的单位。
#
#
# 元素：136
# 类型：初筛为待定
# 内容：3.“货物”系指供方按招标
# 纯文本长度：1208 tokens
# Part长度：1687 tokens
# ==================================================
#
# 第 6 部分:
# --------------------------------------------------
# 元素：160
# 类型：Section 标题
# 内容：二、招标文件
#
#
# 元素：161
# 类型：初筛为待定
# 内容：（一）招标文件的构成。本招标文件由以下部分组成：
#
#
# 元素：162
# 类型：初筛为待定
# 内容：1.招标公告
#
#
# 元素：163
# 类型：初筛为待定
# 内容：2.招标需求
#
#
# 元素：164
# 类型：初筛为待定
# 内容：3.投标人须知
#
#
# 元素：165
# 类型：初筛为待定
# 内容：4.评标办法及评分标准 5.合同条款
#
#
# 元素：166
# 类型：初筛为待定
# 内容：6.投标文件格式
#
#
# 元素：167
# 类型：初筛为待定
# 内容：7.本项目招标文件的澄清、答复、修改、补充的内容
#
#
# 元素：168
# 类型：初筛为待定
# 内容：（
# 纯文本长度：646 tokens
# Part长度：904 tokens
# ==================================================
#
# 第 7 部分:
# --------------------------------------------------
# 元素：176
# 类型：Section 标题
# 内容：三、投标文件的编制
#
#
# 元素：177
# 类型：初筛为待定
# 内容：（一）、投标文件的组成
#
#
# 元素：178
# 类型：初筛为待定
# 内容：1. 投标人应完整地按招标文件要求的投标文件格式编写投标文件，投标文 件应包含但不限于以下内容：
#
#
# 元素：179
# 类型：初筛为待定
# 内容：（1）投标函；
#
#
# 元素：180
# 类型：初筛为待定
# 内容：（2）投标保证书；
#
#
# 元素：181
# 类型：初筛为待定
# 内容：（3）无违法记录声明；
#
#
# 元素：182
# 类型：初筛为待定
# 内容：（4）法定代表人授权书；
#
#
# 元素：183
# 类型：初筛为待定
# 内容：    ①投标人代表若为法定代
# 纯文本长度：3239 tokens
# Part长度：4601 tokens
# ==================================================
#
# 第 8 部分:
# --------------------------------------------------
# 元素：257
# 类型：Section 标题
# 内容：四、开标
#
#
# 元素：258
# 类型：初筛为待定
# 内容：（一）、开标准备
#
#
# 元素：259
# 类型：初筛为待定
# 内容：招标代理机构将在规定的时间和地点进行开标，投标人的法定代表人或其授 权代表应参加线上开标会。投标人的法定代表人或其授权代表未按时参加线上开 标会的，视同放弃开标监督权利、认可开标结果。
#
#
# 元素：260
# 类型：初筛为待定
# 内容：（二）、开标程序：
#
#
# 元素：261
# 类型：初筛为待定
# 内容：1.开标会由招标代理机构主持，主持人宣布开标会议开始； 2.主持人介绍参加开标会的人员名单；
#
#
# 元素：262
# 类型：初筛为待定
# 内容：3.主持人宣布
# 纯文本长度：381 tokens
# Part长度：563 tokens
# ==================================================
#
# 第 9 部分:
# --------------------------------------------------
# 元素：268
# 类型：Section 标题
# 内容：五、评标
#
#
# 元素：269
# 类型：初筛为待定
# 内容：（一）、组建评标委员会
#
#
# 元素：270
# 类型：初筛为待定
# 内容：评标委员会根据招标采购项目的特点进行组建，并负责评标工作。评标委员 会由招标人代表和有关技术、经济等方面的专家组成。成员为 5 人以上单数，专 家不得少于 2/3。
#
#
# 元素：271
# 类型：初筛为待定
# 内容：评标委员会履行下列职责：
#
#
# 元素：272
# 类型：初筛为待定
# 内容：（1）审查投标文件是否符合招标文件要求，并做出评价；
#
#
# 元素：273
# 类型：初筛为待定
# 内容：（2）要求投标人对投标文件有关事项作出解释或者澄清；
#
#
# 元素
# 纯文本长度：1200 tokens
# Part长度：1647 tokens
# ==================================================
#
# 第 10 部分:
# --------------------------------------------------
# 元素：295
# 类型：Section 标题
# 内容：六、定标
#
#
# 元素：296
# 类型：初筛为待定
# 内容：本项目评标委员会按评审排序结果推荐 1-3 名中标候选人，并由招标人确定 中标人。
#
#
# 元素：297
# 类型：初筛为待定
# 内容：1. 招标代理机构在评标结束后将评标报告交招标人确认，同时在发布招标公 告的网站上对评标结果进行公示。
#
#
# 元素：298
# 类型：初筛为待定
# 内容：2. 若中标人放弃中标、或因不可抗力提出不能履行合同， 或不按招标文件规 定提交履约保证金或其它原因被依法撤销中标资格，则招标人重新组织招标。
#
#
# 纯文本长度：169 tokens
# Part长度：233 tokens
# ==================================================
#
# 第 11 部分:
# --------------------------------------------------
# 元素：299
# 类型：Section 标题
# 内容：七、合同授予
#
#
# 元素：300
# 类型：初筛为待定
# 内容：1.招标人与中标人应当在《中标通知书》发出之日起 30  日内签订合同。 2.中标人拖延、拒签合同的,将被扣罚投标保证金并取消中标资格。
#
#
# 纯文本长度：83 tokens
# Part长度：113 tokens
# ==================================================
#
# 第 12 部分:
# --------------------------------------------------
# 元素：301
# 类型：Section 标题
# 内容：八、履约保证金
#
#
# 元素：302
# 类型：初筛为待定
# 内容：中标人与招标人签订合同后 7 个工作日内，向招标人提交合同总价款 10%的 履约保证金。
#
#
# 纯文本长度：55 tokens
# Part长度：85 tokens
# ==================================================
#
# 第 13 部分:
# --------------------------------------------------
# 元素：303
# 类型：Section 标题
# 内容：九、招标代理服务费的收取
#
#
# 元素：304
# 类型：初筛为待定
# 内容：1. 招标代理服务费由中标人支付。
#
#
# 元素：305
# 类型：初筛为待定
# 内容：2.招标代理服务费的收取标准：按照《招标代理服务收费标准》货物收费标 准下浮 12%计取。
#
#
# 元素：306
# 类型：初筛为待定
# 内容：                招标代理服务收费标准
#
#
# 元素：307
# 类型：初筛为正文
# 内容：| 服务类型及费率   中标金额（万元） | 货物招标 | 服务招标 | 工程招标 |
# |---|---|---|---|
# | 100   以下 | 1.5% | 1.5% |
# 纯文本长度：342 tokens
# Part长度：439 tokens
# ==================================================
#
# 第 14 部分:
# --------------------------------------------------
# 元素：309
# 类型：Chapter 标题
# 内容：第四章 评标办法及评分标准
#
#
# 元素：310
# 类型：初筛为待定
# 内容：一、评标原则及顺序
#
#
# 元素：311
# 类型：初筛为待定
# 内容：    （一）招标人负责依法组建评标委员会，评标工作由评标委员会承担。评标委员 会由技术、经济等方面的专家和招标人委派的评标代表共同组成。成员为
#
#
# 元素：312
# 类型：初筛为待定
# 内容：    5 人以上单数，专家不得少于 2/3。
#
#
# 元素：313
# 类型：初筛为正文
# 内容：    （二）评标工作依据《中华人民共和国招标投标法》、国家七部委联合颁发的《评 标委员会和评标办法暂行规定》等相关法律法规中规定的公平、公正
# 纯文本长度：2109 tokens
# Part长度：2848 tokens
# ==================================================
#
# 第 15 部分:
# --------------------------------------------------
# 元素：353
# 类型：Section 标题
# 内容：附件一：资格审查表
#
#
# 元素：354
# 类型：初筛为正文
# 内容：| 序号 | 审查内容 | 合格条件 |
# |---|---|---|
# | 1 | 在中华人民共和国注册并具有独立   法人资格，具有工商行政主管部门   颁发的营业执照。 | 投标人须提供有效的营业执照复印件并   加盖公章 |
# | 2 | 距投标截止时间近半年内任意一个   月的依法缴纳社会保险记录和依法   纳税记录 | 投标人须提供距投标截止时间近半年内   任意一个月的依法缴纳社会保险记录和   依法纳税记录复印件并加盖公章 |
# | 3 | 投标人须提供近三年内，在经营活
# 纯文本长度：1032 tokens
# Part长度：1079 tokens
# ==================================================
#
# 第 16 部分:
# --------------------------------------------------
# 元素：356
# 类型：Section 标题
# 内容：附件二：符合性审查表
#
#
# 元素：357
# 类型：初筛为正文
# 内容：| 序号 | 审查内容 |
# |---|---|
# | 1 | 是否按照招标文件规定的格式提供法定代表人授权书 |
# | 2 | 是否递交投标保证金或投标保证金金额是否符合招标文件要求； |
# | 3 | 投标有效期是否满足招标文件要求 |
# | 4 | 是否按照招标文件要求密封、签署、盖章 |
# | 5 | 是否按招标文件要求提供资格证书和资质证明文件 |
# | 6 | 是否对招标文件带“*”号的重要商务、技术条款作 出负偏离响应和未作实质   性响应 |
# | 7 | 是否对招标文件做出实质性响
# 纯文本长度：499 tokens
# Part长度：529 tokens
# ==================================================
#
# 第 17 部分:
# --------------------------------------------------
# 元素：358
# 类型：Section 标题
# 内容：附件三：评分标准
#
#
# 元素：359
# 类型：初筛为待定
# 内容：    （一）、价格分（40 分）
#
#
# 元素：360
# 类型：初筛为正文
# 内容：| 序号 | 评审因素 | 分值 | 评分标准说明 |
# |---|---|---|---|
# | 1 | 价格分 | 40 | > 嵌套表格:
# > | 评分标准 | 投标人名称及评审得分 |
# > |---|---|
# > |   |   |   |   |
# > | β值分布 | 分值 | β | 得分 | β | 得分 | β | 得分 |
# > | 依次递减 |   |   |   |   |   |   |
# >
# 纯文本长度：3407 tokens
# Part长度：3556 tokens
# ==================================================
#
# 第 18 部分:
# --------------------------------------------------
# 元素：367
# 类型：Chapter 标题
# 内容：第五章 合同条款及格式
#
#
# 元素：368
# 类型：初筛为待定
# 内容：买卖合同
#
#
# 元素：369
# 类型：初筛为待定
# 内容：                            甲方合同编号:           乙方合同编号:
#
#
# 元素：370
# 类型：初筛为待定
# 内容：甲        方（买   方 ）： 北京京铁运恒采购供应站有限公司
#
#
# 元素：371
# 类型：初筛为待定
# 内容：法定代表人（负责人 ）：  王荣生
#
#
# 元素：372
# 类型：初筛为待定
# 内容：住                    所：  北京市丰台区北京西站东附楼瑞尔威
#
#
# 元素
# 纯文本长度：7734 tokens
# Part长度：9981 tokens
# ==================================================
#
# 第 19 部分:
# --------------------------------------------------
# 元素：502
# 类型：Chapter 标题
# 内容：第六章 投标文件格式
#
#
# 元素：503
# 类型：初筛为待定
# 内容：    附件 1—投标函
#
#
# 元素：504
# 类型：初筛为待定
# 内容：    附件 2—投标保证书
#
#
# 元素：505
# 类型：初筛为待定
# 内容：    附件 3—无违法记录声明
#
#
# 元素：506
# 类型：初筛为待定
# 内容：    附件 4—法定代表人授权书 附件 5—投标人情况简介
#
#
# 元素：507
# 类型：初筛为待定
# 内容：    附件 6—投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表
#
#
# 元素：508
# 类型：初筛为待定
# 内容：    附件 7—投标一览表 附件
# 纯文本长度：342 tokens
# Part长度：565 tokens
# ==================================================
#
# 第 20 部分:
# --------------------------------------------------
# 元素：516
# 类型：Section 标题
# 内容：附件 1 投标函
#
#
# 元素：517
# 类型：初筛为待定
# 内容：致：招标人
#
#
# 元素：518
# 类型：初筛为正文
# 内容：根据贵方为                 项目招标采购货物及服务的招标要求，签字代 表          （全名、职务）经正式授权并代表投标人                  （投 标人名称、地址）提交下述文件正本 一 份和副本       份及电子版      份。
#
#
# 元素：519
# 类型：初筛为待定
# 内容：1、开标一览表
#
#
# 元素：520
# 类型：初筛为待定
# 内容：2、分项报价表
#
#
# 元素：521
# 类型：初筛为待定
# 内容：3、投
# 纯文本长度：500 tokens
# Part长度：780 tokens
# ==================================================
#
# 第 21 部分:
# --------------------------------------------------
# 元素：533
# 类型：Section 标题
# 内容：附件 2 投标保证书
#
#
# 元素：534
# 类型：初筛为待定
# 内容：致：招标人
#
#
# 元素：535
# 类型：初筛为待定
# 内容：（投标人名称）参加贵方组织的                  项目的投标，对以下事项进行保证：
#
#
# 元素：536
# 类型：初筛为待定
# 内容：1、遵守《中华人民共和国招标投标法》和相关法律法规，严格按照招标文 件的要求参加投标，不进行任何破坏招标活动的行为。
#
#
# 元素：537
# 类型：初筛为待定
# 内容：2、保证投标内容的真实、合法、有效及准确。
#
#
# 元素：538
# 类型：初筛为待定
# 内容：3、若中标，保证按规定的时间、地点与招标人签订合
# 纯文本长度：229 tokens
# Part长度：360 tokens
# ==================================================
#
# 第 22 部分:
# --------------------------------------------------
# 元素：541
# 类型：Section 标题
# 内容：附件 3 无违法记录声明
#
#
# 元素：542
# 类型：初筛为待定
# 内容：致：招标人
#
#
# 元素：543
# 类型：初筛为待定
# 内容：我单位在参加本次项目投标活动前三年内，在经营活动中没有重大违法
#
#
# 元素：544
# 类型：初筛为待定
# 内容：记录。
#
#
# 元素：545
# 类型：初筛为待定
# 内容：特此声明！
#
#
# 元素：546
# 类型：初筛为待定
# 内容：法定代表人或被授权代表(签字或盖章)：
#
#
# 元素：547
# 类型：初筛为待定
# 内容：投标人名称（公章）：
#
#
# 元素：548
# 类型：初筛为待定
# 内容：日期：       年     月      日
#
#
# 纯文本长度：97 tokens
# Part长度：227 tokens
# ==================================================
#
# 第 23 部分:
# --------------------------------------------------
# 元素：549
# 类型：Section 标题
# 内容：附件 4 法定代表人授权书
#
#
# 元素：550
# 类型：初筛为待定
# 内容：致：招标人
#
#
# 元素：551
# 类型：初筛为正文
# 内容：本授权书声明：注册于（国家或地区的名称）的（公司名称）的在下面签字 的（法人代表（单位负责人）姓名、职务）代表本公司授权（单位名称）的在下 面签字的（被授权人的姓名、职务）（身份证件号码）为本公司的合法代理人， 就（项目名称）的投标，以本公司名义处理一切与之有关的事务。
#
#
# 元素：552
# 类型：初筛为待定
# 内容：本授权书于           年      月      日签字生效,特此声明。
#
#
# 元素：553
# 类型：初筛为
# 纯文本长度：246 tokens
# Part长度：377 tokens
# ==================================================
#
# 第 24 部分:
# --------------------------------------------------
# 元素：557
# 类型：Section 标题
# 内容：附件 5 投标人情况简介
#
#
# 元素：558
# 类型：初筛为待定
# 内容：投标人：（公章）                                              填表日期：      年    月    日
#
#
# 元素：559
# 类型：初筛为正文
# 内容：| 投标人全称 | [合并单元格 →6] |  |  |  |  |  | [合并单元格 →3] 成立日期 |  |  | [合并单元格 →3] |  |  |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | 详细地址 |
# 纯文本长度：1314 tokens
# Part长度：1360 tokens
# ==================================================
#
# 第 25 部分:
# --------------------------------------------------
# 元素：560
# 类型：Section 标题
# 内容：附件 6 投标人 2021 年 1 月 1 日起至投标截止日止同类产品销售业绩表
#
#
# 元素：561
# 类型：初筛为正文
# 内容：| 合同时间 | 项目名称 | 合作单位 | 合同金额 | 备注（如项目实施情况） |
# |---|---|---|---|---|
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
#
#
# 元素：562
# 类型：初筛为正文
# 内容：注：要求提供用户合同复印件、发票复印件、发票明细汇
# 纯文本长度：194 tokens
# Part长度：241 tokens
# ==================================================
#
# 第 26 部分:
# --------------------------------------------------
# 元素：563
# 类型：Section 标题
# 内容：附件 7 投标一览表
#
#
# 元素：564
# 类型：初筛为待定
# 内容：                                投标一览表
#
#
# 元素：565
# 类型：初筛为待定
# 内容：项目名称：北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）
#
#
# 元素：566
# 类型：初筛为正文
# 内容：| 序号 | 货物名称 | 规格 | 含税单价   （元/桶） | 数量（桶） | 投标总价（含税） （元） | 交货期 （含配送周期） | 交货地点 | 质保期 | 备注 |
# |---|---|---|---|---|---|
# 纯文本长度：426 tokens
# Part长度：557 tokens
# ==================================================
#
# 第 27 部分:
# --------------------------------------------------
# 元素：571
# 类型：Section 标题
# 内容：附件 8 分项报价表
#
#
# 元素：572
# 类型：初筛为待定
# 内容：                                    分项报价表
#
#
# 元素：573
# 类型：初筛为待定
# 内容：项目名称：                                                         项目编号：
#
#
# 元素：574
# 类型：初筛为待定
# 内容：                                                                报价单位：人民币元
#
#
# 元素：575
# 类型：初筛为正文
#
# 纯文本长度：381 tokens
# Part长度：528 tokens
# ==================================================
#
# 第 28 部分:
# --------------------------------------------------
# 元素：580
# 类型：Section 标题
# 内容：附件 9 投标方案
#
#
# 元素：581
# 类型：初筛为待定
# 内容：                （格式自制）
#
#
# 元素：582
# 类型：初筛为待定
# 内容：阐述对招标人采购需求的理解、对采购需求分析及对招标人采购需求拟定 投标方案。包括但不限于：
#
#
# 元素：583
# 类型：初筛为正文
# 内容：·拟投入本项目的人员配备方案； ·货物质量保证方案；
#
#
# 元素：584
# 类型：初筛为正文
# 内容：·食品安全卫生管理措施； ·配送方案
#
#
# 元素：585
# 类型：初筛为正文
# 内容：·售后服务制度和承诺；
#
#
# 元素：586
# 类型：初筛为正文
# 内容：·应急方案； ·检测报告；
# 纯文本长度：198 tokens
# Part长度：363 tokens
# ==================================================
#
# 第 29 部分:
# --------------------------------------------------
# 元素：590
# 类型：Section 标题
# 内容：附件 10 投标人资格声明
#
#
# 元素：591
# 类型：初筛为待定
# 内容：致：招标人
#
#
# 元素：592
# 类型：初筛为正文
# 内容：为响应你方       年      月       日的（项目编号）投标邀请，下述签字人 愿意参与投标，并提供满足招标需求中规定的（货物及服务），我方递交的投标 文件中全部说明、材料、文件内容是真实的和有效的。
#
#
# 元素：593
# 类型：初筛为待定
# 内容：我方详知：招标人可能要求提供进一步的资格材料，我方愿意配合你方，向 有关机构和单位（如银行、会计师事务所、相关企业等）查证和获得有关资料。
#
#
# 元素：594
# 类型：初筛为待
# 纯文本长度：219 tokens
# Part长度：334 tokens
# ==================================================
#
# 第 30 部分:
# --------------------------------------------------
# 元素：597
# 类型：Section 标题
# 内容：附件 11 资格证明文件
#
#
# 元素：598
# 类型：初筛为待定
# 内容：1、有效的营业执照复印件（加盖公章）
#
#
# 元素：599
# 类型：初筛为待定
# 内容：2、社会保险缴纳记录和依法纳税记录（近半年内任意一个月的依法缴纳社会保
#
#
# 元素：600
# 类型：初筛为待定
# 内容：险记录复印件并加盖公章）
#
#
# 元素：601
# 类型：初筛为待定
# 内容：3、提供近三年内，在经营活动中没有重大违法记录的声明（格式见附件 3）
#
#
# 元素：602
# 类型：初筛为待定
# 内容：4、在“信用中国”和“中国政府采购网”网站查询的投标人信用记录的查询结
#
#
# 元素：603
# 类型：初筛为待定
#
# 纯文本长度：645 tokens
# Part长度：892 tokens
# ==================================================
#
# 第 31 部分:
# --------------------------------------------------
# 元素：612
# 类型：Section 标题
# 内容：附件 13 投标人认为必要的其他证明文件
#
#
# 纯文本长度：17 tokens
# Part长度：32 tokens
# ==================================================
#
# 第 32 部分:
# --------------------------------------------------
# 元素：613
# 类型：Section 标题
# 内容：附件 14 技术规格偏离表
#
#
# 元素：614
# 类型：初筛为待定
# 内容：投标人名称：  （公章）      项目编号：
#
#
# 元素：615
# 类型：初筛为正文
# 内容：| 序号 | 产品名称 | 招标规格 | 投标规格 | 偏离 | 说明 |
# |---|---|---|---|---|---|
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |
# 纯文本长度：365 tokens
# Part长度：462 tokens
# ==================================================
#
# 第 33 部分:
# --------------------------------------------------
# 元素：619
# 类型：Section 标题
# 内容：附件 15 商务条款偏离表
#
#
# 元素：620
# 类型：初筛为待定
# 内容：投标人名称：     （公章）            项目编号：
#
#
# 元素：621
# 类型：初筛为正文
# 内容：| 序号 | 招标文件条目号 | 招标文件的商务条款 | 投标文件的商务条款 | 说明 |
# |---|---|---|---|---|
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
#
# 纯文本长度：338 tokens
# Part长度：435 tokens
# ==================================================
#
# 第 34 部分:
# --------------------------------------------------
# 元素：625
# 类型：Section 标题
# 内容：附件 16 拟投入本项目的人员配备表
#
#
# 元素：626
# 类型：初筛为待定
# 内容：项目名称：                                 项目编号：
#
#
# 元素：627
# 类型：初筛为正文
# 内容：| 1 | 管理人员数量 | 人 |
# |---|---|---|
# | 2 | 技术人员数量 | 人 |
# | 3 | 其他拟参加本项目工作人员数量 | 人 |
#
#
# 元素：628
# 类型：初筛为正文
# 内容：注：本表后附拟投入主要管理人和主要技术人员的社保证明（近半年内任意一个月 的证明材料）复印件加盖公章。
#
#
# 元素：629
# 类型：初筛为待定
# 内
# 纯文本长度：174 tokens
# Part长度：272 tokens
# ==================================================
#
# 第 35 部分:
# --------------------------------------------------
# 元素：631
# 类型：Section 标题
# 内容：附件 17 中标服务费承诺书
#
#
# 元素：632
# 类型：初筛为待定
# 内容：致：北京中外建工程管理有限公司：
#
#
# 元素：633
# 类型：初筛为正文
# 内容：我们在贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节物资 采购项目（第一包： 一级压榨花生油） 招标项目中若获中标（项目编号： DLXM-2024-148-01），我们保证在签订经济合同的同时按招标文件的规定，以支 票、汇票或现金， 向贵公司即北京中外建工程管理有限公司（地址：北京市丰台 区福宜街 5 号院 1 号楼新时代国际中心 A 座 15 层，开户银行：中国民生银行股 份有限公司
# 纯文本长度：345 tokens
# Part长度：442 tokens
# ==================================================
#
# 第 36 部分:
# --------------------------------------------------
# 元素：637
# 类型：Section 标题
# 内容：附件 18 关于投标保证金的声明
#
#
# 元素：638
# 类型：初筛为待定
# 内容：致：北京中外建工程管理有限公司
#
#
# 元素：639
# 类型：初筛为正文
# 内容：我单位参与贵公司组织的北京京铁运恒采购供应站有限公司 2024 年端午节 物资采购项目（第一包：一级压榨花生油），项目编号 DLXM-2024-148-01。在 招投标活动结束后，请将投标保证金退至我单位以下账户：
#
#
# 元素：640
# 类型：初筛为待定
# 内容：户    名： 开 户 行： 行    号： 账    号： 为此，我单位声明：
#
#
# 元素：641
# 类型：初筛为正文
# 内容：以上账户信息真实有效
# 纯文本长度：372 tokens
# Part长度：537 tokens
# ==================================================
#
# 第 37 部分:
# --------------------------------------------------
# 元素：647
# 类型：Section 标题
# 内容：附件 19 开标会声明书
#
#
# 元素：648
# 类型：初筛为待定
# 内容：        关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目 （第一包：一级压榨花生油）开标会的声明书
#
#
# 元素：649
# 类型：初筛为待定
# 内容：致：北京中外建工程管理有限公司
#
#
# 元素：650
# 类型：初筛为正文
# 内容：本单位   （投标人名称）    关于北京京铁运恒采购供应站有限公司 2024 年端午节物资采购项目（第一包：一级压榨花生油）的投标文件于递交截止时间： 2024 年 4 月 11 日 09 时 00 分前通过 快递 方式（快递单号：
# 纯文本长度：517 tokens
# Part长度：664 tokens
# ==================================================
